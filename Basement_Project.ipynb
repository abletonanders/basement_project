# %%
import asyncio
from playwright.async_api import async_playwright

async def get_event_links(url):
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(url)

        # Scroll down to load all dynamic content
        previous_height = None
        while True:
            current_height = await page.evaluate("document.body.scrollHeight")
            if previous_height == current_height:
                break
            await page.evaluate("window.scrollTo(0, document.body.scrollHeight)")
            await asyncio.sleep(1)
            previous_height = current_height

        # Extract links containing '/events/'
        links = await page.query_selector_all("a[href*='/events/']")
        event_links = [await link.get_attribute("href") for link in links]

        await browser.close()
        return event_links

url = "https://basementny.net/past"
events = await get_event_links(url)
print(events)

# Or, if you're running as a standalone script:
# asyncio.run(get_event_links(url))
# Out:
# ['/events/63e285d2-4a4a-4133-8ae0-6a57f3dc911a', '/events/32006196-222a-40e9-be76-202d55f1f96c', '/events/f1778147-8f5e-4106-afac-fa787cef899c', '/events/808cc6ab-063a-453c-9f9d-8cfecb9752dc', '/events/e7b6ebe1-db40-451a-a23a-408809f7484d', '/events/219ea7f2-37af-49b4-af2c-abe78e540422', '/events/8b849243-d119-4e7a-85f7-8caec4a269ee', '/events/d1147ab9-5f08-4695-9ee6-9740085c2eb5', '/events/828a55dd-6c5c-4c9d-b02e-7b442ce6926a', '/events/a0dbdfc5-c4ed-4e04-a05e-c5ba728f1f91', '/events/40ac783a-34e7-4d3a-899b-03a6b0cdce3f', '/events/764eb181-5f70-4f60-86f9-12a95ad32877', '/events/0d837954-fdcc-4248-bae4-5cd2ddfd4a98', '/events/91eabd5a-e619-48f3-8826-15524e30af05', '/events/37114c04-60ae-4c89-9c4e-9596cd38f906', '/events/02bfc52d-6d5d-4e54-9da8-7c7820de00e9', '/events/02a5bfc0-cfff-4e4c-af4f-d06addbe5386', '/events/a5a2d3db-8b82-4a60-b4eb-336fb3850a6a', '/events/08286661-eafd-43c8-8bd8-17cbee3f22ed', '/events/fd18978d-921b-4794-96a0-5f6162ffb2a2', '/events/5cb44f6f-fdb3-488b-86ee-6a93ba92b72a', '/events/3f69a3ea-fe62-4ecf-8d63-ca6b36e55827', '/events/e4fb0825-63d1-4263-983b-ae60e714e247', '/events/76b41f4e-aa1b-4078-a427-1d4490918964', '/events/74b23560-c108-480e-a60b-5995b37c9110', '/events/9c1b0c95-ff23-48a8-89b6-8cd715011c91', '/events/eab3db0f-ee35-4f3a-ac3d-846dbc7501a8', '/events/8210ed1b-c074-4217-8ff5-01b1364e7801', '/events/3b983098-ce82-40d9-803e-3042bff40be4', '/events/f16847c9-91c3-4673-9744-e6dcdee69a83', '/events/baa76d54-3f0d-49b7-9d4c-b9889b0c68a9', '/events/6961133d-be9f-469e-9c2e-f9bd220bf56d', '/events/b2a43fde-58e3-4c0b-82df-2ca4cfc3a243', '/events/abf1ed30-ea1a-4fa3-8d66-d78bb0ba01cc', '/events/280f56e2-6656-415f-87f0-b58654da0efc', '/events/c2c34d91-e5c5-4647-a40f-c73253e10085', '/events/8bacdb12-3fcf-4c48-bb3a-26a71261ec81', '/events/33db0aae-d319-40b2-9a7e-752411a897a9', '/events/cc145edb-b028-4d46-9b06-5492e56acc22', '/events/e25cc4df-6fc3-4542-89af-69cc58a5ecb3', '/events/402a67bb-1010-4ba9-ae33-f437c84bb9e0', '/events/11d545d9-065f-4126-aa8e-4803ab290305', '/events/d7109ef5-0237-4933-a460-e6488c45936c', '/events/c30d7f34-915b-4f6e-bfa2-97aeed2d8f88', '/events/1ef2ff90-966c-45d1-ad98-505534b627c9', '/events/e9b0c072-1aec-4ff3-b41b-4d82fe899e7c', '/events/4216dc40-b483-4273-a0d7-8f57f1dfc75e', '/events/335c6368-dc66-499d-9953-82e5590cf674', '/events/08f4344a-75a1-4c12-84ea-e2f0836aa876', '/events/090a521d-8a3e-472e-836e-2051758d3beb', '/events/a2a44514-150a-45a3-88d2-514722b7960a', '/events/186d25f0-6b55-48fb-a13f-7386bb43a8b4', '/events/6cce25bb-5da0-419c-8d9e-040567204644', '/events/6bfeacba-547f-4fdb-b9d8-dc91f8433c43', '/events/ac816dad-cddc-44d2-8945-ba3d390e642e', '/events/01624054-24dc-484e-a990-669a6b26ce4b', '/events/63f40f82-3591-4a8f-ba49-40ca8baa717c', '/events/f493c67a-1260-4c6a-9a2d-46307a6eac39', '/events/453b326d-2bce-45b5-8f97-598a6c08d2ea', '/events/fc2924dd-810f-42d3-9ad4-866afe1e6e7e', '/events/159b92d6-616a-411c-9129-e44a268c95f0', '/events/226badc1-c5d4-400f-a332-fa8532685257', '/events/a775c05b-9cf2-4028-a3af-3d4e449e5507', '/events/f127cff6-8964-496e-8ebf-a4a2f5eb7d9e', '/events/09ddf24e-8e78-4eb9-87f4-550570846d34', '/events/0c8a5c83-4fbf-4629-a010-02fdb77e16c7', '/events/e1667bff-c320-49ee-82b8-d224add30708', '/events/04b72dc1-1fd4-4f2a-9e5e-388444eb1cbc', '/events/7f612e43-aa6c-48fd-b692-72f7e6952f14', '/events/43431318-c40c-4622-8d2a-bfc44c6656f1', '/events/b2120d42-ef5f-40b5-b27c-7e5bfb44612e', '/events/169034ae-e9e4-4d45-8cf5-28d1395c66c3', '/events/59c5389b-5666-476d-983f-f4c1bd5edd86', '/events/ae5b319b-638a-44a3-884a-33be255799cc', '/events/69e5763c-8eb5-47b9-a4e9-912dc43764a2', '/events/518ae248-3a09-4494-9ecd-4e48ff9c7b5e', '/events/09bcb49c-23a2-4d7a-940a-dd5db7da3198', '/events/0907a79f-a14a-4471-aa2c-572f006886a9', '/events/2aa71e2e-89fc-4c95-8de5-60ea133a9e29', '/events/970b8b37-a13c-4000-9bb9-55c82a5fc993', '/events/7479f6e1-533b-4798-af9f-67dd4e38dc18', '/events/b5abf8d6-8ef2-4d9d-83c4-a6355d3e69bf', '/events/44ca5d2f-13b7-4005-a38c-f5a95a17075b', '/events/ff1a00 ...

# %%
import asyncio
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
from datetime import datetime
from dateutil.parser import parse as parse_date
import nest_asyncio
nest_asyncio.apply()

async def get_event_detail(url):
    # Launch browser and navigate to the URL
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(url)
        # Wait until the event date element is present, with an increased timeout
        await page.wait_for_selector("div.event-detail__date", timeout=9000)
        html = await page.content()
        await browser.close()
    
    # Parse the rendered HTML with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    
    # 1. Extract event detail date
    date_div = soup.find("div", class_="event-detail__date")
    if not date_div:
        raise ValueError("Could not find the event detail date element.")
    date_text = date_div.get_text(strip=True).title()
    # Use dateutil parser to handle multiple date formats
    event_date = parse_date(date_text)
    
    # 2. Extract event title
    title_h1 = soup.find("h1", class_="event-detail__title")
    if not title_h1:
        raise ValueError("Could not find the event detail title element.")
    event_title_div = title_h1.find("div", recursive=False)
    event_title = event_title_div.get_text(strip=True) if event_title_div else ""
    
    # 3. Extract event detail music information
    event_detail_music = []
    stage_divs = title_h1.find_all("div", class_=lambda c: c and "event-detail__title-stages" in c)
    for stage in stage_divs:
        container = stage.find("p") if stage.find("p") else stage
        headline_div = container.find("div", class_="event-detail__headline")
        if not headline_div:
            continue
        stage_name = headline_div.get_text(strip=True)
        dj_divs = container.find_all("div")
        dj_list = []
        for dj in dj_divs:
            if dj == headline_div:
                continue
            text = dj.get_text(strip=True)
            if not text or text.lower() == "null":
                continue
            if "event-detail__headline" in dj.get("class", []):
                continue
            dj_list.append(text)
        if stage_name and dj_list:
            event_detail_music.append({stage_name: dj_list})
    
    return {
        "event_detail_date": event_date,
        "event_detail_title": event_title,
        "event_detail_music": event_detail_music
    }

# Example usage:
if __name__ == "__main__":
    url = "https://basementny.net/events/3dd1e882-fb7d-4307-b0ae-d93bafaee185"
    event_data = asyncio.run(get_event_detail(url))
    print(event_data)
# Out:
# {'event_detail_date': datetime.datetime(2022, 3, 25, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['BLUE HOUR', 'TYGAPAW', 'MEMPHY', 'DJ CLONE', 'WORD OF COMMAND']}]}

# %%
event_data_list = []

# %%
len(event_data_list)
# Out:
# 150

# %%
for x in events[:150]:
    url = "https://basementny.net" + x
    event_data = asyncio.run(get_event_detail(url))
    print(event_data)
    event_data_list.append(event_data)
# Out:
# {'event_detail_date': datetime.datetime(2025, 3, 8, 22, 30), 'event_detail_title': 'March 8', 'event_detail_music': [{'Basement': ['DJ BONE', 'MIKE SERVITO', 'ROSE KOURTS']}, {'Studio': ['FKA.M4A', 'JASON KENDIG', 'COSMO']}]}
# {'event_detail_date': datetime.datetime(2025, 3, 7, 22, 30), 'event_detail_title': 'BASSIANI NIGHT', 'event_detail_music': [{'Basement': ['NEWA B2B NDRX', 'KANCHELI B2B NEBBIERI']}, {'Studio': ['GABRIELLE KWARTENG', '98DOTS', 'DJ SURGE']}]}
# {'event_detail_date': datetime.datetime(2025, 3, 1, 22, 30), 'event_detail_title': 'ALTÆR 5 Year Anniversary', 'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE', 'STERAC', 'AUSPEX']}, {'Studio': ['DAVID ELIMELECH', 'LOREN', "S'AINT PANIC"]}]}
# {'event_detail_date': datetime.datetime(2025, 2, 28, 22, 30), 'event_detail_title': 'X-TRA.SERVICES', 'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE', 'YANT', 'ÆON']}, {'Studio': ['HAAI', 'K WATA', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 22, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']}, {'Studio': ['JADALAREIGN', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 21, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['X CLUB.', 'LDS', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['MIKE SERVITO', 'TT', 'ALÍRIO']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 15, 22, 30), 'event_detail_title': 'FEBRUARY 15', 'event_detail_music': [{'Basement': ['DAX J', 'ANNĒ', 'ANNIE LEW']}, {'Studio': ['KEVIN AVIANCE', 'CHRIS CRUSE', 'MICHAEL CIGNARALE']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 14, 22, 30), 'event_detail_title': 'HERRENSAUNA', 'event_detail_music': [{'Basement': ['MCMLXXXV', 'DJ SALIVA', 'MARKUS']}, {'Studio': ['SCHACKE', 'KIM ANH', 'IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 8, 22, 30), 'event_detail_title': 'FEBRUARY 8', 'event_detail_music': [{'Basement': ['DARIA KOLOSOVA', 'ETAPP KYLE', 'KOZHA']}, {'Studio': ['ISABELLA', 'SEKUCCI B2B STERLING JUAN DIAZ', 'KIA']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 7, 22, 30), 'event_detail_title': 'FEBRUARY 7', 'event_detail_music': [{'Basement': ['BLASHA & ALLATT', 'SANDRIEN', 'DEVOYE']}, {'Studio': ['CHEZ DAMIER', 'DONIS', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2025, 2, 1, 22, 30), 'event_detail_title': 'FEBRUARY 1', 'event_detail_music': [{'Basement': ['BORIS', 'VOLVOX']}, {'Studio': ['MASSIMILIANO PAGLIARA']}]}
# {'event_detail_date': datetime.datetime(2025, 1, 25, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['DAIYAH', 'FURTIVE', 'RON LIKE HELL']}, {'Studio': ['CARLOS SOUFFRONT', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2025, 1, 18, 22, 30), 'event_detail_title': 'BOUND 8 YEAR ANNIVERSARY', 'event_detail_music': [{'Basement': ['ADRIANA LOPEZ', 'AKUA', 'KATIE REX']}, {'Studio': ['ROSE KOURTS', 'X3BUTTERFLY', 'KILOPATRAH JONES']}]}
# {'event_detail_date': datetime.datetime(2025, 1, 11, 22, 30), 'event_detail_title': 'JANUARY 11', 'event_detail_music': [{'Basement': ['ROBERT HOOD', 'KYRUH', 'ELLE DEE']}, {'Studio': ['ROI PEREZ', 'LYRIC HOOD', 'MAKADSI']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 21, 22, 30), 'event_detail_title': 'DECEMBER 21', 'event_detail_music': [{'Basement': ['D.DAN', 'QUELZA', 'CSILLA', 'COTTON']}, {'Studio': ['MASSIMILIANO PAGLIARA', 'JASON KENDIG', 'MASHA MAR']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 20, 22, 30), 'event_detail_title': 'DECEMBER 20', 'event_detail_music': [{'Basement': ['CHLÄR', 'RENE WISE', 'LYDO']}, {'Studio': ['GIDEÖN', 'THE CARRY NATION', 'HEIDI LAWDEN']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 14, 22, 30), 'event_detail_title': 'HERRENSAUNA', 'event_detail_music': [{'Basement': ['MCMLXXXV', 'CEM', 'ISABELLA KOEN B2B DJ RICHARD']}, {'Studio': ['OCTO OCTA', 'KETIA', 'STERLING JUAN DIAZ']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 13, 22, 30), 'event_detail_title': 'DECEMBER 13', 'event_detail_music': [{'Basement': ['MAMA SNAKE', 'JASSS', 'LYDO']}, {'Studio': ['ERIS DREW', 'NATUTA', 'X3BUTTERFLY']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 7, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['PAUL FLEETWOOD', 'RYAN SMITH']}, {'Studio': ['MEILGAARDEN', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2024, 12, 6, 22, 30), 'event_detail_title': 'MAMA TOLD YA', 'event_detail_music': [{'Basement': ['ANETHA', 'LACCHESI', 'MAC DECLOS']}, {'Studio': ['PEACHLYFE', 'ALISON SWING', 'ULTRATHEM']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 23, 22, 30), 'event_detail_title': 'MUTUAL RYTM NIGHT', 'event_detail_music': [{'Basement': ['SHDW', 'RUIZ OSC1', 'SELECTIVE RESPONSE']}, {'Studio': ['KEVIN AVIANCE', 'JADALAREIGN', 'JASON KENDIG']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 22, 22, 30), 'event_detail_title': 'NOVEMBER 22', 'event_detail_music': [{'Basement': ['FUNCTION', 'AKUA', 'ALEX.COSMOS']}, {'Studio': ['HERCULES & LOVE AFFAIR (DJ SET)', 'MAKADSI', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 16, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['DJ HOCKEY', 'ANTENES', 'RON LIKE HELL']}, {'Studio': ['DORISBURG', 'WONJA', 'SUCCUBASS']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 15, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['TAKAAKI ITOH', 'ÆON', 'AUSPEX']}, {'Studio': ['DJ HOLOGRAPHIC', 'PARTOK', 'MEZ']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 9, 22, 30), 'event_detail_title': 'PORNCEPTUAL', 'event_detail_music': [{'Basement': ['NØRBAK', 'AMANDA MUSSI', 'ELLE DEE']}, {'Studio': ['RACHEL NOON', 'DEE DIGGS', 'MANU MIRAN']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 8, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['FRANÇOIS X', 'SUPERGLOSS', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['LONGITUDE (BOUFFANT BOUFFANT B2B JACOB MEEHAN)', 'SHAUN J. WRIGHT', 'DJ MISS PARKER']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 2, 22, 30), 'event_detail_title': 'November 2', 'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE', 'AMORAL', 'MOS']}, {'Studio': ['FKA.M4A', 'TOM PETERS', 'SEKUCCI']}]}
# {'event_detail_date': datetime.datetime(2024, 11, 1, 22, 30), 'event_detail_title': 'rural', 'event_detail_music': [{'Basement': ['WATA IGARASHI', 'ATSUSHI MAEDA', 'AMELIA HOLT']}, {'Studio': ['INTERSTELLAR FUNK', 'NAO', 'DJ HEALTHY']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 26, 22, 30), 'event_detail_title': 'BOUND BLACKOUT', 'event_detail_music': [{'Basement': ['LOLSNAKE', 'X TIN', 'KATIE REX']}, {'Studio': ['NITA AVIANCE', 'DJ VOICES', 'DONOFRIO']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 25, 22, 30), 'event_detail_title': 'OCTOBER 25', 'event_detail_music': [{'Basement': ['JULIANA HUXTABLE', 'X CLUB.', 'ANNIE LEW']}, {'Studio': ['PABLO BOZZI', 'TT', 'IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 19, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['JOTON', 'RON LIKE HELL']}, {'Studio': ['GAY MARVINE', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 18, 22, 30), 'event_detail_title': 'OCTOBER 18', 'event_detail_music': [{'Basement': ['RANDOMER', 'BAUGRUPPE90', 'KXAH']}, {'Studio': ['MOMA READY', 'KIM ANH', 'MUTUALISM']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 12, 22, 30), 'event_detail_title': 'OCTOBER 12', 'event_detail_music': [{'Basement': ['LUKE SLATER', 'NDRX', '98DOTS']}, {'Studio': ['CLARISA KIMSKII', 'ANALOG SOUL', 'LORANT']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 11, 22, 30), 'event_detail_title': 'MORD NIGHT', 'event_detail_music': [{'Basement': ['BAS MOOY', 'ADRIANA LOPEZ', 'UFO95', 'AÖCRAM']}, {'Studio': ['PHYSICAL THERAPY', 'MIKE SERVITO', 'SISTER ZO']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 5, 22, 30), 'event_detail_title': 'BCCO', 'event_detail_music': [{'Basement': ['DJ HYPERDRIVE', 'PHIL BERG', 'CSILLA']}, {'Studio': ['MCR-T', 'CRYME', 'MEILGAARDEN']}]}
# {'event_detail_date': datetime.datetime(2024, 10, 4, 22, 30), 'event_detail_title': 'OCTOBER 4', 'event_detail_music': [{'Basement': ['DJ STINGRAY 313', 'BOSTON 168', 'ELLE DEE']}, {'Studio': ['DJ SALIVA', 'SEKUCCI', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 28, 22, 30), 'event_detail_title': 'SEPTEMBER 28', 'event_detail_music': [{'Basement': ['QUELZA', 'NEWA']}, {'Studio': ['FREDDY K', 'MARIE MONTEXIER', 'AMELIA HOLT']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 27, 22, 30), 'event_detail_title': 'SEPTEMBER 27', 'event_detail_music': [{'Basement': ['KI/KI', 'SALOME', 'MORENXXX']}, {'Studio': ['SCHACKE', 'JEK', 'CONNOR WRONG']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 21, 22, 30), 'event_detail_title': 'SEPTEMBER 21', 'event_detail_music': [{'Basement': ['DANIEL AVERY', 'BLANKA', 'DAIYAH']}, {'Studio': ['PEREL', 'LAUREL HALO', 'MASHA MAR']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 20, 22, 30), 'event_detail_title': 'MALA JUNTA', 'event_detail_music': [{'Basement': ['D.DAN', 'MAMA SNAKE', 'HOLDEN FEDERICO']}, {'Studio': ['RYKER']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 14, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['DAY THIEF', 'RON LIKE HELL']}, {'Studio': ['PEACH', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 13, 22, 30), 'event_detail_title': 'SEPTEMBER 13', 'event_detail_music': [{'Basement': ['DVS1', 'BEATRICE']}, {'Studio': ['JOB JOBSE', 'MEILGAARDEN', 'IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 7, 22, 30), 'event_detail_title': 'SEPTEMBER 7', 'event_detail_music': [{'Basement': ['FREDDY K', 'ALARICO LIVE', 'KAISER', 'LYDO']}, {'Studio': ['ROZA TERENZI', 'CALL SUPER', 'MATAS']}]}
# {'event_detail_date': datetime.datetime(2024, 9, 6, 22, 30), 'event_detail_title': 'SEPTEMBER 6', 'event_detail_music': [{'Basement': ['PERC', 'CEM', 'COTTON']}, {'Studio': ['DJ MINX', 'BYRON YEATES', 'ELISSA SUCKDOG']}]}
# {'event_detail_date': datetime.datetime(2024, 8, 31, 22, 30), 'event_detail_title': 'AUGUST 31', 'event_detail_music': [{'Basement': ['ROMAN FLÜGEL LIVE', 'ALARICO', 'ÆON']}, {'Studio': ['ROI PEREZ', 'NATUTA', 'MARKUS']}]}
# {'event_detail_date': datetime.datetime(2024, 8, 24, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['NASTIA REIGEL', 'JAMAICA SUK', 'AUSPEX']}, {'Studio': ['CHRIS CRUSE', 'EVAN TAIL', 'KIA']}]}
# {'event_detail_date': datetime.datetime(2024, 8, 17, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['REGAL', 'ANNIE LEW', 'WORD OF COMMAND B2B DJ CLONE']}, {'Studio': ['MCMLXXXV', 'KETIA', 'JOSELO']}]}
# {'event_detail_date': datetime.datetime(2024, 8, 10, 22, 30), 'event_detail_title': 'AUGUST 10', 'event_detail_music': [{'Basement': ['ANCIENT METHODS B2B PHASE FATALE', 'JUANA B2B NE/RE/A']}, {'Studio': ['JADALAREIGN', 'JORKES', 'COSMO']}]}
# {'event_detail_date': datetime.datetime(2024, 8, 3, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['LEEON', 'RYAN SMITH']}, {'Studio': ['WHODAT', 'SCOTIA', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 27, 22, 30), 'event_detail_title': 'July 27', 'event_detail_music': [{'Basement': ['Ø [PHASE]', 'HARUKA', 'COTTON']}, {'Studio': ['SEDEF ADASÏ', 'SUCCUBASS', 'MATAS']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 26, 22, 30), 'event_detail_title': 'July 26', 'event_detail_music': [{'Basement': ['RØDHAD', 'HOLDEN FEDERICO']}, {'Studio': ['PAURRO', 'ANALOG SOUL', 'SISTER ZO']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 20, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'RON LIKE HELL']}, {'Studio': ['BUDINO', 'LIAD KRISPIN', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 19, 22, 30), 'event_detail_title': 'July 19', 'event_detail_music': [{'Basement': ['LUKE SLATER', 'MAX WATTS', 'ERIC UMBLE']}, {'Studio': ['MIKE SERVITO', 'SHAUN J. WRIGHT', 'DEEP CREEP']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 13, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['UVB', 'MAREENA', 'AUSPEX']}, {'Studio': ['BÉZIER', 'DEVOYE', 'WHODAT']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 12, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['MIKE DEARBORN', 'FALSEBOI', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['OSSX', 'ROSE KOURTS', 'JUSTIN CUDMORE']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 6, 22, 30), 'event_detail_title': 'July 6', 'event_detail_music': [{'Basement': ['FUNCTION', 'NØRBAK', 'UMFANG']}, {'Studio': ['PROSUMER', 'JASON KENDIG', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2024, 7, 5, 22, 30), 'event_detail_title': 'CLOSED: JULY 5', 'event_detail_music': []}
# {'event_detail_date': datetime.datetime(2024, 6, 29, 22, 30), 'event_detail_title': 'BOUND PRIDE', 'event_detail_music': [{'Basement': ['VOLVOX FEATURING DOMI', 'KATIE REX', 'VILE']}, {'Studio': ['HARUKA', 'LINDO (JOTA B2B VICENTA)', 'RYAN FARR']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 28, 22, 30), 'event_detail_title': 'JUNE 28', 'event_detail_music': [{'Basement': ['SCHACKE', 'ANNIE LEW B2B MOS', 'MORENXXX']}, {'Studio': ['MASSIMILIANO PAGLIARA', 'DJ HOLOGRAPHIC', 'JEFFREY SFIRE']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 22, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['Anthony Parasole', 'AMX', 'Justin Cudmore']}, {'Studio': ['Jennifer Cardini', 'David Elimelech', 'Manu Miran']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 21, 22, 30), 'event_detail_title': 'JUNE 21', 'event_detail_music': [{'Basement': ['Yonti', 'Elle Dee', 'Concrete Husband']}, {'Studio': ['The Carry Nation', 'Partok', 'Donis']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 15, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['Fiedel', 'Vel', 'Word of Command', 'DJ Clone']}, {'Studio': ['Matrixxman', 'Sekucci b2b Sterling Juan Diaz', 'Natuta']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 14, 22, 30), 'event_detail_title': 'JUNE 14', 'event_detail_music': [{'Basement': ['Schwefelgelb', 'Chloe Lula', 'Ana B']}, {'Studio': ['Dee Diggs', 'Analog Soul', 'Eli Escobar']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 8, 22, 30), 'event_detail_title': 'X-TRA.SERVICES', 'event_detail_music': [{'Basement': ['Barker', 'Terence Fixmer', 'LYDO']}, {'Studio': ['ADAB', 'Kfeelz', 'Antojito']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 7, 22, 30), 'event_detail_title': 'JUNE 7', 'event_detail_music': [{'Basement': ['Truncate', 'Tapefeed', 'ROLA']}, {'Studio': ['DJ Pierre', 'Justin Cudmore', 'Boys’ Shorts']}]}
# {'event_detail_date': datetime.datetime(2024, 6, 1, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['Shaun J. Wright', 'Ron Like Hell', 'Ryan Smith']}, {'Studio': ['Baronhawk Poitier', 'Ron Like Hell']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 31, 22, 30), 'event_detail_title': 'MAY 31', 'event_detail_music': [{'Basement': ['DJ STINGRAY 313', 'JULIANA HUXTABLE', 'ALEX.COSMOS']}, {'Studio': ['CINTHIE', 'CHRIS CRUSE', 'JACOB MEEHAN']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 25, 22, 30), 'event_detail_title': 'SPANDAU20 NIGHT', 'event_detail_music': [{'Basement': ['FJAAK LIVE', 'ELLI ACULA', 'ANNA Z. B2B J.MANUEL']}, {'Studio': ['KEVIN AVIANCE', 'X3BUTTERFLY', 'IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 24, 22, 30), 'event_detail_title': 'MAY 24', 'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RYKER']}, {'Studio': ['JASON KENDIG', 'SEKUCCI', 'GEE DEE']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 18, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['MARY YUZOVSKAYA', 'NE/RE/A', 'RYAN SMITH']}, {'Studio': ['TAMA SUMO B2B LAKUTI', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 17, 22, 30), 'event_detail_title': 'BOUND Blackout', 'event_detail_music': [{'Basement': ['Katie Rex b2b KYRUH', 'Andi b2b Arvin T', 'Pure Immanence']}, {'Studio': ['Jimmy Edgar', 'Jubilee', 'Choque']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 11, 22, 30), 'event_detail_title': 'MAY 11', 'event_detail_music': [{'Basement': ['DJ BONE', 'DEVOYE', 'ELLE DEE']}, {'Studio': ['MARCELLUS PITTMAN', 'MIKE SERVITO', 'LAUREN FLAX']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 10, 22, 30), 'event_detail_title': 'RECLAIM YOUR CITY', 'event_detail_music': [{'Basement': ['STERAC', 'KR!Z', 'LYCHEE']}, {'Studio': ['RICK WADE', 'HARUKA', 'COSMO']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 4, 22, 30), 'event_detail_title': 'BASEMENT 5 Year Anniversary', 'event_detail_music': [{'Basement': ['BEN KLOCK', 'NEWA', 'ÆON', 'COTTON']}, {'Studio': ['LYDO', 'JEK B2B MATAS', 'MEILGAARDEN B2B IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2024, 5, 3, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['MARCEL FENGLER', 'AMOTIK', 'AUSPEX']}, {'Studio': ['VICKI POWELL', 'WILL AUTOMAGIC', 'KIM ANH']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 27, 22, 30), 'event_detail_title': 'BASSIANI NIGHT', 'event_detail_music': [{'Basement': ['FADI MOHEM', 'KANCHELI B2B PHILIPPA PACHO', 'NDRX']}, {'Studio': ['KIM ANN FOXMAN', 'MATAS', 'SEKUCCI']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 26, 22, 30), 'event_detail_title': 'BOUND BLACKOUT', 'event_detail_music': [{'Basement': ['PARRISH SMITH', 'SAUSHA', 'KATIE REX']}, {'Studio': ['MAKADSI', 'DJ MISS PARKER', 'FLIRTY800']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 20, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['WRECKED ALL NIGHT LONG (RON LIKE HELL & RYAN SMITH)']}, {'Studio': ['LEONCE', 'KEENAN ORR', 'KILOPATRAH JONES']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 19, 22, 30), 'event_detail_title': 'April 19', 'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST', 'CONCRETE HUSBAND', 'KXAH']}, {'Studio': ['ANALOG SOUL', 'MOMA READY', 'TORIBIO']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 13, 22, 30), 'event_detail_title': 'April 13', 'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE', 'CHLÄR', 'IAN CRANE']}, {'Studio': ['SANDRIEN', 'JASON KENDIG', 'PERFECT LOVERS']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 12, 22, 30), 'event_detail_title': 'April 12', 'event_detail_music': [{'Basement': ['FUNCTION', 'HADONE', 'ANNIE LEW']}, {'Studio': ['COMO SE DJ', 'RYKER', 'OZA']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 6, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['LINDSEY HERBERT', 'NONCOMPLIANT', 'JUSTIN CUDMORE']}, {'Studio': ['ETAPP KYLE', 'THE CARRY NATION', 'COSMO']}]}
# {'event_detail_date': datetime.datetime(2024, 4, 5, 22, 30), 'event_detail_title': 'HERRENSAUNA', 'event_detail_music': [{'Basement': ['MCMLXXXV', 'SALOME', 'FASHION']}, {'Studio': ['CEM', 'DJ SALIVA', 'X3BUTTERFLY']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 30, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['NØRBAK', 'ESTHER DUNE', 'AUSPEX']}, {'Studio': ['CLARISA KIMSKII', 'COLORED CRAIG', 'MIKE SERVITO']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 29, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['BJARKI', 'ELLE DEE', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['YHA YHA', 'MOMA READY', 'MASHA MAR']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 23, 22, 30), 'event_detail_title': 'PORNCEPTUAL', 'event_detail_music': [{'Basement': ['JAMAICA SUK', 'VOLVOX', 'LYDO']}, {'Studio': ['ARIEL ZETINA', 'BOUFFANT BOUFFANT', 'CURSES']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 22, 22, 30), 'event_detail_title': 'March 22', 'event_detail_music': [{'Basement': ['DRUMCELL', 'KANGDING RAY', 'ÆON']}, {'Studio': ['THE CARRY NATION', 'IAN CRANE', 'NSPERGER']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 16, 22, 30), 'event_detail_title': '13 YEARS OF WRECKED', 'event_detail_music': [{'Basement': ['PARTOK', 'WRECKED']}, {'Studio': ['\u200b\u200bT.WAN', 'WRECKED']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 15, 22, 30), 'event_detail_title': 'March 15', 'event_detail_music': [{'Basement': ['FRANÇOIS X', 'UFO95 LIVE', 'SEVYN 0000']}, {'Studio': ['JEK B2B MATAS', 'ADOBEPRINCESS']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 9, 22, 30), 'event_detail_title': 'March 9', 'event_detail_music': [{'Basement': ['KI/KI', 'COMO SE DJ']}, {'Studio': ['ROI PEREZ ALL NIGHT LONG']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 8, 22, 30), 'event_detail_title': 'March 8', 'event_detail_music': [{'Basement': ['ELLI ACULA', 'VOLVOX', 'MOS']}, {'Studio': ['KEVIN AVIANCE', 'MUTUALISM B2B SPRKLBB', 'FATHERHOOD']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 2, 22, 30), 'event_detail_title': 'March 2', 'event_detail_music': [{'Basement': ['REGAL', 'BAUGRUPPE90', 'ANNIE LEW']}, {'Studio': ['MCR-T', 'X-COAST', 'STERLING JUAN DIAZ']}]}
# {'event_detail_date': datetime.datetime(2024, 3, 1, 22, 30), 'event_detail_title': 'March 1', 'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN', 'CHLOE LULA', 'ARVIN T']}, {'Studio': ['10 YEARS TIME PASSAGES: BINH', 'EVAN BAGGS']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 24, 22, 30), 'event_detail_title': 'DWELLER', 'event_detail_music': [{'Basement': ['ROBERT HOOD', 'DEVOYE', 'DAIYAH']}, {'Studio': ['SHAUN J WRIGHT', 'MISS TWINK USA', 'KILOPATRAH JONES']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 23, 22, 30), 'event_detail_title': 'BOUND 7 YEAR ANNIVERSARY', 'event_detail_music': [{'Basement': ['CLOUDS', 'SHYBOI', 'KATIE REX']}, {'Studio': ['JACQ JILL', 'KIA', 'AL V DAM']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 17, 22, 30), 'event_detail_title': 'BasementFREDDY K OPEN TO CLOSE', 'event_detail_music': [{'Basement': ['FREDDY K OPEN TO CLOSE']}, {'Studio': ['THE CARRY NATION', 'JACOB MEEHAN', 'MAKADSI']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 16, 22, 30), 'event_detail_title': 'BasementHARUKACLARISA KIMSKIISPLOOFI B2B NICOLO BERNARDI', 'event_detail_music': [{'Basement': ['HARUKA', 'CLARISA KIMSKII', 'SPLOOFI B2B NICOLO BERNARDI']}, {'Studio': ['ELI ESCOBAR', 'NOMI RUIZ', 'JOSH STEERS']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 10, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['AARON CLARK', 'ARIEL ZETINA', 'LYCHEE', 'RON LIKE HELL', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 9, 22, 30), 'event_detail_title': 'FAST FORWARD NIGHT', 'event_detail_music': [{'Basement': ['SUGAR', 'NEWA', 'RYKER']}, {'Studio': ['SCHACKE', 'X3BUTTERFLY', 'JEK']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 3, 22, 30), 'event_detail_title': 'BasementHENNING BAERESTELLA BOERSMACONCRETE HUSBAND', 'event_detail_music': [{'Basement': ['HENNING BAER', 'ESTELLA BOERSMA', 'CONCRETE HUSBAND']}, {'Studio': ['DJ MINX', 'GABRIELLE KWARTENG', 'SEKUCCI']}]}
# {'event_detail_date': datetime.datetime(2024, 2, 2, 22, 30), 'event_detail_title': 'BasementANCIENT METHODSORPHXMUERTE LENTA', 'event_detail_music': [{'Basement': ['ANCIENT METHODS', 'ORPHX', 'MUERTE LENTA']}, {'Studio': ['ANALOG SOUL', 'ROSE KOURTS', 'RELAXER']}]}
# {'event_detail_date': datetime.datetime(2024, 1, 27, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['TRUNCATE / AMANDA MUSSI / WORD OF COMMAND / DJ CLONE']}, {'Studio': ['BORED LORD / KILOPATRAH JONES / ANTOJITO']}]}
# {'event_detail_date': datetime.datetime(2024, 1, 20, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['KYRUH', 'RON LIKE HELL']}, {'Studio': ['SOLAR & MOZHGAN', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2024, 1, 13, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE', 'HIROKO YAMAMURA', 'JUSTIN CUDMORE']}, {'Studio': ['PARTOK', 'CROMBY', 'LAUREN FLAX']}]}
# {'event_detail_date': datetime.datetime(2023, 12, 16, 22, 30), 'event_detail_title': 'BasementOSCAR MULEROBEATRICELYDO', 'event_detail_music': [{'Basement': ['OSCAR MULERO', 'BEATRICE', 'LYDO']}, {'Studio': ['NEWA', 'JASON KENDIG', 'IAN CRANE']}]}
# {'event_detail_date': datetime.datetime(2023, 12, 15, 22, 30), 'event_detail_title': 'BasementPERCJULIANA HUXTABLEWORLD OF COMMAND', 'event_detail_music': [{'Basement': ['PERC', 'JULIANA HUXTABLE', 'WORLD OF COMMAND']}, {'Studio': ['KEVIN AVIANCE', 'NATUTA', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2023, 12, 2, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['JUANA', 'RYAN SMITH']}, {'Studio': ['WNGDU', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2023, 12, 1, 22, 30), 'event_detail_title': 'BasementSLAMFLAVIA LAUSERIC UMBLE', 'event_detail_music': [{'Basement': ['SLAM', 'FLAVIA LAUS', 'ERIC UMBLE']}, {'Studio': ['MASSIMILIANO PAGLIARA', 'DAVID ELIMELECH', 'KIM ANH']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 18, 22, 30), 'event_detail_title': 'BasementANSWER CODE REQUESTPHILIPPA PACHOMARCO NEVES', 'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST', 'PHILIPPA PACHO', 'MARCO NEVES']}, {'Studio': ['GABRIELLA KWARTENG', 'THE CARRY NATION', 'KIA']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 17, 22, 30), 'event_detail_title': '', 'event_detail_music': [{'Basement': ['FUNCTION', 'RANDOMER', 'ÆON']}, {'Studio': ['DJ HOLOGRAPHIC', 'GIDEÖN', 'JACOB MEEHAN']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 11, 22, 30), 'event_detail_title': 'BITE NITE', 'event_detail_music': [{'Basement': ['ANCIENT METHODS', 'PHASE FATALE', 'VULKANSKI']}, {'Studio': ['PABLO BOZZI', 'SUCCUBASS', 'NE/RE/A']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 10, 22, 30), 'event_detail_title': '', 'event_detail_music': [{'Basement': ['WATA IGARASHI', 'VOLVOX', 'PAULA KOSKI']}, {'Studio': ['DAN SHAKE', 'JASON KENDIG', 'X3BUTTERFLY']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 4, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['WTCHCRFT', 'RON LIKE HELL']}, {'Studio': ['FATHER DUKES', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2023, 11, 3, 22, 30), 'event_detail_title': 'Herrensauna', 'event_detail_music': [{'Basement': ['MCMLXXXV', 'FUTURE.666', 'SEVYN 0000']}, {'Studio': ['CEM', 'OR:LA', 'DJ SALIVA']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 28, 22, 30), 'event_detail_title': 'Oct 28 BOUND', 'event_detail_music': [{'Basement': ['Nur Jaber', 'Katie Rex', 'Annie Lew']}, {'Studio': ['X Club.', 'Jek', 'Kilopatrah Jones']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 27, 18, 0), 'event_detail_title': 'BasementKangding RayClarisa Kimskii b2b Ne/Re/A /Connor Wrong', 'event_detail_music': [{'Basement': ['Kangding Ray', 'Clarisa Kimskii b2b Ne/Re/A /', 'Connor Wrong']}, {'Studio': ['Tama Sumo b2b Lakuti', 'Mike Servito', 'Choque']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30), 'event_detail_title': 'BasementDANIEL AVERYFADI MOHEMSPLOOFI', 'event_detail_music': [{'Basement': ['DANIEL AVERY', 'FADI MOHEM', 'SPLOOFI']}, {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30), 'event_detail_title': 'BasementDANIEL AVERYFADI MOHEMSPLOOFI', 'event_detail_music': [{'Basement': ['DANIEL AVERY', 'FADI MOHEM', 'SPLOOFI']}, {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 14, 22, 30), 'event_detail_title': 'BasementRØDHÅDNDRXLYDO', 'event_detail_music': [{'Basement': ['RØDHÅD', 'NDRX', 'LYDO']}, {'Studio': ['MATAS', 'COMO SE DJ', 'MEILGAARDEN']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 13, 0, 0), 'event_detail_title': 'BasementREBEKAHSOMEWHENLISAS', 'event_detail_music': [{'Basement': ['REBEKAH', 'SOMEWHEN', 'LISAS']}, {'Studio': ['KETIA', 'MANU MIRAN', 'JOSELO']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 7, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['NONCOMPLIANT', 'MATRIXXMAN', 'RYAN SMITH']}, {'Studio': ['KHIDJA', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2023, 10, 6, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['LEWIS FAUTZI', 'LAURA BCR', 'COTTON', 'AUSPEX']}, {'Studio': ['NITA AVIANCE B2B MIKE SERVITO', 'MICHAEL MAGNAN', 'ALISSA BRIANNA']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 30, 22, 30), 'event_detail_title': 'MALA JUNTA', 'event_detail_music': [{'Basement': ['D.DAN', 'ELLE DEE']}, {'Studio': ['HYPERAKTIVIST', 'YAZZUS', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 29, 22, 30), 'event_detail_title': 'BasementCHLOE LULABRYAN KASENICYOUNG MALE', 'event_detail_music': [{'Basement': ['CHLOE LULA', 'BRYAN KASENIC', 'YOUNG MALE']}, {'Studio': ['HAAI', 'STERLING JUAN DIAZ', 'SISTER ZO']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 23, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['LEESH', 'RON LIKE HELL']}, {'Studio': ['BÉZIER', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 22, 22, 30), 'event_detail_title': '', 'event_detail_music': [{'Basement': ['TALISMANN', 'KYRUH', 'CONCRETE HUSBAND']}, {'Studio': ['SALOME', 'MATAS', 'RYKER']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 16, 22, 30), 'event_detail_title': 'MORD 10 YEARS', 'event_detail_music': [{'Basement': ['BAS MOOY', 'QUELZA', 'ANTENES']}, {'Studio': ['ELI ESCOBAR', 'LOVE LETTERS', 'COSMO']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 15, 22, 0), 'event_detail_title': 'BasementMAMA SNAKEKANCHELIALEX.COSMOS', 'event_detail_music': [{'Basement': ['MAMA SNAKE', 'KANCHELI', 'ALEX.COSMOS']}, {'Studio': ['ISABELLA', 'CHRIS CRUSE', 'HARUKA']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 9, 22, 30), 'event_detail_title': 'BasementNASTIALOBSTERHOLDEN FEDERICO', 'event_detail_music': [{'Basement': ['NASTIA', 'LOBSTER', 'HOLDEN FEDERICO']}, {'Studio': ['ASH LAURYN', 'MOMA READY', 'ARIEL ME LLAMO']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 8, 22, 30), 'event_detail_title': 'BasementSCHACKEEGOTOTÆON', 'event_detail_music': [{'Basement': ['SCHACKE', 'EGOTOT', 'ÆON']}, {'Studio': ['DJ SALIVA', 'ADOBEPRINCESS', 'COMO SE DJ']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 2, 22, 30), 'event_detail_title': 'PORNCEPTUAL', 'event_detail_music': [{'Basement': ['FLAVIA LAUS', 'DEEPNEUE', 'KATIE REX']}, {'Studio': ['THE CARRY NATION', 'JEFFREY SFIRE', 'X3BUTTERFLY']}]}
# {'event_detail_date': datetime.datetime(2023, 9, 1, 22, 30), 'event_detail_title': 'BasementEFDEMINSETAOC MASSSPLOOFI B2B NICOLÒ BERNARDI', 'event_detail_music': [{'Basement': ['EFDEMIN', 'SETAOC MASS', 'SPLOOFI B2B NICOLÒ BERNARDI']}, {'Studio': ['KEVIN AVIANCE', 'JASON KENDIG', 'KIM ANH']}]}
# {'event_detail_date': datetime.datetime(2023, 8, 26, 22, 30), 'event_detail_title': '', 'event_detail_music': [{'Basement': ['.VRIL LIVE', 'YONTI', 'ELLE DEE']}, {'Studio': ['ROI PEREZ / GIDEÖN / MEILGAARDEN']}]}
# {'event_detail_date': datetime.datetime(2023, 8, 19, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['DINA', 'MORENXXX', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['PANGAEA', 'HONEY BUN', 'FLIRTY800']}]}
# {'event_detail_date': datetime.datetime(2023, 8, 12, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['DUSTIN ZAHN', 'LENNART WIEHE', 'JUSTIN CUDMORE']}, {'Studio': ['BEIGE', 'SPRKLBB']}]}
# {'event_detail_date': datetime.datetime(2023, 8, 5, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['ERIKA', 'RON LIKE HELL']}, {'Studio': ['DAVIS GALVIN', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 29, 22, 30), 'event_detail_title': 'X-TRA.SERVICES', 'event_detail_music': [{'Basement': ['JAMES RUSKIN', 'DEVOYE', 'TOMÁS URQUIETA']}, {'Studio': ['SEKUCCI', 'MISS PARKER', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 28, 22, 0), 'event_detail_title': 'BasementFUNCTIONAMOTIKELLE DEE', 'event_detail_music': [{'Basement': ['FUNCTION', 'AMOTIK', 'ELLE DEE']}, {'Studio': ['MUTUALISM', 'RELAXER']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 22, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['KANGDING RAY', 'MARY YUZOVSKAYA', 'AUSPEX']}, {'Studio': ['JADALAREIGN', 'STERLING JUAN DIAZ', 'DAY THIEF']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 21, 22, 30), 'event_detail_title': 'BasementCLARISA KIMSKIIUMFANGYOUNG MALE', 'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'UMFANG', 'YOUNG MALE']}, {'Studio': ['MIKE SERVITO', 'DEE DIGGS']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 15, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['CLARK PRICE', 'RYAN SMITH']}, {'Studio': ['MEZ', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 14, 22, 30), 'event_detail_title': 'BasementDJ BONEANALOG SOULROSE KOURTS', 'event_detail_music': [{'Basement': ['DJ BONE', 'ANALOG SOUL', 'ROSE KOURTS']}, {'Studio': ['PEREL', 'FATHERHOOD']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 8, 22, 30), 'event_detail_title': 'BasementHENNING BAERRON LIKE HELLLYCHEE', 'event_detail_music': [{'Basement': ['HENNING BAER', 'RON LIKE HELL', 'LYCHEE']}, {'Studio': ['ELI ESCOBAR', 'KIM ANH', 'NATUTA']}]}
# {'event_detail_date': datetime.datetime(2023, 7, 7, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['QUEST?ONMARQ', '1MORNING', 'MUERTE LENTA', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['MISS TWINK USA', 'JEK', 'DEEP CREEP']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 30, 22, 30), 'event_detail_title': 'June 30', 'event_detail_music': [{'Basement': ['HEADLESS HORSEMAN', 'MADNESS OF', 'L.SANGRE']}, {'Studio': ['GERD JANSON', 'MAKADSI', 'MATAS']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 24, 22, 30), 'event_detail_title': 'BOUND PRIDE', 'event_detail_music': [{'Basement': ['FIEDEL', 'FASHION', 'KATIE REX']}, {'Studio': ['ULTRATHEM', 'WINTER WRONG', 'SISTER ZO', 'CHOQUE']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 23, 22, 30), 'event_detail_title': 'BasementLYDOKYRUHDAIYAHCONCRETE HUSBAND', 'event_detail_music': [{'Basement': ['LYDO', 'KYRUH', 'DAIYAH', 'CONCRETE HUSBAND']}, {'Studio': ['MASSIMILIANO PAGLIARA', 'TAMA SUMO B2B LAKUTI', 'X3BUTTERFLY']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 17, 22, 30), 'event_detail_title': 'BasementSCHACKENDRXELLE DEE', 'event_detail_music': [{'Basement': ['SCHACKE', 'NDRX', 'ELLE DEE']}, {'Studio': ['THE SPECTRUM:  NDRX', 'LAUREN FLAX', 'MANU MIRAN']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 16, 22, 30), 'event_detail_title': 'FIST 7 YEAR ANNIVERSARY', 'event_detail_music': [{'Basement': ['SLAM', 'ISABELLA KOEN', 'COTTON', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['BAUGRUPPE90', 'SEVYN 0000', 'SEKUCCI']}]}
# {'event_detail_date': datetime.datetime(2023, 6, 10, 22, 30), 'event_detail_title': 'BasementDASHA RUSHTAPEFEEDJAY YORK', 'event_detail_music': [{'Basement': ['DASHA RUSH', 'TAPEFEED', 'JAY YORK']}, {'Studio': ['FOR FUTURES SAKE', 'DJ RAQX', 'DX7']}]}

# %%
events[214]
# Out:
# '/events/a3b33be9-aeba-438a-a74d-3e3b37d39a4c'

# %%
for x in events[214:]:
    url = "https://basementny.net" + x
    event_data = asyncio.run(get_event_detail(url))
    # print(url)
    print(event_data)
    event_data_list.append(event_data)
# Out:
# {'event_detail_date': datetime.datetime(2022, 9, 16, 22, 30), 'event_detail_title': 'September 16', 'event_detail_music': [{'Basement': ['WATA IGARASHI', 'ALEJANDRO FRANCO', 'ANTENES']}, {'Studio': ['THE CARRY NATION', 'DEE DIGGS', 'KILOPATRAH JONES']}]}
# {'event_detail_date': datetime.datetime(2022, 9, 10, 0, 0), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['REGAL', 'MADWOMAN', 'AUSPEX']}, {'Studio': ['EFDEMIN', 'LAUREN FLAX']}]}
# {'event_detail_date': datetime.datetime(2022, 9, 10, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['RANDOMER', 'PHILIPPA PACHO', 'WORD OF COMMAND', 'DJ CLONE']}, {'Studio': ['KIM ANN FOXMAN', 'ONIO', 'ULTRATHEM']}]}
# {'event_detail_date': datetime.datetime(2022, 9, 3, 0, 0), 'event_detail_title': 'FAST FORWARD NIGHT', 'event_detail_music': [{'Basement': ['SUGAR', 'EZY', 'TT']}, {'Studio': ['SCHACKE', 'PEACHLYFE']}]}
# {'event_detail_date': datetime.datetime(2022, 9, 2, 22, 0), 'event_detail_title': 'September 2', 'event_detail_music': [{'Basement': ['999999999', 'VOLVOX', 'MADNESS OF']}, {'Studio': ['MASSIMILIANO PAGLIARA', 'RYAN ELLIOTT', 'ROSE KOURTS']}]}
# {'event_detail_date': datetime.datetime(2022, 8, 27, 22, 30), 'event_detail_title': 'August 27', 'event_detail_music': [{'Basement': ['LUKE SLATER', 'BEATRICE', 'UMFANG']}]}
# {'event_detail_date': datetime.datetime(2022, 8, 20, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['NONCOMPLIANT', 'MIKE DEARBORN', 'JUSTIN CUDMORE B2B AUSPEX']}]}
# {'event_detail_date': datetime.datetime(2022, 8, 13, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['AKUA', 'ANA B', 'GABBERBITCH69 B2B LIMITBREAK!', 'WORD OF COMMAND B2B DJ CLONE']}]}
# {'event_detail_date': datetime.datetime(2022, 8, 6, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['SUCCUBASS', 'MIKE SERVITO', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 29, 0, 0), 'event_detail_title': 'L.I.E.S. NIGHT', 'event_detail_music': [{'Basement': ['RON MORELLI', 'SILENT SERVANT']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 23, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['ALPHA TRACKS', 'ESTOC', 'SAUSHA B2B SUNRISE HUNTER', 'WORD OF COMMAND B2B DJ CLONE']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 22, 22, 30), 'event_detail_title': 'July 22', 'event_detail_music': [{'Basement': ['TAPEFEED', 'VERONICA VASICKA', 'MOMENT OF TERROR']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 16, 22, 30), 'event_detail_title': 'WRECKED [DAY INTO NIGHT]', 'event_detail_music': [{'Basement': ['VICKI POWELL', 'MANU MIRAN', 'JUANA', 'DEE DIGGS', 'RYAN SMITH', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 15, 22, 30), 'event_detail_title': 'July 15', 'event_detail_music': [{'Basement': ['FREDDY K', 'PANGAEA', 'LYCHEE']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 9, 22, 30), 'event_detail_title': 'X-TRA.SERVICES', 'event_detail_music': [{'Basement': ['CTRLS', 'REN G', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 8, 22, 30), 'event_detail_title': 'July 8', 'event_detail_music': [{'Basement': ['REBEKAH', 'STARKK']}]}
# {'event_detail_date': datetime.datetime(2022, 7, 2, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['JAMES RUSKIN', 'VOLVOX B2B JUANA', 'JUSTIN CUDMORE B2B HIROKO YAMAMURA']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 30, 22, 30), 'event_detail_title': 'July 30', 'event_detail_music': [{'Basement': ['D.DAN', 'PEACHLYFE', 'TT']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 25, 22, 30), 'event_detail_title': 'BOUND BLACKOUT', 'event_detail_music': [{'Basement': ['SUGAR', 'TT', 'KATIE REX']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 24, 22, 30), 'event_detail_title': 'HERRENSAUNA', 'event_detail_music': [{'Basement': ['CEM', 'MCMLXXXV', 'ISABELLA KOEN']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 18, 22, 30), 'event_detail_title': 'June 18', 'event_detail_music': [{'Basement': ['FUNCTION', 'MAX WATTS', 'LYCHEE']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 17, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['FIEDEL', 'AKUA', 'AUSPEX']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 11, 22, 30), 'event_detail_title': 'June 11', 'event_detail_music': [{'Basement': ['REGIS', 'YOUNG MALE', 'L.SANGRE']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 10, 22, 30), 'event_detail_title': 'June 10', 'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST', 'SILENT SERVANT', 'JANUARY HUNT']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 4, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['BÉZIER', 'RON LIKE HELL', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2022, 6, 3, 22, 30), 'event_detail_title': 'June 3', 'event_detail_music': [{'Basement': ['PARTOK', 'MADISON MOORE', 'KIM ANN FOXMAN']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 28, 22, 30), 'event_detail_title': 'STAUB', 'event_detail_music': [{'Basement': ['OSCAR MULERO', 'IRAKLI', 'ANTENES']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 27, 22, 30), 'event_detail_title': 'May 27', 'event_detail_music': [{'Basement': ['VAGUE MÉCANIQUE LIVE', 'TERENCE FIXMER B2B PHASE FATALE', 'IREEN AMNES']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 21, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['ABAJOUR', 'RYAN SMITH', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 14, 22, 30), 'event_detail_title': 'May 14', 'event_detail_music': [{'Basement': ['TIN MAN', 'MIKE SERVITO B2B JUSTIN CUDMORE']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 13, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['KILBOURNE', 'AIDEN', 'S&M B2B BURNER ACCOUNT', 'DJ CLONE B2B WORD OF COMMAND']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 7, 22, 30), 'event_detail_title': 'BASEMENT ANNIVERSARY', 'event_detail_music': [{'Basement': ['JULIANA HUXTABLE', 'LYDO', 'TT', 'KYRUH']}]}
# {'event_detail_date': datetime.datetime(2022, 5, 6, 22, 30), 'event_detail_title': 'May 6', 'event_detail_music': [{'Basement': ['REGAL', 'VOLVOX', 'WTCHCRFT']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 30, 22, 30), 'event_detail_title': 'EXALT', 'event_detail_music': [{'Basement': ['MATRIXXMAN', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 29, 22, 30), 'event_detail_title': 'April 29', 'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN', 'THAM', 'DAIYAH']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 23, 22, 30), 'event_detail_title': 'BOUND BLACKOUT', 'event_detail_music': [{'Basement': ['LOKIER', 'KATIE REX', 'KYRUH']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 22, 22, 30), 'event_detail_title': 'aufnahme + wiedergabe', 'event_detail_music': [{'Basement': ['ANCIENT METHODS', 'PHILIPP STROBEL', 'NE', 'RE', 'A']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 16, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['RYAN SMITH', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 15, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['TRUNCATE', 'SHAUN J WRIGHT B2B MADISON MOORE', 'JUSTIN CUDMORE']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 9, 22, 30), 'event_detail_title': 'April 9', 'event_detail_music': [{'Basement': ['RROSE', 'KANGDING RAY', 'LYCHEE']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 8, 22, 30), 'event_detail_title': 'April 8', 'event_detail_music': [{'Basement': ['LYDO', 'WORD OF COMMAND', 'ANA B']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 2, 22, 30), 'event_detail_title': 'MORD NIGHT', 'event_detail_music': [{'Basement': ['BAS MOOY', 'ANSOME', 'YOUNG MALE']}]}
# {'event_detail_date': datetime.datetime(2022, 4, 1, 22, 30), 'event_detail_title': 'ALTÆR', 'event_detail_music': [{'Basement': ['SNTS', 'NUR JABER', 'AUSPEX']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 26, 22, 30), 'event_detail_title': 'March 26', 'event_detail_music': [{'Basement': ['REGIS', 'RON MORELLI', 'NE', 'RE', 'A']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 25, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['BLUE HOUR', 'TYGAPAW', 'MEMPHY', 'DJ CLONE', 'WORD OF COMMAND']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 19, 22, 30), 'event_detail_title': '11 YEARS OF WRECKED', 'event_detail_music': [{'Basement': ['BORIS', 'RYAN SMITH', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 18, 22, 30), 'event_detail_title': 'March 18', 'event_detail_music': [{'Basement': ['FUNCTION', 'ELLE DEE']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 12, 22, 30), 'event_detail_title': 'March 12', 'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RACHEL NOON', 'TT']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 11, 22, 30), 'event_detail_title': 'March 11', 'event_detail_music': [{'Basement': ['SARA LANDRY', 'XIORRO', 'YOUNG MALE']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 5, 22, 30), 'event_detail_title': 'March 5', 'event_detail_music': [{'Basement': ['DJ STINGRAY', 'KYRUH B2B WTCHCRFT']}]}
# {'event_detail_date': datetime.datetime(2022, 3, 4, 22, 30), 'event_detail_title': 'March 4', 'event_detail_music': [{'Basement': ['BEN KLOCK', 'UMFANG']}]}
# {'event_detail_date': datetime.datetime(2022, 2, 26, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['LIVWUTANG', 'RYAN SMITH', 'RON LIKE HELL']}]}
# {'event_detail_date': datetime.datetime(2022, 2, 19, 22, 30), 'event_detail_title': 'FIST', 'event_detail_music': [{'Basement': ['SHLØMO', 'ARIEL ZETINA', 'JANUARY HUNT', 'WORD OF COMMAND', 'DJ CLONE']}]}
# {'event_detail_date': datetime.datetime(2022, 2, 12, 22, 30), 'event_detail_title': 'X-TRA.SERVICES', 'event_detail_music': [{'Basement': ['PEACHLYFE', 'MORENXXX', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2022, 2, 5, 22, 30), 'event_detail_title': 'BALANCE', 'event_detail_music': [{'Basement': ['JULIANA HUXTABLE', 'VINCENT NEUMANN  JUSTIN CUDMORE']}]}
# {'event_detail_date': datetime.datetime(2022, 1, 29, 22, 30), 'event_detail_title': 'January 29', 'event_detail_music': [{'Basement': ['ANETHA', 'SOMEWHEN', 'TT']}]}
# {'event_detail_date': datetime.datetime(2022, 1, 22, 22, 30), 'event_detail_title': 'January 22', 'event_detail_music': [{'Basement': ['ANCIENT METHODS', 'FIEDEL', 'DAIYAH']}]}
# {'event_detail_date': datetime.datetime(2022, 1, 15, 22, 30), 'event_detail_title': 'POSSESSION', 'event_detail_music': [{'Basement': ['PARFAIT', 'D.DAN', 'LYDO']}]}
# {'event_detail_date': datetime.datetime(2022, 1, 7, 22, 30), 'event_detail_title': 'January 7', 'event_detail_music': [{'Basement': ['I HATE MODELS', 'NDRX', 'KYRUH']}]}
# {'event_detail_date': datetime.datetime(2021, 12, 18, 22, 30), 'event_detail_title': 'WRECKED', 'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']}]}
# {'event_detail_date': datetime.datetime(2021, 12, 11, 22, 30), 'event_detail_title': 'BOUND BLACKOUT', 'event_detail_music': [{'Basement': ['ETAPP KYLE', 'FALSE WITNESS', 'KATIE REX', 'NIGHT DOLL']}]}
# {'event_detail_date': datetime.datetime(2021, 12, 4, 22, 30), 'event_detail_title': 'BasementPERCANTPUKE', 'event_detail_music': [{'Basement': ['PERC', 'ANTPUKE']}]}

# %%
event_data_list_storage = event_data_list.copy()

# %%
event_data_list
# Out:
# [{'event_detail_date': datetime.datetime(2025, 3, 8, 22, 30),
#   'event_detail_title': 'March 8',
#   'event_detail_music': [{'Basement': ['DJ BONE',
#      'MIKE SERVITO',
#      'ROSE KOURTS']},
#    {'Studio': ['FKA.M4A', 'JASON KENDIG', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2025, 3, 7, 22, 30),
#   'event_detail_title': 'BASSIANI NIGHT',
#   'event_detail_music': [{'Basement': ['NEWA B2B NDRX',
#      'KANCHELI B2B NEBBIERI']},
#    {'Studio': ['GABRIELLE KWARTENG', '98DOTS', 'DJ SURGE']}]},
#  {'event_detail_date': datetime.datetime(2025, 3, 1, 22, 30),
#   'event_detail_title': 'ALTÆR 5 Year Anniversary',
#   'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE',
#      'STERAC',
#      'AUSPEX']},
#    {'Studio': ['DAVID ELIMELECH', 'LOREN', "S'AINT PANIC"]}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 28, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE', 'YANT', 'ÆON']},
#    {'Studio': ['HAAI', 'K WATA', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 22, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']},
#    {'Studio': ['JADALAREIGN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 21, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['X CLUB.',
#      'LDS',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MIKE SERVITO', 'TT', 'ALÍRIO']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 15, 22, 30),
#   'event_detail_title': 'FEBRUARY 15',
#   'event_detail_music': [{'Basement': ['DAX J', 'ANNĒ', 'ANNIE LEW']},
#    {'Studio': ['KEVIN AVIANCE', 'CHRIS CRUSE', 'MICHAEL CIGNARALE']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 14, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV', 'DJ SALIVA', 'MARKUS']},
#    {'Studio': ['SCHACKE', 'KIM ANH', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 8, 22, 30),
#   'event_detail_title': 'FEBRUARY 8',
#   'event_detail_music': [{'Basement': ['DARIA KOLOSOVA',
#      'ETAPP KYLE',
#      'KOZHA']},
#    {'Studio': ['ISABELLA', 'SEKUCCI B2B STERLING JUAN DIAZ', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 7, 22, 30),
#   'event_detail_title': 'FEBRUARY 7',
#   'event_detail_music': [{'Basement': ['BLASHA & ALLATT',
#      'SANDRIEN',
#      'DEVOYE']},
#    {'Studio': ['CHEZ DAMIER', 'DONIS', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 1, 22, 30),
#   'event_detail_title': 'FEBRUARY 1',
#   'event_detail_music': [{'Basement': ['BORIS', 'VOLVOX']},
#    {'Studio': ['MASSIMILIANO PAGLIARA']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 25, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DAIYAH', 'FURTIVE', 'RON LIKE HELL']},
#    {'Studio': ['CARLOS SOUFFRONT', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 18, 22, 30),
#   'event_detail_title': 'BOUND 8 YEAR ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['ADRIANA LOPEZ', 'AKUA', 'KATIE REX']},
#    {'Studio': ['ROSE KOURTS', 'X3BUTTERFLY', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 11, 22, 30),
#   'event_detail_title': 'JANUARY 11',
#   'event_detail_music': [{'Basement': ['ROBERT HOOD', 'KYRUH', 'ELLE DEE']},
#    {'Studio': ['ROI PEREZ', 'LYRIC HOOD', 'MAKADSI']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 21, 22, 30),
#   'event_detail_title': 'DECEMBER 21',
#   'event_detail_music': [{'Basement': ['D.DAN', 'QUELZA', 'CSILLA', 'COTTON']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'JASON KENDIG', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 20, 22, 30),
#   'event_detail_title': 'DECEMBER 20',
#   'event_detail_music': [{'Basement': ['CHLÄR', 'RENE WISE', 'LYDO']},
#    {'Studio': ['GIDEÖN', 'THE CARRY NATION', 'HEIDI LAWDEN']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 14, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV',
#      'CEM',
#      'ISABELLA KOEN B2B DJ RICHARD']},
#    {'Studio': ['OCTO OCTA', 'KETIA', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 13, 22, 30),
#   'event_detail_title': 'DECEMBER 13',
#   'event_detail_music': [{'Basement': ['MAMA SNAKE', 'JASSS', 'LYDO']},
#    {'Studio': ['ERIS DREW', 'NATUTA', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 7, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['PAUL FLEETWOOD', 'RYAN SMITH']},
#    {'Studio': ['MEILGAARDEN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 6, 22, 30),
#   'event_detail_title': 'MAMA TOLD YA',
#   'event_detail_music': [{'Basement': ['ANETHA', 'LACCHESI', 'MAC DECLOS']},
#    {'Studio': ['PEACHLYFE', 'ALISON SWING', 'ULTRATHEM']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 23, 22, 30),
#   'event_detail_title': 'MUTUAL RYTM NIGHT',
#   'event_detail_music': [{'Basement': ['SHDW',
#      'RUIZ OSC1',
#      'SELECTIVE RESPONSE']},
#    {'Studio': ['KEVIN AVIANCE', 'JADALAREIGN', 'JASON KENDIG']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 22, 22, 30),
#   'event_detail_title': 'NOVEMBER 22',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'AKUA', 'ALEX.COSMOS']},
#    {'Studio': ['HERCULES & LOVE AFFAIR (DJ SET)', 'MAKADSI', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DJ HOCKEY',
#      'ANTENES',
#      'RON LIKE HELL']},
#    {'Studio': ['DORISBURG', 'WONJA', 'SUCCUBASS']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 15, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['TAKAAKI ITOH', 'ÆON', 'AUSPEX']},
#    {'Studio': ['DJ HOLOGRAPHIC', 'PARTOK', 'MEZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 9, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['NØRBAK', 'AMANDA MUSSI', 'ELLE DEE']},
#    {'Studio': ['RACHEL NOON', 'DEE DIGGS', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 8, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['FRANÇOIS X',
#      'SUPERGLOSS',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['LONGITUDE (BOUFFANT BOUFFANT B2B JACOB MEEHAN)',
#      'SHAUN J. WRIGHT',
#      'DJ MISS PARKER']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 2, 22, 30),
#   'event_detail_title': 'November 2',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE',
#      'AMORAL',
#      'MOS']},
#    {'Studio': ['FKA.M4A', 'TOM PETERS', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 1, 22, 30),
#   'event_detail_title': 'rural',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'ATSUSHI MAEDA',
#      'AMELIA HOLT']},
#    {'Studio': ['INTERSTELLAR FUNK', 'NAO', 'DJ HEALTHY']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 26, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['LOLSNAKE', 'X TIN', 'KATIE REX']},
#    {'Studio': ['NITA AVIANCE', 'DJ VOICES', 'DONOFRIO']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 25, 22, 30),
#   'event_detail_title': 'OCTOBER 25',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'X CLUB.',
#      'ANNIE LEW']},
#    {'Studio': ['PABLO BOZZI', 'TT', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 19, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JOTON', 'RON LIKE HELL']},
#    {'Studio': ['GAY MARVINE', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 18, 22, 30),
#   'event_detail_title': 'OCTOBER 18',
#   'event_detail_music': [{'Basement': ['RANDOMER', 'BAUGRUPPE90', 'KXAH']},
#    {'Studio': ['MOMA READY', 'KIM ANH', 'MUTUALISM']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 12, 22, 30),
#   'event_detail_title': 'OCTOBER 12',
#   'event_detail_music': [{'Basement': ['LUKE SLATER', 'NDRX', '98DOTS']},
#    {'Studio': ['CLARISA KIMSKII', 'ANALOG SOUL', 'LORANT']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 11, 22, 30),
#   'event_detail_title': 'MORD NIGHT',
#   'event_detail_music': [{'Basement': ['BAS MOOY',
#      'ADRIANA LOPEZ',
#      'UFO95',
#      'AÖCRAM']},
#    {'Studio': ['PHYSICAL THERAPY', 'MIKE SERVITO', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 5, 22, 30),
#   'event_detail_title': 'BCCO',
#   'event_detail_music': [{'Basement': ['DJ HYPERDRIVE',
#      'PHIL BERG',
#      'CSILLA']},
#    {'Studio': ['MCR-T', 'CRYME', 'MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 4, 22, 30),
#   'event_detail_title': 'OCTOBER 4',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY 313',
#      'BOSTON 168',
#      'ELLE DEE']},
#    {'Studio': ['DJ SALIVA', 'SEKUCCI', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 28, 22, 30),
#   'event_detail_title': 'SEPTEMBER 28',
#   'event_detail_music': [{'Basement': ['QUELZA', 'NEWA']},
#    {'Studio': ['FREDDY K', 'MARIE MONTEXIER', 'AMELIA HOLT']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 27, 22, 30),
#   'event_detail_title': 'SEPTEMBER 27',
#   'event_detail_music': [{'Basement': ['KI/KI', 'SALOME', 'MORENXXX']},
#    {'Studio': ['SCHACKE', 'JEK', 'CONNOR WRONG']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 21, 22, 30),
#   'event_detail_title': 'SEPTEMBER 21',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY', 'BLANKA', 'DAIYAH']},
#    {'Studio': ['PEREL', 'LAUREL HALO', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 20, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['D.DAN',
#      'MAMA SNAKE',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['RYKER']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 14, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DAY THIEF', 'RON LIKE HELL']},
#    {'Studio': ['PEACH', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 13, 22, 30),
#   'event_detail_title': 'SEPTEMBER 13',
#   'event_detail_music': [{'Basement': ['DVS1', 'BEATRICE']},
#    {'Studio': ['JOB JOBSE', 'MEILGAARDEN', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 7, 22, 30),
#   'event_detail_title': 'SEPTEMBER 7',
#   'event_detail_music': [{'Basement': ['FREDDY K',
#      'ALARICO LIVE',
#      'KAISER',
#      'LYDO']},
#    {'Studio': ['ROZA TERENZI', 'CALL SUPER', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 6, 22, 30),
#   'event_detail_title': 'SEPTEMBER 6',
#   'event_detail_music': [{'Basement': ['PERC', 'CEM', 'COTTON']},
#    {'Studio': ['DJ MINX', 'BYRON YEATES', 'ELISSA SUCKDOG']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 31, 22, 30),
#   'event_detail_title': 'AUGUST 31',
#   'event_detail_music': [{'Basement': ['ROMAN FLÜGEL LIVE', 'ALARICO', 'ÆON']},
#    {'Studio': ['ROI PEREZ', 'NATUTA', 'MARKUS']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 24, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['NASTIA REIGEL',
#      'JAMAICA SUK',
#      'AUSPEX']},
#    {'Studio': ['CHRIS CRUSE', 'EVAN TAIL', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 17, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['REGAL',
#      'ANNIE LEW',
#      'WORD OF COMMAND B2B DJ CLONE']},
#    {'Studio': ['MCMLXXXV', 'KETIA', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 10, 22, 30),
#   'event_detail_title': 'AUGUST 10',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS B2B PHASE FATALE',
#      'JUANA B2B NE/RE/A']},
#    {'Studio': ['JADALAREIGN', 'JORKES', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 3, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LEEON', 'RYAN SMITH']},
#    {'Studio': ['WHODAT', 'SCOTIA', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 27, 22, 30),
#   'event_detail_title': 'July 27',
#   'event_detail_music': [{'Basement': ['Ø [PHASE]', 'HARUKA', 'COTTON']},
#    {'Studio': ['SEDEF ADASÏ', 'SUCCUBASS', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 26, 22, 30),
#   'event_detail_title': 'July 26',
#   'event_detail_music': [{'Basement': ['RØDHAD', 'HOLDEN FEDERICO']},
#    {'Studio': ['PAURRO', 'ANALOG SOUL', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'RON LIKE HELL']},
#    {'Studio': ['BUDINO', 'LIAD KRISPIN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 19, 22, 30),
#   'event_detail_title': 'July 19',
#   'event_detail_music': [{'Basement': ['LUKE SLATER',
#      'MAX WATTS',
#      'ERIC UMBLE']},
#    {'Studio': ['MIKE SERVITO', 'SHAUN J. WRIGHT', 'DEEP CREEP']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 13, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['UVB', 'MAREENA', 'AUSPEX']},
#    {'Studio': ['BÉZIER', 'DEVOYE', 'WHODAT']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 12, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['MIKE DEARBORN',
#      'FALSEBOI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['OSSX', 'ROSE KOURTS', 'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 6, 22, 30),
#   'event_detail_title': 'July 6',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'NØRBAK', 'UMFANG']},
#    {'Studio': ['PROSUMER', 'JASON KENDIG', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 5, 22, 30),
#   'event_detail_title': 'CLOSED: JULY 5',
#   'event_detail_music': []},
#  {'event_detail_date': datetime.datetime(2024, 6, 29, 22, 30),
#   'event_detail_title': 'BOUND PRIDE',
#   'event_detail_music': [{'Basement': ['VOLVOX FEATURING DOMI',
#      'KATIE REX',
#      'VILE']},
#    {'Studio': ['HARUKA', 'LINDO (JOTA B2B VICENTA)', 'RYAN FARR']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 28, 22, 30),
#   'event_detail_title': 'JUNE 28',
#   'event_detail_music': [{'Basement': ['SCHACKE',
#      'ANNIE LEW B2B MOS',
#      'MORENXXX']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'DJ HOLOGRAPHIC', 'JEFFREY SFIRE']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 22, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['Anthony Parasole',
#      'AMX',
#      'Justin Cudmore']},
#    {'Studio': ['Jennifer Cardini', 'David Elimelech', 'Manu Miran']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 21, 22, 30),
#   'event_detail_title': 'JUNE 21',
#   'event_detail_music': [{'Basement': ['Yonti',
#      'Elle Dee',
#      'Concrete Husband']},
#    {'Studio': ['The Carry Nation', 'Partok', 'Donis']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 15, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['Fiedel',
#      'Vel',
#      'Word of Command',
#      'DJ Clone']},
#    {'Studio': ['Matrixxman', 'Sekucci b2b Sterling Juan Diaz', 'Natuta']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 14, 22, 30),
#   'event_detail_title': 'JUNE 14',
#   'event_detail_music': [{'Basement': ['Schwefelgelb', 'Chloe Lula', 'Ana B']},
#    {'Studio': ['Dee Diggs', 'Analog Soul', 'Eli Escobar']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 8, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['Barker', 'Terence Fixmer', 'LYDO']},
#    {'Studio': ['ADAB', 'Kfeelz', 'Antojito']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 7, 22, 30),
#   'event_detail_title': 'JUNE 7',
#   'event_detail_music': [{'Basement': ['Truncate', 'Tapefeed', 'ROLA']},
#    {'Studio': ['DJ Pierre', 'Justin Cudmore', 'Boys’ Shorts']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 1, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['Shaun J. Wright',
#      'Ron Like Hell',
#      'Ryan Smith']},
#    {'Studio': ['Baronhawk Poitier', 'Ron Like Hell']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 31, 22, 30),
#   'event_detail_title': 'MAY 31',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY 313',
#      'JULIANA HUXTABLE',
#      'ALEX.COSMOS']},
#    {'Studio': ['CINTHIE', 'CHRIS CRUSE', 'JACOB MEEHAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 25, 22, 30),
#   'event_detail_title': 'SPANDAU20 NIGHT',
#   'event_detail_music': [{'Basement': ['FJAAK LIVE',
#      'ELLI ACULA',
#      'ANNA Z. B2B J.MANUEL']},
#    {'Studio': ['KEVIN AVIANCE', 'X3BUTTERFLY', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 24, 22, 30),
#   'event_detail_title': 'MAY 24',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RYKER']},
#    {'Studio': ['JASON KENDIG', 'SEKUCCI', 'GEE DEE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 18, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['MARY YUZOVSKAYA',
#      'NE/RE/A',
#      'RYAN SMITH']},
#    {'Studio': ['TAMA SUMO B2B LAKUTI', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 17, 22, 30),
#   'event_detail_title': 'BOUND Blackout',
#   'event_detail_music': [{'Basement': ['Katie Rex b2b KYRUH',
#      'Andi b2b Arvin T',
#      'Pure Immanence']},
#    {'Studio': ['Jimmy Edgar', 'Jubilee', 'Choque']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 11, 22, 30),
#   'event_detail_title': 'MAY 11',
#   'event_detail_music': [{'Basement': ['DJ BONE', 'DEVOYE', 'ELLE DEE']},
#    {'Studio': ['MARCELLUS PITTMAN', 'MIKE SERVITO', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 10, 22, 30),
#   'event_detail_title': 'RECLAIM YOUR CITY',
#   'event_detail_music': [{'Basement': ['STERAC', 'KR!Z', 'LYCHEE']},
#    {'Studio': ['RICK WADE', 'HARUKA', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 4, 22, 30),
#   'event_detail_title': 'BASEMENT 5 Year Anniversary',
#   'event_detail_music': [{'Basement': ['BEN KLOCK', 'NEWA', 'ÆON', 'COTTON']},
#    {'Studio': ['LYDO', 'JEK B2B MATAS', 'MEILGAARDEN B2B IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 3, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER', 'AMOTIK', 'AUSPEX']},
#    {'Studio': ['VICKI POWELL', 'WILL AUTOMAGIC', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 27, 22, 30),
#   'event_detail_title': 'BASSIANI NIGHT',
#   'event_detail_music': [{'Basement': ['FADI MOHEM',
#      'KANCHELI B2B PHILIPPA PACHO',
#      'NDRX']},
#    {'Studio': ['KIM ANN FOXMAN', 'MATAS', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 26, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['PARRISH SMITH',
#      'SAUSHA',
#      'KATIE REX']},
#    {'Studio': ['MAKADSI', 'DJ MISS PARKER', 'FLIRTY800']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['WRECKED ALL NIGHT LONG (RON LIKE HELL & RYAN SMITH)']},
#    {'Studio': ['LEONCE', 'KEENAN ORR', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 19, 22, 30),
#   'event_detail_title': 'April 19',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'CONCRETE HUSBAND',
#      'KXAH']},
#    {'Studio': ['ANALOG SOUL', 'MOMA READY', 'TORIBIO']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 13, 22, 30),
#   'event_detail_title': 'April 13',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS LIVE',
#      'CHLÄR',
#      'IAN CRANE']},
#    {'Studio': ['SANDRIEN', 'JASON KENDIG', 'PERFECT LOVERS']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 12, 22, 30),
#   'event_detail_title': 'April 12',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'HADONE', 'ANNIE LEW']},
#    {'Studio': ['COMO SE DJ', 'RYKER', 'OZA']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 6, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['LINDSEY HERBERT',
#      'NONCOMPLIANT',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['ETAPP KYLE', 'THE CARRY NATION', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 5, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV', 'SALOME', 'FASHION']},
#    {'Studio': ['CEM', 'DJ SALIVA', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 30, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['NØRBAK', 'ESTHER DUNE', 'AUSPEX']},
#    {'Studio': ['CLARISA KIMSKII', 'COLORED CRAIG', 'MIKE SERVITO']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 29, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['BJARKI',
#      'ELLE DEE',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['YHA YHA', 'MOMA READY', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 23, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['JAMAICA SUK', 'VOLVOX', 'LYDO']},
#    {'Studio': ['ARIEL ZETINA', 'BOUFFANT BOUFFANT', 'CURSES']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 22, 22, 30),
#   'event_detail_title': 'March 22',
#   'event_detail_music': [{'Basement': ['DRUMCELL', 'KANGDING RAY', 'ÆON']},
#    {'Studio': ['THE CARRY NATION', 'IAN CRANE', 'NSPERGER']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 16, 22, 30),
#   'event_detail_title': '13 YEARS OF WRECKED',
#   'event_detail_music': [{'Basement': ['PARTOK', 'WRECKED']},
#    {'Studio': ['\u200b\u200bT.WAN', 'WRECKED']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 15, 22, 30),
#   'event_detail_title': 'March 15',
#   'event_detail_music': [{'Basement': ['FRANÇOIS X',
#      'UFO95 LIVE',
#      'SEVYN 0000']},
#    {'Studio': ['JEK B2B MATAS', 'ADOBEPRINCESS']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 9, 22, 30),
#   'event_detail_title': 'March 9',
#   'event_detail_music': [{'Basement': ['KI/KI', 'COMO SE DJ']},
#    {'Studio': ['ROI PEREZ ALL NIGHT LONG']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 8, 22, 30),
#   'event_detail_title': 'March 8',
#   'event_detail_music': [{'Basement': ['ELLI ACULA', 'VOLVOX', 'MOS']},
#    {'Studio': ['KEVIN AVIANCE', 'MUTUALISM B2B SPRKLBB', 'FATHERHOOD']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 2, 22, 30),
#   'event_detail_title': 'March 2',
#   'event_detail_music': [{'Basement': ['REGAL', 'BAUGRUPPE90', 'ANNIE LEW']},
#    {'Studio': ['MCR-T', 'X-COAST', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 1, 22, 30),
#   'event_detail_title': 'March 1',
#   'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN',
#      'CHLOE LULA',
#      'ARVIN T']},
#    {'Studio': ['10 YEARS TIME PASSAGES: BINH', 'EVAN BAGGS']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 24, 22, 30),
#   'event_detail_title': 'DWELLER',
#   'event_detail_music': [{'Basement': ['ROBERT HOOD', 'DEVOYE', 'DAIYAH']},
#    {'Studio': ['SHAUN J WRIGHT', 'MISS TWINK USA', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 23, 22, 30),
#   'event_detail_title': 'BOUND 7 YEAR ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['CLOUDS', 'SHYBOI', 'KATIE REX']},
#    {'Studio': ['JACQ JILL', 'KIA', 'AL V DAM']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 17, 22, 30),
#   'event_detail_title': 'BasementFREDDY K OPEN TO CLOSE',
#   'event_detail_music': [{'Basement': ['FREDDY K OPEN TO CLOSE']},
#    {'Studio': ['THE CARRY NATION', 'JACOB MEEHAN', 'MAKADSI']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 16, 22, 30),
#   'event_detail_title': 'BasementHARUKACLARISA KIMSKIISPLOOFI B2B NICOLO BERNARDI',
#   'event_detail_music': [{'Basement': ['HARUKA',
#      'CLARISA KIMSKII',
#      'SPLOOFI B2B NICOLO BERNARDI']},
#    {'Studio': ['ELI ESCOBAR', 'NOMI RUIZ', 'JOSH STEERS']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 10, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['AARON CLARK',
#      'ARIEL ZETINA',
#      'LYCHEE',
#      'RON LIKE HELL',
#      'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 9, 22, 30),
#   'event_detail_title': 'FAST FORWARD NIGHT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'NEWA', 'RYKER']},
#    {'Studio': ['SCHACKE', 'X3BUTTERFLY', 'JEK']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 3, 22, 30),
#   'event_detail_title': 'BasementHENNING BAERESTELLA BOERSMACONCRETE HUSBAND',
#   'event_detail_music': [{'Basement': ['HENNING BAER',
#      'ESTELLA BOERSMA',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['DJ MINX', 'GABRIELLE KWARTENG', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 2, 22, 30),
#   'event_detail_title': 'BasementANCIENT METHODSORPHXMUERTE LENTA',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'ORPHX',
#      'MUERTE LENTA']},
#    {'Studio': ['ANALOG SOUL', 'ROSE KOURTS', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 27, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['TRUNCATE / AMANDA MUSSI / WORD OF COMMAND / DJ CLONE']},
#    {'Studio': ['BORED LORD / KILOPATRAH JONES / ANTOJITO']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['KYRUH', 'RON LIKE HELL']},
#    {'Studio': ['SOLAR & MOZHGAN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 13, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE',
#      'HIROKO YAMAMURA',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['PARTOK', 'CROMBY', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 16, 22, 30),
#   'event_detail_title': 'BasementOSCAR MULEROBEATRICELYDO',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'BEATRICE', 'LYDO']},
#    {'Studio': ['NEWA', 'JASON KENDIG', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 15, 22, 30),
#   'event_detail_title': 'BasementPERCJULIANA HUXTABLEWORLD OF COMMAND',
#   'event_detail_music': [{'Basement': ['PERC',
#      'JULIANA HUXTABLE',
#      'WORLD OF COMMAND']},
#    {'Studio': ['KEVIN AVIANCE', 'NATUTA', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 2, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JUANA', 'RYAN SMITH']},
#    {'Studio': ['WNGDU', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 1, 22, 30),
#   'event_detail_title': 'BasementSLAMFLAVIA LAUSERIC UMBLE',
#   'event_detail_music': [{'Basement': ['SLAM', 'FLAVIA LAUS', 'ERIC UMBLE']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'DAVID ELIMELECH', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 18, 22, 30),
#   'event_detail_title': 'BasementANSWER CODE REQUESTPHILIPPA PACHOMARCO NEVES',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'PHILIPPA PACHO',
#      'MARCO NEVES']},
#    {'Studio': ['GABRIELLA KWARTENG', 'THE CARRY NATION', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'RANDOMER', 'ÆON']},
#    {'Studio': ['DJ HOLOGRAPHIC', 'GIDEÖN', 'JACOB MEEHAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 11, 22, 30),
#   'event_detail_title': 'BITE NITE',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHASE FATALE',
#      'VULKANSKI']},
#    {'Studio': ['PABLO BOZZI', 'SUCCUBASS', 'NE/RE/A']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'VOLVOX',
#      'PAULA KOSKI']},
#    {'Studio': ['DAN SHAKE', 'JASON KENDIG', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['WTCHCRFT', 'RON LIKE HELL']},
#    {'Studio': ['FATHER DUKES', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 3, 22, 30),
#   'event_detail_title': 'Herrensauna',
#   'event_detail_music': [{'Basement': ['MCMLXXXV',
#      'FUTURE.666',
#      'SEVYN 0000']},
#    {'Studio': ['CEM', 'OR:LA', 'DJ SALIVA']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 28, 22, 30),
#   'event_detail_title': 'Oct 28 BOUND',
#   'event_detail_music': [{'Basement': ['Nur Jaber', 'Katie Rex', 'Annie Lew']},
#    {'Studio': ['X Club.', 'Jek', 'Kilopatrah Jones']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 27, 18, 0),
#   'event_detail_title': 'BasementKangding RayClarisa Kimskii b2b Ne/Re/A /Connor Wrong',
#   'event_detail_music': [{'Basement': ['Kangding Ray',
#      'Clarisa Kimskii b2b Ne/Re/A /',
#      'Connor Wrong']},
#    {'Studio': ['Tama Sumo b2b Lakuti', 'Mike Servito', 'Choque']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30),
#   'event_detail_title': 'BasementDANIEL AVERYFADI MOHEMSPLOOFI',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY',
#      'FADI MOHEM',
#      'SPLOOFI']},
#    {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30),
#   'event_detail_title': 'BasementDANIEL AVERYFADI MOHEMSPLOOFI',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY',
#      'FADI MOHEM',
#      'SPLOOFI']},
#    {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 14, 22, 30),
#   'event_detail_title': 'BasementRØDHÅDNDRXLYDO',
#   'event_detail_music': [{'Basement': ['RØDHÅD', 'NDRX', 'LYDO']},
#    {'Studio': ['MATAS', 'COMO SE DJ', 'MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 13, 0, 0),
#   'event_detail_title': 'BasementREBEKAHSOMEWHENLISAS',
#   'event_detail_music': [{'Basement': ['REBEKAH', 'SOMEWHEN', 'LISAS']},
#    {'Studio': ['KETIA', 'MANU MIRAN', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 7, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['NONCOMPLIANT',
#      'MATRIXXMAN',
#      'RYAN SMITH']},
#    {'Studio': ['KHIDJA', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 6, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['LEWIS FAUTZI',
#      'LAURA BCR',
#      'COTTON',
#      'AUSPEX']},
#    {'Studio': ['NITA AVIANCE B2B MIKE SERVITO',
#      'MICHAEL MAGNAN',
#      'ALISSA BRIANNA']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 30, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['D.DAN', 'ELLE DEE']},
#    {'Studio': ['HYPERAKTIVIST', 'YAZZUS', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 29, 22, 30),
#   'event_detail_title': 'BasementCHLOE LULABRYAN KASENICYOUNG MALE',
#   'event_detail_music': [{'Basement': ['CHLOE LULA',
#      'BRYAN KASENIC',
#      'YOUNG MALE']},
#    {'Studio': ['HAAI', 'STERLING JUAN DIAZ', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 23, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LEESH', 'RON LIKE HELL']},
#    {'Studio': ['BÉZIER', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TALISMANN',
#      'KYRUH',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['SALOME', 'MATAS', 'RYKER']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 16, 22, 30),
#   'event_detail_title': 'MORD 10 YEARS',
#   'event_detail_music': [{'Basement': ['BAS MOOY', 'QUELZA', 'ANTENES']},
#    {'Studio': ['ELI ESCOBAR', 'LOVE LETTERS', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 15, 22, 0),
#   'event_detail_title': 'BasementMAMA SNAKEKANCHELIALEX.COSMOS',
#   'event_detail_music': [{'Basement': ['MAMA SNAKE',
#      'KANCHELI',
#      'ALEX.COSMOS']},
#    {'Studio': ['ISABELLA', 'CHRIS CRUSE', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 9, 22, 30),
#   'event_detail_title': 'BasementNASTIALOBSTERHOLDEN FEDERICO',
#   'event_detail_music': [{'Basement': ['NASTIA',
#      'LOBSTER',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['ASH LAURYN', 'MOMA READY', 'ARIEL ME LLAMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 8, 22, 30),
#   'event_detail_title': 'BasementSCHACKEEGOTOTÆON',
#   'event_detail_music': [{'Basement': ['SCHACKE', 'EGOTOT', 'ÆON']},
#    {'Studio': ['DJ SALIVA', 'ADOBEPRINCESS', 'COMO SE DJ']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 2, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['FLAVIA LAUS',
#      'DEEPNEUE',
#      'KATIE REX']},
#    {'Studio': ['THE CARRY NATION', 'JEFFREY SFIRE', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 1, 22, 30),
#   'event_detail_title': 'BasementEFDEMINSETAOC MASSSPLOOFI B2B NICOLÒ BERNARDI',
#   'event_detail_music': [{'Basement': ['EFDEMIN',
#      'SETAOC MASS',
#      'SPLOOFI B2B NICOLÒ BERNARDI']},
#    {'Studio': ['KEVIN AVIANCE', 'JASON KENDIG', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 26, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['.VRIL LIVE', 'YONTI', 'ELLE DEE']},
#    {'Studio': ['ROI PEREZ / GIDEÖN / MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 19, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['DINA',
#      'MORENXXX',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['PANGAEA', 'HONEY BUN', 'FLIRTY800']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 12, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['DUSTIN ZAHN',
#      'LENNART WIEHE',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['BEIGE', 'SPRKLBB']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 5, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ERIKA', 'RON LIKE HELL']},
#    {'Studio': ['DAVIS GALVIN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 29, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JAMES RUSKIN',
#      'DEVOYE',
#      'TOMÁS URQUIETA']},
#    {'Studio': ['SEKUCCI', 'MISS PARKER', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 28, 22, 0),
#   'event_detail_title': 'BasementFUNCTIONAMOTIKELLE DEE',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'AMOTIK', 'ELLE DEE']},
#    {'Studio': ['MUTUALISM', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 22, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['KANGDING RAY',
#      'MARY YUZOVSKAYA',
#      'AUSPEX']},
#    {'Studio': ['JADALAREIGN', 'STERLING JUAN DIAZ', 'DAY THIEF']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 21, 22, 30),
#   'event_detail_title': 'BasementCLARISA KIMSKIIUMFANGYOUNG MALE',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII',
#      'UMFANG',
#      'YOUNG MALE']},
#    {'Studio': ['MIKE SERVITO', 'DEE DIGGS']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 15, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARK PRICE', 'RYAN SMITH']},
#    {'Studio': ['MEZ', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 14, 22, 30),
#   'event_detail_title': 'BasementDJ BONEANALOG SOULROSE KOURTS',
#   'event_detail_music': [{'Basement': ['DJ BONE',
#      'ANALOG SOUL',
#      'ROSE KOURTS']},
#    {'Studio': ['PEREL', 'FATHERHOOD']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 8, 22, 30),
#   'event_detail_title': 'BasementHENNING BAERRON LIKE HELLLYCHEE',
#   'event_detail_music': [{'Basement': ['HENNING BAER',
#      'RON LIKE HELL',
#      'LYCHEE']},
#    {'Studio': ['ELI ESCOBAR', 'KIM ANH', 'NATUTA']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 7, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['QUEST?ONMARQ',
#      '1MORNING',
#      'MUERTE LENTA',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MISS TWINK USA', 'JEK', 'DEEP CREEP']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 30, 22, 30),
#   'event_detail_title': 'June 30',
#   'event_detail_music': [{'Basement': ['HEADLESS HORSEMAN',
#      'MADNESS OF',
#      'L.SANGRE']},
#    {'Studio': ['GERD JANSON', 'MAKADSI', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 24, 22, 30),
#   'event_detail_title': 'BOUND PRIDE',
#   'event_detail_music': [{'Basement': ['FIEDEL', 'FASHION', 'KATIE REX']},
#    {'Studio': ['ULTRATHEM', 'WINTER WRONG', 'SISTER ZO', 'CHOQUE']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 23, 22, 30),
#   'event_detail_title': 'BasementLYDOKYRUHDAIYAHCONCRETE HUSBAND',
#   'event_detail_music': [{'Basement': ['LYDO',
#      'KYRUH',
#      'DAIYAH',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['MASSIMILIANO PAGLIARA',
#      'TAMA SUMO B2B LAKUTI',
#      'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 17, 22, 30),
#   'event_detail_title': 'BasementSCHACKENDRXELLE DEE',
#   'event_detail_music': [{'Basement': ['SCHACKE', 'NDRX', 'ELLE DEE']},
#    {'Studio': ['THE SPECTRUM:  NDRX', 'LAUREN FLAX', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 16, 22, 30),
#   'event_detail_title': 'FIST 7 YEAR ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['SLAM',
#      'ISABELLA KOEN',
#      'COTTON',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['BAUGRUPPE90', 'SEVYN 0000', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 10, 22, 30),
#   'event_detail_title': 'BasementDASHA RUSHTAPEFEEDJAY YORK',
#   'event_detail_music': [{'Basement': ['DASHA RUSH', 'TAPEFEED', 'JAY YORK']},
#    {'Studio': ['FOR FUTURES SAKE', 'DJ RAQX', 'DX7']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 9, 22, 30),
#   'event_detail_title': 'VESELKA',
#   'event_detail_music': [{'Basement': ['PEACHLYFE', 'TWEEMAN', 'ANA B']},
#    {'Studio': ['THE CARRY NATION', 'JASON KENDIG', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 3, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['KIM ANN FOXMAN', 'RON LIKE HELL']},
#    {'Studio': ['SHAUN J. WRIGHT', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 2, 22, 30),
#   'event_detail_title': 'BasementANCIENT METHODSPHASE FATALECHLOE LULA',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHASE FATALE',
#      'CHLOE LULA']},
#    {'Studio': ['CHRIS CRUSE', 'PARTOK']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 27, 22, 30),
#   'event_detail_title': 'BasementCLARISA KIMSKIISANDRIENHOLDEN FEDERICO',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII',
#      'SANDRIEN',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['BINH', 'JEK', 'HANK JACKSON']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 26, 22, 30),
#   'event_detail_title': 'BasementSURGEONETAPP KYLEUMFANG',
#   'event_detail_music': [{'Basement': ['SURGEON', 'ETAPP KYLE', 'UMFANG']},
#    {'Studio': ['JASON KENDIG', 'DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ADAB', 'RON LIKE HELL']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 19, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['WALLIS', 'KATIE REX', 'SPEEDY SPICE']},
#    {'Studio': ['DEE DIGGS', 'MICHAEL MAGNAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 13, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SCALAMERIYA',
#      'FLAVIA LAUS',
#      'STARRK',
#      'AUSPEX']},
#    {'Studio': ['JUANA', 'LOVE LETTERS', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 12, 22, 30),
#   'event_detail_title': 'BasementJULIANA HUXTABLEMANNI DEEWTCHCRFT',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'MANNI DEE',
#      'WTCHCRFT']},
#    {'Studio': ['EZY', 'MANU MIRAN', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 6, 22, 30),
#   'event_detail_title': 'BASEMENT ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['FREDDY K', 'BEATRICE', 'LYDO']},
#    {'Studio': ['JEK', 'MATAS', 'MUTUALISM', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 5, 22, 30),
#   'event_detail_title': 'BasementTHOMAS P. HECKMANNYOUNG MALEELLE DEE',
#   'event_detail_music': [{'Basement': ['THOMAS P. HECKMANN',
#      'YOUNG MALE',
#      'ELLE DEE']},
#    {'Studio': ['ANALOG SOUL', 'MIKE SERVITO', 'DEVOYE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 29, 22, 30),
#   'event_detail_title': 'BOUND Blackout',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'LYDO', 'KATIE REX']},
#    {'Studio': ['CINTHIE', 'JADALAREIGN', 'SAVILE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 28, 22, 30),
#   'event_detail_title': 'L.I.E.S. NITE',
#   'event_detail_music': [{'Basement': ['LEGOWELT',
#      'VERONICA VASICKA',
#      'L.SANGRE']},
#    {'Studio': ['RON MORELLI', 'TRAXX', 'SWEATER ON POLO']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 22, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['SCHWEFELGELB',
#      'ANDI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['KETIA', '8ULENTINA']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 21, 22, 30),
#   'event_detail_title': 'BasementSHDW & OBSCURE SHAPELARS HUISMANNCHONTANE',
#   'event_detail_music': [{'Basement': ['SHDW & OBSCURE SHAPE',
#      'LARS HUISMANN',
#      'CHONTANE']},
#    {'Studio': ['THE CARRY NATION', 'ELI ESCOBAR', 'COSMO B2B DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 15, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JURI HEIDEMANN',
#      'TOMÁS URQUIETA',
#      'LYDO']},
#    {'Studio': ['KIERNAN LAVEAUX', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 14, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHILIPP STROBEL',
#      'MOTIVE-A']},
#    {'Studio': ['CARLOS SOUFFRONT', 'GALCHER LUSTWERK', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 8, 22, 30),
#   'event_detail_title': 'BasementREBEKAHTALISMANNLYCHEE B2B GUILT ATTENDANT',
#   'event_detail_music': [{'Basement': ['REBEKAH',
#      'TALISMANN',
#      'LYCHEE B2B GUILT ATTENDANT']},
#    {'Studio': ['HUERCO S', 'DEBONAIR', 'SIGNIFICANT OTHER', 'ONLY CHILD']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 7, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['DJ HYPERACTIVE',
#      'CLARISA KIMSKII',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['MIKE SERVITO', 'MADISON MOORE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 1, 0, 0),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['T.WAN', 'RON LIKE HELL']},
#    {'Studio': ['FATHERHOOD', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 31, 22, 30),
#   'event_detail_title': 'BasementREGALPHILIPPA PACHO B2B BLUE HOURLISAS',
#   'event_detail_music': [{'Basement': ['REGAL',
#      'PHILIPPA PACHO B2B BLUE HOUR',
#      'LISAS']},
#    {'Studio': ['RACHEL NOON', 'MOHAJER', 'NICK BAZZANO']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 25, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['HYPERAKTIVIST', 'YAZZUS', 'KYRUH']},
#    {'Studio': ['DJ TOOL', 'WHY BE', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 24, 22, 30),
#   'event_detail_title': 'BasementDR. RUBINSTEINDARIA KOLOSOVAWTCHCRFT',
#   'event_detail_music': [{'Basement': ['DR. RUBINSTEIN',
#      'DARIA KOLOSOVA',
#      'WTCHCRFT']},
#    {'Studio': ['X-COAST', 'DAVID ELIMELECH', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 18, 22, 30),
#   'event_detail_title': 'BasementOSCAR MULEROFREDDY KLYDO',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'FREDDY K', 'LYDO']},
#    {'Studio': ['JASON KENDIG', 'JEK', 'MISS PARKER']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 17, 22, 30),
#   'event_detail_title': 'BasementTAKAAKI ITOHHIROKO YAMAMURAUMFANG',
#   'event_detail_music': [{'Basement': ['TAKAAKI ITOH',
#      'HIROKO YAMAMURA',
#      'UMFANG']},
#    {'Studio': ['DJ MINX', 'MIKE SERVITO B2B LOVE LETTERS', 'HONEY BUN']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 11, 22, 30),
#   'event_detail_title': 'March 11',
#   'event_detail_music': [{'Basement': ['DRUMCELL', 'TIN MAN', 'ELLE DEE']},
#    {'Studio': ['MARCELLUS PITTMAN', 'DEE DIGGS', 'DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 10, 22, 30),
#   'event_detail_title': 'BasementMARCEL FENGLERSTEYADEEPAK SHARMA',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER',
#      'STEYA',
#      'DEEPAK SHARMA']},
#    {'Studio': ['ANALOG SOUL', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 4, 22, 30),
#   'event_detail_title': 'WRECKED 12 YEAR ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['AKUA', 'LYCHEE B2B FURTIVE']},
#    {'Studio': ['RON LIKE HELL', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 3, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['ADRIANA LOPEZ', 'UUN', 'AUSPEX']},
#    {'Studio': ['ARIEL ZETINA', 'MUTUALISM', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 25, 22, 30),
#   'event_detail_title': 'DWELLER',
#   'event_detail_music': [{'Basement': ['TERRENCE DIXON',
#      'MAX WATTS',
#      'JUANA']},
#    {'Studio': ['FRED P', 'ETTA']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 24, 22, 30),
#   'event_detail_title': 'BasementANTHONY PARASOLEVOLVOXANA B',
#   'event_detail_music': [{'Basement': ['ANTHONY PARASOLE', 'VOLVOX', 'ANA B']},
#    {'Studio': ['JUSTIN CUDMORE', 'RELAXER B2B SPF 50']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 18, 22, 30),
#   'event_detail_title': 'BasementHÉCTOR OAKSKYRUHJEK',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'KYRUH', 'JEK']},
#    {'Studio': ['GERD JANSON', 'DEE DIGGS', 'JASON KENDIG']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 17, 22, 30),
#   'event_detail_title': 'BasementTRUNCATEANALOG SOULLYCHEE',
#   'event_detail_music': [{'Basement': ['TRUNCATE', 'ANALOG SOUL', 'LYCHEE']},
#    {'Studio': ['DJ PIERRE', 'LAUREN FLAX', 'HEIDI SABERTOOTH']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 11, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['MANNI DEE', 'KATIE REX', 'LISAS']},
#    {'Studio': ['ACEMO', 'ROSE KOURTS', 'TURTLE BUGG']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 10, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['RYAN JAMES FORD',
#      'BAPARI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MCR-T', 'SISTER ZO', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['PAUL FLEETWOOD (PERIMETER JUNK)',
#      'RON LIKE HELL']},
#    {'Studio': ['DJ VOICES', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 28, 22, 30),
#   'event_detail_title': 'BasementSPFDJSCHACKEJEK',
#   'event_detail_music': [{'Basement': ['SPFDJ', 'SCHACKE', 'JEK']},
#    {'Studio': ['NEWA', 'FKA.M4A']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 21, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['BLOODY MARY',
#      'YOUNG MALE',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['FATHERHOOD', 'SYBIL JASON']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 14, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SLAM', 'DENISE RABE', 'AUSPEX']},
#    {'Studio': ['LEEON', 'JASON KENDIG', 'ANALOG SOUL']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 7, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['MIKE PARKER', 'AKUA', '1MORNING']},
#    {'Studio': ['LYDO B2B SCHACKE', 'DEVOYE']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 17, 22, 30),
#   'event_detail_title': 'BasementFUNCTIONPEACHLYFEUMFANG',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'PEACHLYFE', 'UMFANG']},
#    {'Studio': ['BORIS', 'JEK']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 16, 22, 30),
#   'event_detail_title': 'BOUND Six Year Anniversary',
# ...
#   'event_detail_title': 'BasementDAX JNEWATT',
#   'event_detail_music': [{'Basement': ['DAX J', 'NEWA', 'TT']},
#    {'Studio': ['REGULARFANTASY', 'JASON KENDIG', 'DEE DIGGS']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 11, 22, 30),
#   'event_detail_title': 'Balance',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER',
#      'AADJA',
#      'MUTUALISM']},
#    {'Studio': ['LUIGI DI VENERE B2B STATHIS', 'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 5, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['SHARLESE', 'RON LIKE HELL']},
#    {'Studio': ['MIDLAND', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 4, 22, 30),
#   'event_detail_title': 'BasementHÉCTOR OAKSSTEF MENDESIDISLYDO',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS',
#      'STEF MENDESIDIS',
#      'LYDO']},
#    {'Studio': ['NDRX', 'DARIA KOLOSOVA']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 28, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['DOLLHOUSE',
#      'HIM HUN',
#      'KATIE REX WITH PANTERAH LIVE']},
#    {'Studio': ['BOUDOIR: ADAM UNKNOWN',
#      'BRICKLAYER',
#      'MATH3CA',
#      'MS. MANGO',
#      'MX. BLAIRE']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 22, 22, 30),
#   'event_detail_title': 'BasementSOMEWHENNUR JABERANA B',
#   'event_detail_music': [{'Basement': ['SOMEWHEN', 'NUR JABER', 'ANA B']},
#    {'Studio': ['X-COAST', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 21, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['CLERIC', 'P.E.A.R.L.', 'AUSPEX']},
#    {'Studio': ['CASHU', 'MADISON MOORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 15, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DEVOYE', 'RON LIKE HELL']},
#    {'Studio': ['SISTER SYSTEM', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 14, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'SCHWEFELGELB',
#      'PHILIPP STROBEL']},
#    {'Studio': ['DJ WAWA', 'HONEY BUN']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 8, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['ETAPP KYLE',
#      'KYRUH',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MICHAEL MAGNAN', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 7, 22, 30),
#   'event_detail_title': 'October 7',
#   'event_detail_music': [{'Basement': ['RROSE', 'ZADIG', 'LYCHEE']},
#    {'Studio': ['MIKE SERVITO', 'PAÀL']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 1, 0, 0),
#   'event_detail_title': 'Herrensauna',
#   'event_detail_music': [{'Basement': ['CEM', 'TT', 'SAUSHA']},
#    {'Studio': ['MCMLXXXV', 'DJ SALIVA', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 30, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'EGOTOT',
#      'SHYBOI']},
#    {'Studio': ['GABRIELLE KWARTENG', '8ULENTINA', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 24, 0, 0),
#   'event_detail_title': 'September 24',
#   'event_detail_music': [{'Basement': ['ANETHA', 'AADJA', 'ANA B']},
#    {'Studio': ['DJ GIGOLA', 'X-COAST']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 23, 22, 30),
#   'event_detail_title': 'September 23',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY', 'UMFANG']},
#    {'Studio': ['INTERSTELLAR FUNK', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 17, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'RYAN SMITH']},
#    {'Studio': ['JACOB MEEHAN', 'FATHER FIGURE']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 16, 22, 30),
#   'event_detail_title': 'September 16',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'ALEJANDRO FRANCO',
#      'ANTENES']},
#    {'Studio': ['THE CARRY NATION', 'DEE DIGGS', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 10, 0, 0),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['REGAL', 'MADWOMAN', 'AUSPEX']},
#    {'Studio': ['EFDEMIN', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 10, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['RANDOMER',
#      'PHILIPPA PACHO',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['KIM ANN FOXMAN', 'ONIO', 'ULTRATHEM']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 3, 0, 0),
#   'event_detail_title': 'FAST FORWARD NIGHT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'EZY', 'TT']},
#    {'Studio': ['SCHACKE', 'PEACHLYFE']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 2, 22, 0),
#   'event_detail_title': 'September 2',
#   'event_detail_music': [{'Basement': ['999999999', 'VOLVOX', 'MADNESS OF']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'RYAN ELLIOTT', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 27, 22, 30),
#   'event_detail_title': 'August 27',
#   'event_detail_music': [{'Basement': ['LUKE SLATER', 'BEATRICE', 'UMFANG']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 20, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['NONCOMPLIANT',
#      'MIKE DEARBORN',
#      'JUSTIN CUDMORE B2B AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 13, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['AKUA',
#      'ANA B',
#      'GABBERBITCH69 B2B LIMITBREAK!',
#      'WORD OF COMMAND B2B DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 6, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['SUCCUBASS',
#      'MIKE SERVITO',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 29, 0, 0),
#   'event_detail_title': 'L.I.E.S. NIGHT',
#   'event_detail_music': [{'Basement': ['RON MORELLI', 'SILENT SERVANT']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 23, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['ALPHA TRACKS',
#      'ESTOC',
#      'SAUSHA B2B SUNRISE HUNTER',
#      'WORD OF COMMAND B2B DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 22, 22, 30),
#   'event_detail_title': 'July 22',
#   'event_detail_music': [{'Basement': ['TAPEFEED',
#      'VERONICA VASICKA',
#      'MOMENT OF TERROR']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 16, 22, 30),
#   'event_detail_title': 'WRECKED [DAY INTO NIGHT]',
#   'event_detail_music': [{'Basement': ['VICKI POWELL',
#      'MANU MIRAN',
#      'JUANA',
#      'DEE DIGGS',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 15, 22, 30),
#   'event_detail_title': 'July 15',
#   'event_detail_music': [{'Basement': ['FREDDY K', 'PANGAEA', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 9, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['CTRLS', 'REN G', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 8, 22, 30),
#   'event_detail_title': 'July 8',
#   'event_detail_music': [{'Basement': ['REBEKAH', 'STARKK']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 2, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['JAMES RUSKIN',
#      'VOLVOX B2B JUANA',
#      'JUSTIN CUDMORE B2B HIROKO YAMAMURA']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 30, 22, 30),
#   'event_detail_title': 'July 30',
#   'event_detail_music': [{'Basement': ['D.DAN', 'PEACHLYFE', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 25, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'TT', 'KATIE REX']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 24, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['CEM', 'MCMLXXXV', 'ISABELLA KOEN']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 18, 22, 30),
#   'event_detail_title': 'June 18',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'MAX WATTS', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 17, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['FIEDEL', 'AKUA', 'AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 11, 22, 30),
#   'event_detail_title': 'June 11',
#   'event_detail_music': [{'Basement': ['REGIS', 'YOUNG MALE', 'L.SANGRE']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 10, 22, 30),
#   'event_detail_title': 'June 10',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'SILENT SERVANT',
#      'JANUARY HUNT']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['BÉZIER',
#      'RON LIKE HELL',
#      'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 3, 22, 30),
#   'event_detail_title': 'June 3',
#   'event_detail_music': [{'Basement': ['PARTOK',
#      'MADISON MOORE',
#      'KIM ANN FOXMAN']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 28, 22, 30),
#   'event_detail_title': 'STAUB',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'IRAKLI', 'ANTENES']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 27, 22, 30),
#   'event_detail_title': 'May 27',
#   'event_detail_music': [{'Basement': ['VAGUE MÉCANIQUE LIVE',
#      'TERENCE FIXMER B2B PHASE FATALE',
#      'IREEN AMNES']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 21, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ABAJOUR',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 14, 22, 30),
#   'event_detail_title': 'May 14',
#   'event_detail_music': [{'Basement': ['TIN MAN',
#      'MIKE SERVITO B2B JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 13, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['KILBOURNE',
#      'AIDEN',
#      'S&M B2B BURNER ACCOUNT',
#      'DJ CLONE B2B WORD OF COMMAND']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 7, 22, 30),
#   'event_detail_title': 'BASEMENT ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'LYDO',
#      'TT',
#      'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 6, 22, 30),
#   'event_detail_title': 'May 6',
#   'event_detail_music': [{'Basement': ['REGAL', 'VOLVOX', 'WTCHCRFT']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 30, 22, 30),
#   'event_detail_title': 'EXALT',
#   'event_detail_music': [{'Basement': ['MATRIXXMAN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 29, 22, 30),
#   'event_detail_title': 'April 29',
#   'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN',
#      'THAM',
#      'DAIYAH']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 23, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['LOKIER', 'KATIE REX', 'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 22, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHILIPP STROBEL',
#      'NE',
#      'RE',
#      'A']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['RYAN SMITH', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 15, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['TRUNCATE',
#      'SHAUN J WRIGHT B2B MADISON MOORE',
#      'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 9, 22, 30),
#   'event_detail_title': 'April 9',
#   'event_detail_music': [{'Basement': ['RROSE', 'KANGDING RAY', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 8, 22, 30),
#   'event_detail_title': 'April 8',
#   'event_detail_music': [{'Basement': ['LYDO', 'WORD OF COMMAND', 'ANA B']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 2, 22, 30),
#   'event_detail_title': 'MORD NIGHT',
#   'event_detail_music': [{'Basement': ['BAS MOOY', 'ANSOME', 'YOUNG MALE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 1, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SNTS', 'NUR JABER', 'AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 26, 22, 30),
#   'event_detail_title': 'March 26',
#   'event_detail_music': [{'Basement': ['REGIS',
#      'RON MORELLI',
#      'NE',
#      'RE',
#      'A']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 25, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['BLUE HOUR',
#      'TYGAPAW',
#      'MEMPHY',
#      'DJ CLONE',
#      'WORD OF COMMAND']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 19, 22, 30),
#   'event_detail_title': '11 YEARS OF WRECKED',
#   'event_detail_music': [{'Basement': ['BORIS',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 18, 22, 30),
#   'event_detail_title': 'March 18',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'ELLE DEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 12, 22, 30),
#   'event_detail_title': 'March 12',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RACHEL NOON', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 11, 22, 30),
#   'event_detail_title': 'March 11',
#   'event_detail_music': [{'Basement': ['SARA LANDRY',
#      'XIORRO',
#      'YOUNG MALE']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 5, 22, 30),
#   'event_detail_title': 'March 5',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY', 'KYRUH B2B WTCHCRFT']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 4, 22, 30),
#   'event_detail_title': 'March 4',
#   'event_detail_music': [{'Basement': ['BEN KLOCK', 'UMFANG']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 26, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LIVWUTANG',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 19, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['SHLØMO',
#      'ARIEL ZETINA',
#      'JANUARY HUNT',
#      'WORD OF COMMAND',
#      'DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 12, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['PEACHLYFE', 'MORENXXX', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 5, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'VINCENT NEUMANN  JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 29, 22, 30),
#   'event_detail_title': 'January 29',
#   'event_detail_music': [{'Basement': ['ANETHA', 'SOMEWHEN', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 22, 22, 30),
#   'event_detail_title': 'January 22',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'FIEDEL',
#      'DAIYAH']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 15, 22, 30),
#   'event_detail_title': 'POSSESSION',
#   'event_detail_music': [{'Basement': ['PARFAIT', 'D.DAN', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 7, 22, 30),
#   'event_detail_title': 'January 7',
#   'event_detail_music': [{'Basement': ['I HATE MODELS', 'NDRX', 'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 18, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 11, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['ETAPP KYLE',
#      'FALSE WITNESS',
#      'KATIE REX',
#      'NIGHT DOLL']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 4, 22, 30),
#   'event_detail_title': 'BasementPERCANTPUKE',
#   'event_detail_music': [{'Basement': ['PERC', 'ANTPUKE']}]}]

# %%
import re

for event in event_data_list:
    title = event.get("event_detail_title", "")
    if re.search(r'\b(january|february)\b', title, re.IGNORECASE): event["event_detail_title"] = ""
    else:
        if re.search(r'\bbasement', title, re.IGNORECASE):
            if not re.search(r'\banniversary\b', title, re.IGNORECASE):
                event["event_detail_title"] = ""

for event in event_data_list:
    title = event.get("event_detail_title", "")
    if re.search(r"MORD", title, re.IGNORECASE):
        event["event_detail_title"] = "MORD NIGHT"
    elif re.search(r"BASEMENT", title, re.IGNORECASE):
        event["event_detail_title"] = "BASEMENT ANNIVERSARY"
    elif re.search(r"WRECKED", title, re.IGNORECASE):
        event["event_detail_title"] = "WRECKED"
    elif re.search(r"BOUND", title, re.IGNORECASE):
        event["event_detail_title"] = "BOUND BLACKOUT"
    elif re.search(r"L\.I\.E\.S\.", title, re.IGNORECASE):
        event["event_detail_title"] = "L.I.E.S. NIGHT"
    elif re.search(r"ALTÆR", title, re.IGNORECASE):
        event["event_detail_title"] = "ALTÆR"
    elif re.search(r"FIST", title, re.IGNORECASE):
        event["event_detail_title"] = "FIST"


# Transformation for event_detail_music
for event in event_data_list:
    # Iterate over each sub-dictionary in the event_detail_music list.
    for stage_dict in event["event_detail_music"]:
        for stage, dj_list in stage_dict.items():
            # First, check for the NE/RE/A case.
            lower_djs = [dj.strip().lower() for dj in dj_list]
            if {"ne", "re", "a"}.issubset(lower_djs):
                dj_list = ["NE/RE/A"]
            else:
                # Otherwise, update the DJ list by splitting any string containing "B2B".
                new_dj_list = []
                for dj in dj_list:
                    if "b2b" in dj.lower():
                        # Use a case-insensitive split on "B2B"
                        parts = re.split("(?i)b2b", dj)
                        if len(parts) >= 2:
                            # First part: trim trailing whitespace.
                            new_dj1 = parts[0].rstrip()
                            # Second part: trim leading whitespace.
                            new_dj2 = parts[1].lstrip()
                            if new_dj1:
                                new_dj_list.append(new_dj1)
                            if new_dj2:
                                new_dj_list.append(new_dj2)
                        else:
                            new_dj_list.append(dj)
                    else:
                        new_dj_list.append(dj)
                dj_list = new_dj_list
            
            # Next, split any DJ string containing " / " as a delimiter.
            new_dj_list = []
            for dj in dj_list:
                if " / " in dj:
                    # Split the string on " / " and strip each part.
                    parts = [part.strip() for part in dj.split(" / ") if part.strip()]
                    new_dj_list.extend(parts)
                else:
                    new_dj_list.append(dj)
            dj_list = new_dj_list
            
            # Finally, convert every DJ string to uppercase.
            dj_list = [dj.upper() for dj in dj_list]
            
            # Update the stage dictionary.
            stage_dict[stage] = dj_list

for event in event_data_list:
    for stage_dict in event["event_detail_music"]:
        for stage, dj_list in stage_dict.items():
            new_dj_list = []
            for dj in dj_list:
                dj_stripped = dj.strip()
                dj_upper = dj_stripped.upper()
                if dj_stripped.lower() == "ne/re/a /".strip().lower(): new_dj_list.append("NE/RE/A")
                elif dj_upper == "ROI PEREZ ALL NIGHT LONG": new_dj_list.append("ROI PEREZ")
                elif dj_upper == "WRECKED ALL NIGHT LONG (RON LIKE HELL & RYAN SMITH)": new_dj_list.extend(["RON LIKE HELL", "RYAN SMITH"])
                elif dj_upper == "VINCENT NEUMANN  JUSTIN CUDMORE": new_dj_list.extend(["VINCENT NEUMANN", "JUSTIN CUDMORE"])
                elif dj_upper == "THE SPECTRUM:  NDRX": new_dj_list.append("NDRX")
                elif dj_upper == "FREDDY K OPEN TO CLOSE": new_dj_list.append("FREDDY K")
                elif dj_upper == "LINDO (JOTA": new_dj_list.append("LINDO (JOTA B2B VICENTA)")
                elif dj_upper == "VICENTA)": continue
                elif dj_upper == "WRECKED": continue
                elif dj_upper == "WORLD OF COMMAND": new_dj_list.append("WORD OF COMMAND")
                elif dj_upper == "VOLVOX FEATURING DOMI": new_dj_list.append("VOLVOX")
                elif dj_upper == "SHAUN J WRIGHT": new_dj_list.append("SHAUN J. WRIGHT")
                elif dj_upper == "PAUL FLEETWOOD (PERIMETER JUNK)": new_dj_list.append("PAUL FLEETWOOD")
                elif dj_upper == "NICOLO BERNARDI": new_dj_list.append("NICOLÒ BERNARDI")
                elif dj_upper == "KATIE REX WITH PANTERAH LIVE": new_dj_list.append("KATIE REX")
                elif dj_upper == "JACOB MEEHAN)": new_dj_list.append("JACOB MEEHAN")
                elif dj_upper == "GABRIELLA KWARTENG": new_dj_list.append("GABRIELLE KWARTENG")
                elif dj_upper == "AMX AKA THE AM": new_dj_list.append("AMX")
                elif dj_upper == "ALARICO LIVE": new_dj_list.append("ALARICO")
                elif dj_upper == "STEF MENDESIDIS LIVE": new_dj_list.append("STEF MENDESIDIS")
                else: new_dj_list.append(dj)
            stage_dict[stage] = new_dj_list

# Now event_data_list has been updated.
event_data_list
# Out:
# [{'event_detail_date': datetime.datetime(2025, 3, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ BONE',
#      'MIKE SERVITO',
#      'ROSE KOURTS']},
#    {'Studio': ['FKA.M4A', 'JASON KENDIG', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2025, 3, 7, 22, 30),
#   'event_detail_title': 'BASSIANI NIGHT',
#   'event_detail_music': [{'Basement': ['NEWA',
#      'NDRX',
#      'KANCHELI',
#      'NEBBIERI']},
#    {'Studio': ['GABRIELLE KWARTENG', '98DOTS', 'DJ SURGE']}]},
#  {'event_detail_date': datetime.datetime(2025, 3, 1, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE',
#      'STERAC',
#      'AUSPEX']},
#    {'Studio': ['DAVID ELIMELECH', 'LOREN', "S'AINT PANIC"]}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 28, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS', 'YANT', 'ÆON']},
#    {'Studio': ['HAAI', 'K WATA', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 22, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']},
#    {'Studio': ['JADALAREIGN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 21, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['X CLUB.',
#      'LDS',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MIKE SERVITO', 'TT', 'ALÍRIO']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 15, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DAX J', 'ANNĒ', 'ANNIE LEW']},
#    {'Studio': ['KEVIN AVIANCE', 'CHRIS CRUSE', 'MICHAEL CIGNARALE']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 14, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV', 'DJ SALIVA', 'MARKUS']},
#    {'Studio': ['SCHACKE', 'KIM ANH', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DARIA KOLOSOVA',
#      'ETAPP KYLE',
#      'KOZHA']},
#    {'Studio': ['ISABELLA', 'SEKUCCI', 'STERLING JUAN DIAZ', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 7, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['BLASHA & ALLATT',
#      'SANDRIEN',
#      'DEVOYE']},
#    {'Studio': ['CHEZ DAMIER', 'DONIS', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2025, 2, 1, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['BORIS', 'VOLVOX']},
#    {'Studio': ['MASSIMILIANO PAGLIARA']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 25, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DAIYAH', 'FURTIVE', 'RON LIKE HELL']},
#    {'Studio': ['CARLOS SOUFFRONT', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 18, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['ADRIANA LOPEZ', 'AKUA', 'KATIE REX']},
#    {'Studio': ['ROSE KOURTS', 'X3BUTTERFLY', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2025, 1, 11, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ROBERT HOOD', 'KYRUH', 'ELLE DEE']},
#    {'Studio': ['ROI PEREZ', 'LYRIC HOOD', 'MAKADSI']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['D.DAN', 'QUELZA', 'CSILLA', 'COTTON']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'JASON KENDIG', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 20, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['CHLÄR', 'RENE WISE', 'LYDO']},
#    {'Studio': ['GIDEÖN', 'THE CARRY NATION', 'HEIDI LAWDEN']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 14, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV',
#      'CEM',
#      'ISABELLA KOEN',
#      'DJ RICHARD']},
#    {'Studio': ['OCTO OCTA', 'KETIA', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 13, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['MAMA SNAKE', 'JASSS', 'LYDO']},
#    {'Studio': ['ERIS DREW', 'NATUTA', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 7, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['PAUL FLEETWOOD', 'RYAN SMITH']},
#    {'Studio': ['MEILGAARDEN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2024, 12, 6, 22, 30),
#   'event_detail_title': 'MAMA TOLD YA',
#   'event_detail_music': [{'Basement': ['ANETHA', 'LACCHESI', 'MAC DECLOS']},
#    {'Studio': ['PEACHLYFE', 'ALISON SWING', 'ULTRATHEM']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 23, 22, 30),
#   'event_detail_title': 'MUTUAL RYTM NIGHT',
#   'event_detail_music': [{'Basement': ['SHDW',
#      'RUIZ OSC1',
#      'SELECTIVE RESPONSE']},
#    {'Studio': ['KEVIN AVIANCE', 'JADALAREIGN', 'JASON KENDIG']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'AKUA', 'ALEX.COSMOS']},
#    {'Studio': ['HERCULES & LOVE AFFAIR (DJ SET)', 'MAKADSI', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DJ HOCKEY',
#      'ANTENES',
#      'RON LIKE HELL']},
#    {'Studio': ['DORISBURG', 'WONJA', 'SUCCUBASS']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 15, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['TAKAAKI ITOH', 'ÆON', 'AUSPEX']},
#    {'Studio': ['DJ HOLOGRAPHIC', 'PARTOK', 'MEZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 9, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['NØRBAK', 'AMANDA MUSSI', 'ELLE DEE']},
#    {'Studio': ['RACHEL NOON', 'DEE DIGGS', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 8, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['FRANÇOIS X',
#      'SUPERGLOSS',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['LONGITUDE (BOUFFANT BOUFFANT',
#      'JACOB MEEHAN',
#      'SHAUN J. WRIGHT',
#      'DJ MISS PARKER']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 2, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS', 'AMORAL', 'MOS']},
#    {'Studio': ['FKA.M4A', 'TOM PETERS', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 11, 1, 22, 30),
#   'event_detail_title': 'rural',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'ATSUSHI MAEDA',
#      'AMELIA HOLT']},
#    {'Studio': ['INTERSTELLAR FUNK', 'NAO', 'DJ HEALTHY']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 26, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['LOLSNAKE', 'X TIN', 'KATIE REX']},
#    {'Studio': ['NITA AVIANCE', 'DJ VOICES', 'DONOFRIO']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 25, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'X CLUB.',
#      'ANNIE LEW']},
#    {'Studio': ['PABLO BOZZI', 'TT', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 19, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JOTON', 'RON LIKE HELL']},
#    {'Studio': ['GAY MARVINE', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RANDOMER', 'BAUGRUPPE90', 'KXAH']},
#    {'Studio': ['MOMA READY', 'KIM ANH', 'MUTUALISM']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 12, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['LUKE SLATER', 'NDRX', '98DOTS']},
#    {'Studio': ['CLARISA KIMSKII', 'ANALOG SOUL', 'LORANT']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 11, 22, 30),
#   'event_detail_title': 'MORD NIGHT',
#   'event_detail_music': [{'Basement': ['BAS MOOY',
#      'ADRIANA LOPEZ',
#      'UFO95',
#      'AÖCRAM']},
#    {'Studio': ['PHYSICAL THERAPY', 'MIKE SERVITO', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 5, 22, 30),
#   'event_detail_title': 'BCCO',
#   'event_detail_music': [{'Basement': ['DJ HYPERDRIVE',
#      'PHIL BERG',
#      'CSILLA']},
#    {'Studio': ['MCR-T', 'CRYME', 'MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2024, 10, 4, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY 313',
#      'BOSTON 168',
#      'ELLE DEE']},
#    {'Studio': ['DJ SALIVA', 'SEKUCCI', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 28, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['QUELZA', 'NEWA']},
#    {'Studio': ['FREDDY K', 'MARIE MONTEXIER', 'AMELIA HOLT']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 27, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['KI/KI', 'SALOME', 'MORENXXX']},
#    {'Studio': ['SCHACKE', 'JEK', 'CONNOR WRONG']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY', 'BLANKA', 'DAIYAH']},
#    {'Studio': ['PEREL', 'LAUREL HALO', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 20, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['D.DAN',
#      'MAMA SNAKE',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['RYKER']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 14, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DAY THIEF', 'RON LIKE HELL']},
#    {'Studio': ['PEACH', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 13, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DVS1', 'BEATRICE']},
#    {'Studio': ['JOB JOBSE', 'MEILGAARDEN', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 7, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FREDDY K',
#      'ALARICO',
#      'KAISER',
#      'LYDO']},
#    {'Studio': ['ROZA TERENZI', 'CALL SUPER', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2024, 9, 6, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['PERC', 'CEM', 'COTTON']},
#    {'Studio': ['DJ MINX', 'BYRON YEATES', 'ELISSA SUCKDOG']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 31, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ROMAN FLÜGEL LIVE', 'ALARICO', 'ÆON']},
#    {'Studio': ['ROI PEREZ', 'NATUTA', 'MARKUS']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 24, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['NASTIA REIGEL',
#      'JAMAICA SUK',
#      'AUSPEX']},
#    {'Studio': ['CHRIS CRUSE', 'EVAN TAIL', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 17, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['REGAL',
#      'ANNIE LEW',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MCMLXXXV', 'KETIA', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHASE FATALE',
#      'JUANA',
#      'NE/RE/A']},
#    {'Studio': ['JADALAREIGN', 'JORKES', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 8, 3, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LEEON', 'RYAN SMITH']},
#    {'Studio': ['WHODAT', 'SCOTIA', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 27, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['Ø [PHASE]', 'HARUKA', 'COTTON']},
#    {'Studio': ['SEDEF ADASÏ', 'SUCCUBASS', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 26, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RØDHAD', 'HOLDEN FEDERICO']},
#    {'Studio': ['PAURRO', 'ANALOG SOUL', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'RON LIKE HELL']},
#    {'Studio': ['BUDINO', 'LIAD KRISPIN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 19, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['LUKE SLATER',
#      'MAX WATTS',
#      'ERIC UMBLE']},
#    {'Studio': ['MIKE SERVITO', 'SHAUN J. WRIGHT', 'DEEP CREEP']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 13, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['UVB', 'MAREENA', 'AUSPEX']},
#    {'Studio': ['BÉZIER', 'DEVOYE', 'WHODAT']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 12, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['MIKE DEARBORN',
#      'FALSEBOI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['OSSX', 'ROSE KOURTS', 'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 6, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'NØRBAK', 'UMFANG']},
#    {'Studio': ['PROSUMER', 'JASON KENDIG', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2024, 7, 5, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': []},
#  {'event_detail_date': datetime.datetime(2024, 6, 29, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['VOLVOX', 'KATIE REX', 'VILE']},
#    {'Studio': ['HARUKA', 'LINDO (JOTA B2B VICENTA)', 'RYAN FARR']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 28, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SCHACKE',
#      'ANNIE LEW',
#      'MOS',
#      'MORENXXX']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'DJ HOLOGRAPHIC', 'JEFFREY SFIRE']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 22, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['ANTHONY PARASOLE',
#      'AMX',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['JENNIFER CARDINI', 'DAVID ELIMELECH', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['YONTI',
#      'ELLE DEE',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['THE CARRY NATION', 'PARTOK', 'DONIS']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 15, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['FIEDEL',
#      'VEL',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MATRIXXMAN', 'SEKUCCI', 'STERLING JUAN DIAZ', 'NATUTA']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 14, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SCHWEFELGELB', 'CHLOE LULA', 'ANA B']},
#    {'Studio': ['DEE DIGGS', 'ANALOG SOUL', 'ELI ESCOBAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 8, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['BARKER', 'TERENCE FIXMER', 'LYDO']},
#    {'Studio': ['ADAB', 'KFEELZ', 'ANTOJITO']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 7, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TRUNCATE', 'TAPEFEED', 'ROLA']},
#    {'Studio': ['DJ PIERRE', 'JUSTIN CUDMORE', 'BOYS’ SHORTS']}]},
#  {'event_detail_date': datetime.datetime(2024, 6, 1, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['SHAUN J. WRIGHT',
#      'RON LIKE HELL',
#      'RYAN SMITH']},
#    {'Studio': ['BARONHAWK POITIER', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 31, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY 313',
#      'JULIANA HUXTABLE',
#      'ALEX.COSMOS']},
#    {'Studio': ['CINTHIE', 'CHRIS CRUSE', 'JACOB MEEHAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 25, 22, 30),
#   'event_detail_title': 'SPANDAU20 NIGHT',
#   'event_detail_music': [{'Basement': ['FJAAK LIVE',
#      'ELLI ACULA',
#      'ANNA Z.',
#      'J.MANUEL']},
#    {'Studio': ['KEVIN AVIANCE', 'X3BUTTERFLY', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 24, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RYKER']},
#    {'Studio': ['JASON KENDIG', 'SEKUCCI', 'GEE DEE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 18, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['MARY YUZOVSKAYA',
#      'NE/RE/A',
#      'RYAN SMITH']},
#    {'Studio': ['TAMA SUMO', 'LAKUTI', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 17, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['KATIE REX',
#      'KYRUH',
#      'ANDI',
#      'ARVIN T',
#      'PURE IMMANENCE']},
#    {'Studio': ['JIMMY EDGAR', 'JUBILEE', 'CHOQUE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 11, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ BONE', 'DEVOYE', 'ELLE DEE']},
#    {'Studio': ['MARCELLUS PITTMAN', 'MIKE SERVITO', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 10, 22, 30),
#   'event_detail_title': 'RECLAIM YOUR CITY',
#   'event_detail_music': [{'Basement': ['STERAC', 'KR!Z', 'LYCHEE']},
#    {'Studio': ['RICK WADE', 'HARUKA', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 4, 22, 30),
#   'event_detail_title': 'BASEMENT ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['BEN KLOCK', 'NEWA', 'ÆON', 'COTTON']},
#    {'Studio': ['LYDO', 'JEK', 'MATAS', 'MEILGAARDEN', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2024, 5, 3, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER', 'AMOTIK', 'AUSPEX']},
#    {'Studio': ['VICKI POWELL', 'WILL AUTOMAGIC', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 27, 22, 30),
#   'event_detail_title': 'BASSIANI NIGHT',
#   'event_detail_music': [{'Basement': ['FADI MOHEM',
#      'KANCHELI',
#      'PHILIPPA PACHO',
#      'NDRX']},
#    {'Studio': ['KIM ANN FOXMAN', 'MATAS', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 26, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['PARRISH SMITH',
#      'SAUSHA',
#      'KATIE REX']},
#    {'Studio': ['MAKADSI', 'DJ MISS PARKER', 'FLIRTY800']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['RON LIKE HELL', 'RYAN SMITH']},
#    {'Studio': ['LEONCE', 'KEENAN ORR', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 19, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'CONCRETE HUSBAND',
#      'KXAH']},
#    {'Studio': ['ANALOG SOUL', 'MOMA READY', 'TORIBIO']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 13, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['STEF MENDESIDIS',
#      'CHLÄR',
#      'IAN CRANE']},
#    {'Studio': ['SANDRIEN', 'JASON KENDIG', 'PERFECT LOVERS']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 12, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'HADONE', 'ANNIE LEW']},
#    {'Studio': ['COMO SE DJ', 'RYKER', 'OZA']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 6, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['LINDSEY HERBERT',
#      'NONCOMPLIANT',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['ETAPP KYLE', 'THE CARRY NATION', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2024, 4, 5, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['MCMLXXXV', 'SALOME', 'FASHION']},
#    {'Studio': ['CEM', 'DJ SALIVA', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 30, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['NØRBAK', 'ESTHER DUNE', 'AUSPEX']},
#    {'Studio': ['CLARISA KIMSKII', 'COLORED CRAIG', 'MIKE SERVITO']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 29, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['BJARKI',
#      'ELLE DEE',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['YHA YHA', 'MOMA READY', 'MASHA MAR']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 23, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['JAMAICA SUK', 'VOLVOX', 'LYDO']},
#    {'Studio': ['ARIEL ZETINA', 'BOUFFANT BOUFFANT', 'CURSES']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DRUMCELL', 'KANGDING RAY', 'ÆON']},
#    {'Studio': ['THE CARRY NATION', 'IAN CRANE', 'NSPERGER']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['PARTOK']},
#    {'Studio': ['\u200b\u200bT.WAN']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 15, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FRANÇOIS X',
#      'UFO95 LIVE',
#      'SEVYN 0000']},
#    {'Studio': ['JEK', 'MATAS', 'ADOBEPRINCESS']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 9, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['KI/KI', 'COMO SE DJ']},
#    {'Studio': ['ROI PEREZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ELLI ACULA', 'VOLVOX', 'MOS']},
#    {'Studio': ['KEVIN AVIANCE', 'MUTUALISM', 'SPRKLBB', 'FATHERHOOD']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 2, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REGAL', 'BAUGRUPPE90', 'ANNIE LEW']},
#    {'Studio': ['MCR-T', 'X-COAST', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2024, 3, 1, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN',
#      'CHLOE LULA',
#      'ARVIN T']},
#    {'Studio': ['10 YEARS TIME PASSAGES: BINH', 'EVAN BAGGS']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 24, 22, 30),
#   'event_detail_title': 'DWELLER',
#   'event_detail_music': [{'Basement': ['ROBERT HOOD', 'DEVOYE', 'DAIYAH']},
#    {'Studio': ['SHAUN J. WRIGHT', 'MISS TWINK USA', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 23, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['CLOUDS', 'SHYBOI', 'KATIE REX']},
#    {'Studio': ['JACQ JILL', 'KIA', 'AL V DAM']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FREDDY K']},
#    {'Studio': ['THE CARRY NATION', 'JACOB MEEHAN', 'MAKADSI']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 16, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HARUKA',
#      'CLARISA KIMSKII',
#      'SPLOOFI',
#      'NICOLÒ BERNARDI']},
#    {'Studio': ['ELI ESCOBAR', 'NOMI RUIZ', 'JOSH STEERS']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 10, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['AARON CLARK',
#      'ARIEL ZETINA',
#      'LYCHEE',
#      'RON LIKE HELL',
#      'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 9, 22, 30),
#   'event_detail_title': 'FAST FORWARD NIGHT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'NEWA', 'RYKER']},
#    {'Studio': ['SCHACKE', 'X3BUTTERFLY', 'JEK']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 3, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HENNING BAER',
#      'ESTELLA BOERSMA',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['DJ MINX', 'GABRIELLE KWARTENG', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2024, 2, 2, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'ORPHX',
#      'MUERTE LENTA']},
#    {'Studio': ['ANALOG SOUL', 'ROSE KOURTS', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 27, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['TRUNCATE',
#      'AMANDA MUSSI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['BORED LORD', 'KILOPATRAH JONES', 'ANTOJITO']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['KYRUH', 'RON LIKE HELL']},
#    {'Studio': ['SOLAR & MOZHGAN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2024, 1, 13, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['LADY STARLIGHT LIVE',
#      'HIROKO YAMAMURA',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['PARTOK', 'CROMBY', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 16, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'BEATRICE', 'LYDO']},
#    {'Studio': ['NEWA', 'JASON KENDIG', 'IAN CRANE']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 15, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['PERC',
#      'JULIANA HUXTABLE',
#      'WORD OF COMMAND']},
#    {'Studio': ['KEVIN AVIANCE', 'NATUTA', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 2, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JUANA', 'RYAN SMITH']},
#    {'Studio': ['WNGDU', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 12, 1, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SLAM', 'FLAVIA LAUS', 'ERIC UMBLE']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'DAVID ELIMELECH', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'PHILIPPA PACHO',
#      'MARCO NEVES']},
#    {'Studio': ['GABRIELLE KWARTENG', 'THE CARRY NATION', 'KIA']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'RANDOMER', 'ÆON']},
#    {'Studio': ['DJ HOLOGRAPHIC', 'GIDEÖN', 'JACOB MEEHAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 11, 22, 30),
#   'event_detail_title': 'BITE NITE',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHASE FATALE',
#      'VULKANSKI']},
#    {'Studio': ['PABLO BOZZI', 'SUCCUBASS', 'NE/RE/A']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'VOLVOX',
#      'PAULA KOSKI']},
#    {'Studio': ['DAN SHAKE', 'JASON KENDIG', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['WTCHCRFT', 'RON LIKE HELL']},
#    {'Studio': ['FATHER DUKES', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 11, 3, 22, 30),
#   'event_detail_title': 'Herrensauna',
#   'event_detail_music': [{'Basement': ['MCMLXXXV',
#      'FUTURE.666',
#      'SEVYN 0000']},
#    {'Studio': ['CEM', 'OR:LA', 'DJ SALIVA']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 28, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['NUR JABER', 'KATIE REX', 'ANNIE LEW']},
#    {'Studio': ['X CLUB.', 'JEK', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 27, 18, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['KANGDING RAY',
#      'CLARISA KIMSKII',
#      'NE/RE/A',
#      'CONNOR WRONG']},
#    {'Studio': ['TAMA SUMO', 'LAKUTI', 'MIKE SERVITO', 'CHOQUE']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY',
#      'FADI MOHEM',
#      'SPLOOFI']},
#    {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY',
#      'FADI MOHEM',
#      'SPLOOFI']},
#    {'Studio': ['JADALAREIGN', 'HARUKA', '4AM NYC']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 14, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RØDHÅD', 'NDRX', 'LYDO']},
#    {'Studio': ['MATAS', 'COMO SE DJ', 'MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 13, 0, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REBEKAH', 'SOMEWHEN', 'LISAS']},
#    {'Studio': ['KETIA', 'MANU MIRAN', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 7, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['NONCOMPLIANT',
#      'MATRIXXMAN',
#      'RYAN SMITH']},
#    {'Studio': ['KHIDJA', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 10, 6, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['LEWIS FAUTZI',
#      'LAURA BCR',
#      'COTTON',
#      'AUSPEX']},
#    {'Studio': ['NITA AVIANCE',
#      'MIKE SERVITO',
#      'MICHAEL MAGNAN',
#      'ALISSA BRIANNA']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 30, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['D.DAN', 'ELLE DEE']},
#    {'Studio': ['HYPERAKTIVIST', 'YAZZUS', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 29, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['CHLOE LULA',
#      'BRYAN KASENIC',
#      'YOUNG MALE']},
#    {'Studio': ['HAAI', 'STERLING JUAN DIAZ', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 23, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LEESH', 'RON LIKE HELL']},
#    {'Studio': ['BÉZIER', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TALISMANN',
#      'KYRUH',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['SALOME', 'MATAS', 'RYKER']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 16, 22, 30),
#   'event_detail_title': 'MORD NIGHT',
#   'event_detail_music': [{'Basement': ['BAS MOOY', 'QUELZA', 'ANTENES']},
#    {'Studio': ['ELI ESCOBAR', 'LOVE LETTERS', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 15, 22, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['MAMA SNAKE',
#      'KANCHELI',
#      'ALEX.COSMOS']},
#    {'Studio': ['ISABELLA', 'CHRIS CRUSE', 'HARUKA']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 9, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['NASTIA',
#      'LOBSTER',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['ASH LAURYN', 'MOMA READY', 'ARIEL ME LLAMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SCHACKE', 'EGOTOT', 'ÆON']},
#    {'Studio': ['DJ SALIVA', 'ADOBEPRINCESS', 'COMO SE DJ']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 2, 22, 30),
#   'event_detail_title': 'PORNCEPTUAL',
#   'event_detail_music': [{'Basement': ['FLAVIA LAUS',
#      'DEEPNEUE',
#      'KATIE REX']},
#    {'Studio': ['THE CARRY NATION', 'JEFFREY SFIRE', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 9, 1, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['EFDEMIN',
#      'SETAOC MASS',
#      'SPLOOFI',
#      'NICOLÒ BERNARDI']},
#    {'Studio': ['KEVIN AVIANCE', 'JASON KENDIG', 'KIM ANH']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 26, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['.VRIL LIVE', 'YONTI', 'ELLE DEE']},
#    {'Studio': ['ROI PEREZ', 'GIDEÖN', 'MEILGAARDEN']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 19, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['DINA',
#      'MORENXXX',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['PANGAEA', 'HONEY BUN', 'FLIRTY800']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 12, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['DUSTIN ZAHN',
#      'LENNART WIEHE',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['BEIGE', 'SPRKLBB']}]},
#  {'event_detail_date': datetime.datetime(2023, 8, 5, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ERIKA', 'RON LIKE HELL']},
#    {'Studio': ['DAVIS GALVIN', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 29, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JAMES RUSKIN',
#      'DEVOYE',
#      'TOMÁS URQUIETA']},
#    {'Studio': ['SEKUCCI', 'MISS PARKER', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 28, 22, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'AMOTIK', 'ELLE DEE']},
#    {'Studio': ['MUTUALISM', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 22, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['KANGDING RAY',
#      'MARY YUZOVSKAYA',
#      'AUSPEX']},
#    {'Studio': ['JADALAREIGN', 'STERLING JUAN DIAZ', 'DAY THIEF']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII',
#      'UMFANG',
#      'YOUNG MALE']},
#    {'Studio': ['MIKE SERVITO', 'DEE DIGGS']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 15, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARK PRICE', 'RYAN SMITH']},
#    {'Studio': ['MEZ', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 14, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ BONE',
#      'ANALOG SOUL',
#      'ROSE KOURTS']},
#    {'Studio': ['PEREL', 'FATHERHOOD']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HENNING BAER',
#      'RON LIKE HELL',
#      'LYCHEE']},
#    {'Studio': ['ELI ESCOBAR', 'KIM ANH', 'NATUTA']}]},
#  {'event_detail_date': datetime.datetime(2023, 7, 7, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['QUEST?ONMARQ',
#      '1MORNING',
#      'MUERTE LENTA',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MISS TWINK USA', 'JEK', 'DEEP CREEP']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 30, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HEADLESS HORSEMAN',
#      'MADNESS OF',
#      'L.SANGRE']},
#    {'Studio': ['GERD JANSON', 'MAKADSI', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 24, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['FIEDEL', 'FASHION', 'KATIE REX']},
#    {'Studio': ['ULTRATHEM', 'WINTER WRONG', 'SISTER ZO', 'CHOQUE']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 23, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['LYDO',
#      'KYRUH',
#      'DAIYAH',
#      'CONCRETE HUSBAND']},
#    {'Studio': ['MASSIMILIANO PAGLIARA',
#      'TAMA SUMO',
#      'LAKUTI',
#      'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SCHACKE', 'NDRX', 'ELLE DEE']},
#    {'Studio': ['NDRX', 'LAUREN FLAX', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 16, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['SLAM',
#      'ISABELLA KOEN',
#      'COTTON',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['BAUGRUPPE90', 'SEVYN 0000', 'SEKUCCI']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DASHA RUSH', 'TAPEFEED', 'JAY YORK']},
#    {'Studio': ['FOR FUTURES SAKE', 'DJ RAQX', 'DX7']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 9, 22, 30),
#   'event_detail_title': 'VESELKA',
#   'event_detail_music': [{'Basement': ['PEACHLYFE', 'TWEEMAN', 'ANA B']},
#    {'Studio': ['THE CARRY NATION', 'JASON KENDIG', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 3, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['KIM ANN FOXMAN', 'RON LIKE HELL']},
#    {'Studio': ['SHAUN J. WRIGHT', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 6, 2, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHASE FATALE',
#      'CHLOE LULA']},
#    {'Studio': ['CHRIS CRUSE', 'PARTOK']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 27, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII',
#      'SANDRIEN',
#      'HOLDEN FEDERICO']},
#    {'Studio': ['BINH', 'JEK', 'HANK JACKSON']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 26, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SURGEON', 'ETAPP KYLE', 'UMFANG']},
#    {'Studio': ['JASON KENDIG', 'DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 20, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ADAB', 'RON LIKE HELL']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 19, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['WALLIS', 'KATIE REX', 'SPEEDY SPICE']},
#    {'Studio': ['DEE DIGGS', 'MICHAEL MAGNAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 13, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SCALAMERIYA',
#      'FLAVIA LAUS',
#      'STARRK',
#      'AUSPEX']},
#    {'Studio': ['JUANA', 'LOVE LETTERS', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 12, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'MANNI DEE',
#      'WTCHCRFT']},
#    {'Studio': ['EZY', 'MANU MIRAN', 'X3BUTTERFLY']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 6, 22, 30),
#   'event_detail_title': 'BASEMENT ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['FREDDY K', 'BEATRICE', 'LYDO']},
#    {'Studio': ['JEK', 'MATAS', 'MUTUALISM', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2023, 5, 5, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['THOMAS P. HECKMANN',
#      'YOUNG MALE',
#      'ELLE DEE']},
#    {'Studio': ['ANALOG SOUL', 'MIKE SERVITO', 'DEVOYE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 29, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'LYDO', 'KATIE REX']},
#    {'Studio': ['CINTHIE', 'JADALAREIGN', 'SAVILE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 28, 22, 30),
#   'event_detail_title': 'L.I.E.S. NIGHT',
#   'event_detail_music': [{'Basement': ['LEGOWELT',
#      'VERONICA VASICKA',
#      'L.SANGRE']},
#    {'Studio': ['RON MORELLI', 'TRAXX', 'SWEATER ON POLO']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 22, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['SCHWEFELGELB',
#      'ANDI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['KETIA', '8ULENTINA']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 21, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SHDW & OBSCURE SHAPE',
#      'LARS HUISMANN',
#      'CHONTANE']},
#    {'Studio': ['THE CARRY NATION', 'ELI ESCOBAR', 'COSMO', 'DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 15, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JURI HEIDEMANN',
#      'TOMÁS URQUIETA',
#      'LYDO']},
#    {'Studio': ['KIERNAN LAVEAUX', 'JOSELO']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 14, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'PHILIPP STROBEL',
#      'MOTIVE-A']},
#    {'Studio': ['CARLOS SOUFFRONT', 'GALCHER LUSTWERK', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REBEKAH',
#      'TALISMANN',
#      'LYCHEE',
#      'GUILT ATTENDANT']},
#    {'Studio': ['HUERCO S', 'DEBONAIR', 'SIGNIFICANT OTHER', 'ONLY CHILD']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 7, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['DJ HYPERACTIVE',
#      'CLARISA KIMSKII',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['MIKE SERVITO', 'MADISON MOORE']}]},
#  {'event_detail_date': datetime.datetime(2023, 4, 1, 0, 0),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['T.WAN', 'RON LIKE HELL']},
#    {'Studio': ['FATHERHOOD', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 31, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REGAL',
#      'PHILIPPA PACHO',
#      'BLUE HOUR',
#      'LISAS']},
#    {'Studio': ['RACHEL NOON', 'MOHAJER', 'NICK BAZZANO']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 25, 22, 30),
#   'event_detail_title': 'MALA JUNTA',
#   'event_detail_music': [{'Basement': ['HYPERAKTIVIST', 'YAZZUS', 'KYRUH']},
#    {'Studio': ['DJ TOOL', 'WHY BE', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 24, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DR. RUBINSTEIN',
#      'DARIA KOLOSOVA',
#      'WTCHCRFT']},
#    {'Studio': ['X-COAST', 'DAVID ELIMELECH', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'FREDDY K', 'LYDO']},
#    {'Studio': ['JASON KENDIG', 'JEK', 'MISS PARKER']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TAKAAKI ITOH',
#      'HIROKO YAMAMURA',
#      'UMFANG']},
#    {'Studio': ['DJ MINX', 'MIKE SERVITO', 'LOVE LETTERS', 'HONEY BUN']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 11, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DRUMCELL', 'TIN MAN', 'ELLE DEE']},
#    {'Studio': ['MARCELLUS PITTMAN', 'DEE DIGGS', 'DJ RAQX']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER',
#      'STEYA',
#      'DEEPAK SHARMA']},
#    {'Studio': ['ANALOG SOUL', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['AKUA', 'LYCHEE', 'FURTIVE']},
#    {'Studio': ['RON LIKE HELL', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 3, 3, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['ADRIANA LOPEZ', 'UUN', 'AUSPEX']},
#    {'Studio': ['ARIEL ZETINA', 'MUTUALISM', 'MANU MIRAN']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 25, 22, 30),
#   'event_detail_title': 'DWELLER',
#   'event_detail_music': [{'Basement': ['TERRENCE DIXON',
#      'MAX WATTS',
#      'JUANA']},
#    {'Studio': ['FRED P', 'ETTA']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 24, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANTHONY PARASOLE', 'VOLVOX', 'ANA B']},
#    {'Studio': ['JUSTIN CUDMORE', 'RELAXER', 'SPF 50']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'KYRUH', 'JEK']},
#    {'Studio': ['GERD JANSON', 'DEE DIGGS', 'JASON KENDIG']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TRUNCATE', 'ANALOG SOUL', 'LYCHEE']},
#    {'Studio': ['DJ PIERRE', 'LAUREN FLAX', 'HEIDI SABERTOOTH']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 11, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['MANNI DEE', 'KATIE REX', 'LISAS']},
#    {'Studio': ['ACEMO', 'ROSE KOURTS', 'TURTLE BUGG']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 10, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['RYAN JAMES FORD',
#      'BAPARI',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MCR-T', 'SISTER ZO', 'MATAS']}]},
#  {'event_detail_date': datetime.datetime(2023, 2, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['PAUL FLEETWOOD', 'RON LIKE HELL']},
#    {'Studio': ['DJ VOICES', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 28, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SPFDJ', 'SCHACKE', 'JEK']},
#    {'Studio': ['NEWA', 'FKA.M4A']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 21, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['BLOODY MARY',
#      'YOUNG MALE',
#      'JUSTIN CUDMORE']},
#    {'Studio': ['FATHERHOOD', 'SYBIL JASON']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 14, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SLAM', 'DENISE RABE', 'AUSPEX']},
#    {'Studio': ['LEEON', 'JASON KENDIG', 'ANALOG SOUL']}]},
#  {'event_detail_date': datetime.datetime(2023, 1, 7, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['MIKE PARKER', 'AKUA', '1MORNING']},
#    {'Studio': ['LYDO', 'SCHACKE', 'DEVOYE']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 17, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'PEACHLYFE', 'UMFANG']},
#    {'Studio': ['BORIS', 'JEK']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 16, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['WTCHCRFT', 'KATIE REX']},
#    {'Studio': ['JENNIFER CARDINI', 'ANALOG SOUL']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DVS1', 'BEATRICE', 'LYDO']},
#    {'Studio': ['ROI PEREZ', 'PARTOK']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 9, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['VIPER DIVA',
#      'UFO95',
#      'SPEEDY SPICE',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['FALSE WITNESS', 'OZA', 'COSMO']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 3, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['AMX', 'RYAN SMITH']},
#    {'Studio': ['DEEP CREEP', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 12, 2, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY 313', 'PERC', 'AKUA']},
#    {'Studio': ['THE CARRY NATION', 'DEE DIGGS']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 19, 0, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RØDHÅD', 'KANGDING RAY', 'AKUA']},
#    {'Studio': ['ANDREW JAMES GUSTAV', 'GIO SHENGELIA']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN',
#      'WTCHCRFT',
#      'ANA B']},
#    {'Studio': ['SHAUN J. WRIGHT', 'MIKE SERVITO']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 12, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DAX J', 'NEWA', 'TT']},
#    {'Studio': ['REGULARFANTASY', 'JASON KENDIG', 'DEE DIGGS']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 11, 22, 30),
#   'event_detail_title': 'Balance',
#   'event_detail_music': [{'Basement': ['MARCEL FENGLER',
#      'AADJA',
#      'MUTUALISM']},
#    {'Studio': ['LUIGI DI VENERE', 'STATHIS', 'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 5, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['SHARLESE', 'RON LIKE HELL']},
#    {'Studio': ['MIDLAND', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 11, 4, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS',
#      'STEF MENDESIDIS',
#      'LYDO']},
#    {'Studio': ['NDRX', 'DARIA KOLOSOVA']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 28, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['DOLLHOUSE', 'HIM HUN', 'KATIE REX']},
#    {'Studio': ['BOUDOIR: ADAM UNKNOWN',
#      'BRICKLAYER',
#      'MATH3CA',
#      'MS. MANGO',
#      'MX. BLAIRE']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SOMEWHEN', 'NUR JABER', 'ANA B']},
#    {'Studio': ['X-COAST', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 21, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['CLERIC', 'P.E.A.R.L.', 'AUSPEX']},
#    {'Studio': ['CASHU', 'MADISON MOORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 15, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['DEVOYE', 'RON LIKE HELL']},
#    {'Studio': ['SISTER SYSTEM', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 14, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'SCHWEFELGELB',
#      'PHILIPP STROBEL']},
#    {'Studio': ['DJ WAWA', 'HONEY BUN']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 8, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['ETAPP KYLE',
#      'KYRUH',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['MICHAEL MAGNAN', 'STERLING JUAN DIAZ']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 7, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RROSE', 'ZADIG', 'LYCHEE']},
#    {'Studio': ['MIKE SERVITO', 'PAÀL']}]},
#  {'event_detail_date': datetime.datetime(2022, 10, 1, 0, 0),
#   'event_detail_title': 'Herrensauna',
#   'event_detail_music': [{'Basement': ['CEM', 'TT', 'SAUSHA']},
#    {'Studio': ['MCMLXXXV', 'DJ SALIVA', 'SISTER ZO']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 30, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'EGOTOT',
#      'SHYBOI']},
#    {'Studio': ['GABRIELLE KWARTENG', '8ULENTINA', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 24, 0, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANETHA', 'AADJA', 'ANA B']},
#    {'Studio': ['DJ GIGOLA', 'X-COAST']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 23, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DANIEL AVERY', 'UMFANG']},
#    {'Studio': ['INTERSTELLAR FUNK', 'RELAXER']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 17, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['CLARISA KIMSKII', 'RYAN SMITH']},
#    {'Studio': ['JACOB MEEHAN', 'FATHER FIGURE']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 16, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['WATA IGARASHI',
#      'ALEJANDRO FRANCO',
#      'ANTENES']},
#    {'Studio': ['THE CARRY NATION', 'DEE DIGGS', 'KILOPATRAH JONES']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 10, 0, 0),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['REGAL', 'MADWOMAN', 'AUSPEX']},
#    {'Studio': ['EFDEMIN', 'LAUREN FLAX']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 10, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['RANDOMER',
#      'PHILIPPA PACHO',
#      'WORD OF COMMAND',
#      'DJ CLONE']},
#    {'Studio': ['KIM ANN FOXMAN', 'ONIO', 'ULTRATHEM']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 3, 0, 0),
#   'event_detail_title': 'FAST FORWARD NIGHT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'EZY', 'TT']},
#    {'Studio': ['SCHACKE', 'PEACHLYFE']}]},
#  {'event_detail_date': datetime.datetime(2022, 9, 2, 22, 0),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['999999999', 'VOLVOX', 'MADNESS OF']},
#    {'Studio': ['MASSIMILIANO PAGLIARA', 'RYAN ELLIOTT', 'ROSE KOURTS']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 27, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['LUKE SLATER', 'BEATRICE', 'UMFANG']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 20, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['NONCOMPLIANT',
#      'MIKE DEARBORN',
#      'JUSTIN CUDMORE',
#      'AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 13, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['AKUA',
#      'ANA B',
#      'GABBERBITCH69',
#      'LIMITBREAK!',
#      'WORD OF COMMAND',
#      'DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 8, 6, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['SUCCUBASS',
#      'MIKE SERVITO',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 29, 0, 0),
#   'event_detail_title': 'L.I.E.S. NIGHT',
#   'event_detail_music': [{'Basement': ['RON MORELLI', 'SILENT SERVANT']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 23, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['ALPHA TRACKS',
#      'ESTOC',
#      'SAUSHA',
#      'SUNRISE HUNTER',
#      'WORD OF COMMAND',
#      'DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TAPEFEED',
#      'VERONICA VASICKA',
#      'MOMENT OF TERROR']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['VICKI POWELL',
#      'MANU MIRAN',
#      'JUANA',
#      'DEE DIGGS',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 15, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FREDDY K', 'PANGAEA', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 9, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['CTRLS', 'REN G', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REBEKAH', 'STARKK']}]},
#  {'event_detail_date': datetime.datetime(2022, 7, 2, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['JAMES RUSKIN',
#      'VOLVOX',
#      'JUANA',
#      'JUSTIN CUDMORE',
#      'HIROKO YAMAMURA']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 30, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['D.DAN', 'PEACHLYFE', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 25, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['SUGAR', 'TT', 'KATIE REX']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 24, 22, 30),
#   'event_detail_title': 'HERRENSAUNA',
#   'event_detail_music': [{'Basement': ['CEM', 'MCMLXXXV', 'ISABELLA KOEN']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'MAX WATTS', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 17, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['FIEDEL', 'AKUA', 'AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 11, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REGIS', 'YOUNG MALE', 'L.SANGRE']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 10, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANSWER CODE REQUEST',
#      'SILENT SERVANT',
#      'JANUARY HUNT']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 4, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['BÉZIER',
#      'RON LIKE HELL',
#      'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2022, 6, 3, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['PARTOK',
#      'MADISON MOORE',
#      'KIM ANN FOXMAN']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 28, 22, 30),
#   'event_detail_title': 'STAUB',
#   'event_detail_music': [{'Basement': ['OSCAR MULERO', 'IRAKLI', 'ANTENES']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 27, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['VAGUE MÉCANIQUE LIVE',
#      'TERENCE FIXMER',
#      'PHASE FATALE',
#      'IREEN AMNES']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 21, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['ABAJOUR',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 14, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TIN MAN',
#      'MIKE SERVITO',
#      'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 13, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['KILBOURNE',
#      'AIDEN',
#      'S&M',
#      'BURNER ACCOUNT',
#      'DJ CLONE',
#      'WORD OF COMMAND']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 7, 22, 30),
#   'event_detail_title': 'BASEMENT ANNIVERSARY',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'LYDO',
#      'TT',
#      'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2022, 5, 6, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['REGAL', 'VOLVOX', 'WTCHCRFT']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 30, 22, 30),
#   'event_detail_title': 'EXALT',
#   'event_detail_music': [{'Basement': ['MATRIXXMAN', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 29, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['TOMMY FOUR SEVEN',
#      'THAM',
#      'DAIYAH']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 23, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['LOKIER', 'KATIE REX', 'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 22, 22, 30),
#   'event_detail_title': 'aufnahme + wiedergabe',
#   'event_detail_music': [{'Basement': ['NE/RE/A']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 16, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['RYAN SMITH', 'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 15, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['TRUNCATE',
#      'SHAUN J. WRIGHT',
#      'MADISON MOORE',
#      'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 9, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['RROSE', 'KANGDING RAY', 'LYCHEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 8, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['LYDO', 'WORD OF COMMAND', 'ANA B']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 2, 22, 30),
#   'event_detail_title': 'MORD NIGHT',
#   'event_detail_music': [{'Basement': ['BAS MOOY', 'ANSOME', 'YOUNG MALE']}]},
#  {'event_detail_date': datetime.datetime(2022, 4, 1, 22, 30),
#   'event_detail_title': 'ALTÆR',
#   'event_detail_music': [{'Basement': ['SNTS', 'NUR JABER', 'AUSPEX']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 26, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['NE/RE/A']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 25, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['BLUE HOUR',
#      'TYGAPAW',
#      'MEMPHY',
#      'DJ CLONE',
#      'WORD OF COMMAND']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 19, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['BORIS',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 18, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['FUNCTION', 'ELLE DEE']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 12, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['HÉCTOR OAKS', 'RACHEL NOON', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 11, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['SARA LANDRY',
#      'XIORRO',
#      'YOUNG MALE']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 5, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['DJ STINGRAY', 'KYRUH', 'WTCHCRFT']}]},
#  {'event_detail_date': datetime.datetime(2022, 3, 4, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['BEN KLOCK', 'UMFANG']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 26, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['LIVWUTANG',
#      'RYAN SMITH',
#      'RON LIKE HELL']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 19, 22, 30),
#   'event_detail_title': 'FIST',
#   'event_detail_music': [{'Basement': ['SHLØMO',
#      'ARIEL ZETINA',
#      'JANUARY HUNT',
#      'WORD OF COMMAND',
#      'DJ CLONE']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 12, 22, 30),
#   'event_detail_title': 'X-TRA.SERVICES',
#   'event_detail_music': [{'Basement': ['PEACHLYFE', 'MORENXXX', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 2, 5, 22, 30),
#   'event_detail_title': 'BALANCE',
#   'event_detail_music': [{'Basement': ['JULIANA HUXTABLE',
#      'VINCENT NEUMANN',
#      'JUSTIN CUDMORE']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 29, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANETHA', 'SOMEWHEN', 'TT']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 22, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['ANCIENT METHODS',
#      'FIEDEL',
#      'DAIYAH']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 15, 22, 30),
#   'event_detail_title': 'POSSESSION',
#   'event_detail_music': [{'Basement': ['PARFAIT', 'D.DAN', 'LYDO']}]},
#  {'event_detail_date': datetime.datetime(2022, 1, 7, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['I HATE MODELS', 'NDRX', 'KYRUH']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 18, 22, 30),
#   'event_detail_title': 'WRECKED',
#   'event_detail_music': [{'Basement': ['JASON KENDIG', 'RYAN SMITH']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 11, 22, 30),
#   'event_detail_title': 'BOUND BLACKOUT',
#   'event_detail_music': [{'Basement': ['ETAPP KYLE',
#      'FALSE WITNESS',
#      'KATIE REX',
#      'NIGHT DOLL']}]},
#  {'event_detail_date': datetime.datetime(2021, 12, 4, 22, 30),
#   'event_detail_title': '',
#   'event_detail_music': [{'Basement': ['PERC', 'ANTPUKE']}]}]

# %%
import pandas as pd

# Suppose event_data_list is already defined

rows = []
for event in event_data_list:
    date = event["event_detail_date"]
    title = event["event_detail_title"]
    for stage_dict in event["event_detail_music"]:
        for stage, dj_list in stage_dict.items():
            for dj in dj_list:
                rows.append({
                    "date": date,
                    "event_title": title,
                    "stage": stage,
                    "DJ": dj
                })

df = pd.DataFrame(rows)
print(df)
# Out:
#                     date     event_title     stage             DJ
# 0    2025-03-08 22:30:00                  Basement        DJ BONE
# 1    2025-03-08 22:30:00                  Basement   MIKE SERVITO
# 2    2025-03-08 22:30:00                  Basement    ROSE KOURTS
# 3    2025-03-08 22:30:00                    Studio        FKA.M4A
# 4    2025-03-08 22:30:00                    Studio   JASON KENDIG
# ...                  ...             ...       ...            ...
# 1443 2021-12-11 22:30:00  BOUND BLACKOUT  Basement  FALSE WITNESS
# 1444 2021-12-11 22:30:00  BOUND BLACKOUT  Basement      KATIE REX
# 1445 2021-12-11 22:30:00  BOUND BLACKOUT  Basement     NIGHT DOLL
# 1446 2021-12-04 22:30:00                  Basement           PERC
# 1447 2021-12-04 22:30:00                  Basement        ANTPUKE
#
# [1448 rows x 4 columns]

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_excel("event_data.xlsx", index=False)

# %%
def split_by_basement(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()

    blocks = []
    current_block = []
    for line in lines:
        # Check if the stripped line is exactly "BASEMENT"
        if line.strip() == "BASEMENT":
            # If we have accumulated lines, join them into one string and add to blocks
            if current_block:
                blocks.append("".join(current_block).rstrip())
                current_block = []
        else:
            current_block.append(line)
    
    # Optionally, add any remaining content as the last block
    if current_block:
        blocks.append("".join(current_block).rstrip())
    
    return blocks

# Example usage:
if __name__ == "__main__":
    file_path = "basement_text.txt"  # Replace with your file path
    blocks = split_by_basement(file_path)
    for i, block in enumerate(blocks, start=1):
        print(f"Block {i}:\n{block}\n{'-'*40}\n")
# Out:
# Block 1:
# ̸November 2021
# RA Pick
# 'Wrecked: TYGAPAW / Ron Like Hell / Ryan Smith' flyer image
# Sat, 20 Nov 2021
# Wrecked: TYGAPAW / Ron Like Hell / Ryan Smith
#
# ̸
# TYGAPAW, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 2:
# 787
# Wrecked bosses Ron Like Hell and Ryan Smith invite the Jamaican-born, New York-based powerhouse to their long-running monthly party for a night of raw and relentless energy.
# 'Sonic Groove Night: Adam X / Frankie Bones / MAEDON / Realmz' flyer image
# Sat, 13 Nov 2021
# Sonic Groove Night: Adam X / Frankie Bones / MAEDON / Realmz
#
# ̸
# Frankie Bones, MAEDON, Realmz
# New York City
# ----------------------------------------
#
# Block 3:
# 442
# 'Fist: Isabella / Loka / Miss Parker / Joselo b2b Fried Plátano / Word of Command b2b DJ Clone' flyer image
# Sat, 6 Nov 2021
# Fist: Isabella / Loka / Miss Parker / Joselo b2b Fried Plátano / Word of Command b2b DJ Clone
#
# ̸
# Miss Parker, JOSELO, Word of Command, DJ Clone, DJ Clone
# New York City
# ----------------------------------------
#
# Block 4:
# 529
# ̸October 2021
# 'Bound Blackout: D.Dan / Katie Rex / Daiyah' flyer image
# Sat, 23 Oct 2021
# Bound Blackout: D.Dan / Katie Rex / Daiyah
#
# ̸
# D.Dan, Katie Rex, DAIYAH
# New York City
# ----------------------------------------
#
# Block 5:
# 736
# 'FJAAK / Umfang / Akua' flyer image
# Fri, 22 Oct 2021
# FJAAK / Umfang / Akua
#
# ̸
# FJAAK, Umfang, Akua
# New York City
# ----------------------------------------
#
# Block 6:
# 951
# 'Wrecked' flyer image
# Sat, 16 Oct 2021
# Wrecked
#
# ̸
# Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 7:
# 777
# 'Sara Landry / Volvox / Juana' flyer image
# Sat, 9 Oct 2021
# Sara Landry / Volvox / Juana
#
# ̸
# Sara Landry, Volvox, Juana
# New York City
# ----------------------------------------
#
# Block 8:
# 674
# RA Pick
# Sat, 2 Oct 2021
# Function
#
# ̸
# Function
# New York City
# ----------------------------------------
#
# Block 9:
# 527
# Here's a clever double-header: a techno mainstay you should already know, and a Tbilisi DJ making waves in her local scene (and beyond—Ben Klock is a fan) who you should get to know immediately.
# ̸September 2021
# 'Wrecked with Honcho' flyer image
# Sat, 25 Sep 2021
# Wrecked with Honcho
#
# ̸
# Honcho, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 10:
# 867
# 'Robert Hood / Aurora Halal / Fadeface' flyer image
# Fri, 24 Sep 2021
# Robert Hood / Aurora Halal / Fadeface
#
# ̸
# Robert Hood, Aurora Halal, FadeFace
# New York City
# ----------------------------------------
#
# Block 11:
# 938
# 'FadeFace / Damon Bradley / LISAS' flyer image
# Fri, 17 Sep 2021
# FadeFace / Damon Bradley / LISAS
#
# ̸
# FadeFace, Damon Bradley, LISAS
# New York City
# ----------------------------------------
#
# Block 12:
# 525
# 'Fist: Lydo / TT b2b DJ Salazar / Buzzi / Word of Command b2b DJ Clone' flyer image
# Sat, 11 Sep 2021
# Fist: Lydo / TT b2b DJ Salazar / Buzzi / Word of Command b2b DJ Clone
#
# ̸
# LYDO, TT (NYC), Buzzi, Word of Command, DJ Clone
# New York City
# ----------------------------------------
#
# Block 13:
# 581
# 'Regis / Headless Horseman / Becka Diamond' flyer image
# Fri, 10 Sep 2021
# Regis / Headless Horseman / Becka Diamond
#
# ̸
# Headless Horseman, Becka Diamond
# New York City
# ----------------------------------------
#
# Block 14:
# 504
# 'Bite Night: Phase Fatale / Silent Servant / Abby Echiverri' flyer image
# Sat, 4 Sep 2021
# Bite Night: Phase Fatale / Silent Servant / Abby Echiverri
#
# ̸
# Phase Fatale, Silent Servant, Abby Echiverri
# New York City
# ----------------------------------------
#
# Block 15:
# 626
# ̸August 2021
# 'Dvs1 / Volvox' flyer image
# Sat, 28 Aug 2021
# Dvs1 / Volvox
#
# ̸
# DVS1, Volvox
# New York City
# ----------------------------------------
#
# Block 16:
# 949
# 'Veronica Vasicka / Ron Morelli / January Hunt' flyer image
# Sat, 21 Aug 2021
# Veronica Vasicka / Ron Morelli / January Hunt
#
# ̸
# Veronica Vasicka, Ron Morelli, January Hunt
# New York City
# ----------------------------------------
#
# Block 17:
# 674
# 'DJ Stingray / Akua / Elle Dee' flyer image
# Sat, 14 Aug 2021
# DJ Stingray / Akua / Elle Dee
#
# ̸
# Akua, Elle Dee
# New York City
# ----------------------------------------
#
# Block 18:
# 758
# RA Pick
# 'Lsdxoxo / Newa' flyer image
# Sat, 7 Aug 2021
# Lsdxoxo / Newa
#
# ̸
# LSDXOXO, Newa
# New York City
# ----------------------------------------
#
# Block 19:
# 846
# One of New York's most unique techno clubs is reopening, and they've invited Berlin's sexiest techno specialist to play.
# ̸December 2020
# 'Ostgut Ton Nacht' flyer image
# Sat, 5 Dec 2020
# Ostgut Ton Nacht
#
# ̸
# New York City
# ----------------------------------------
#
# Block 20:
# 133
# ̸June 2020
# 'United We Stream x Basement' flyer image
# Wed, 24 Jun 2020
# United We Stream x Basement
#
# ̸
# Anthony Parasole, Mike Servito, Rachel Noon, Volvox, Xiorro
# New York City
# ----------------------------------------
#
# Block 21:
# 11
# 'United We Stream / Live From Basement' flyer image
# Tue, 2 Jun 2020
# United We Stream / Live From Basement
#
# ̸
# Anthony Parasole, Mike Servito, Rachel Noon, Volvox, Xiorro
# New York City
# ----------------------------------------
#
# Block 22:
# 11
# ̸March 2020
# '[POSTPONED] Bound: Blackout with Somewhen / Nur Jaber / Katie Rex' flyer image
# Fri, 27 Mar 2020
# [POSTPONED] Bound: Blackout with Somewhen / Nur Jaber / Katie Rex
#
# ̸
# Somewhen, Nur Jaber, Katie Rex
# New York City
# ----------------------------------------
#
# Block 23:
# 153
# RA Pick
# '[CANCELLED] 9-Years of Wrecked with Boris' flyer image
# Sat, 21 Mar 2020
# [CANCELLED] 9-Years of Wrecked with Boris
#
# ̸
# Boris
# New York City
# ----------------------------------------
#
# Block 24:
# 210
# Wrecked celebrates a massive anniversary with a massive guest: Berghain's very own Boris.
# '[POSTPONED] Boston 168 / Joey Quiñones / Pure Immanence' flyer image
# Fri, 20 Mar 2020
# [POSTPONED] Boston 168 / Joey Quiñones / Pure Immanence
#
# ̸
# Boston 168, Joey Quinones, Pure Immanence
# New York City
# ----------------------------------------
#
# Block 25:
# 47
# RA Pick
# '[POSTPONED] Fist with Blue Hour / Ariel Zetina / Miss Parker' flyer image
# Sat, 14 Mar 2020
# [POSTPONED] Fist with Blue Hour / Ariel Zetina / Miss Parker
#
# ̸
# Blue Hour, Ariel Zetina, Miss Parker, DJ Clone, Word of Command
# New York City
# ----------------------------------------
#
# Block 26:
# 70
# Though her diverse sound touches everything from Chicago house, soca, ballroom to pop, Chicago's Ariel Zetina will probably tap into her collection of dramatic, but always jacking techno for this Fist night.
# '[POSTPONED] Balance with Claire Morgan / Bloody Mary / Michael Magnan' flyer image
# Fri, 13 Mar 2020
# [POSTPONED] Balance with Claire Morgan / Bloody Mary / Michael Magnan
#
# ̸
# Claire Morgan, Bloody Mary, Michael Magnan, Justin Cudmore
# New York City
# ----------------------------------------
#
# Block 27:
# 31
# RA Pick
# 'Derrick May / Analog Soul' flyer image
# Fri, 6 Mar 2020
# Derrick May / Analog Soul
#
# ̸
# Derrick May, Analog Soul
# New York City
# ----------------------------------------
#
# Block 28:
# 260
# Break a sweat with one of techno's founding fathers, Derrick May, and the ceaselessly exciting and unpredictable Analog Soul.
# ̸February 2020
# 'Altær: Henning Baer / VSK / Volvox / Auspex' flyer image
# Sat, 29 Feb 2020
# Altær: Henning Baer / VSK / Volvox / Auspex
#
# ̸
# VSK, Henning Baer, Volvox, Auspex
# New York City
# ----------------------------------------
#
# Block 29:
# 283
# RA Pick
# 'Pangaea / Galcher Lustwerk / Lauren Flax' flyer image
# Fri, 28 Feb 2020
# Pangaea / Galcher Lustwerk / Lauren Flax
#
# ̸
# Pangaea, Galcher Lustwerk, Lauren Flax
# New York City
# ----------------------------------------
#
# Block 30:
# 246
# Hip-house, broken techno and Lauren Flax's electro hybrids make for another loose and varied night at BASEMENT.
# RA Pick
# 'Levon Vincent / Tin Man / Justin Cudmore' flyer image
# Sat, 22 Feb 2020
# Levon Vincent / Tin Man / Justin Cudmore
#
# ̸
# Levon Vincent, Tin Man, Justin Cudmore
# New York City
# ----------------------------------------
#
# Block 31:
# 145
# Melodic, intricate and uplifting techno all night thanks to this motley trio.
# 'Wrecked with Juana / Ron Like Hell / Ryan Smith' flyer image
# Sat, 15 Feb 2020
# Wrecked with Juana / Ron Like Hell / Ryan Smith
#
# ̸
# Juana, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 32:
# 333
# 'SHDW & Obscure Shape/ Damon Bradley / Adrestia' flyer image
# Fri, 14 Feb 2020
# SHDW & Obscure Shape/ Damon Bradley / Adrestia
#
# ̸
# SHDW, Obscure Shape, Damon Bradley, Adrestia
# New York City
# ----------------------------------------
#
# Block 33:
# 98
# RA Pick
# Sat, 8 Feb 2020
# Randomer / LYDO
#
# ̸
# Randomer, LYDO
# New York City
# ----------------------------------------
#
# Block 34:
# 390
# Rarely do kicks hit as hard as those in a Randomer track. Infectious melodies and oftentimes indecipherable offbeat rhythms are reflected in this producer's music and DJ sets. Schacke, who topped our best tracks of 2019 list, brings his fast 'n' fun pop techno. X-TRA.SERVICES founder Lydo matches energy with blistering relentless sets that have been recently received by Berghain and Boiler Room.
# 'Rebekah / Shlømo / GIA' flyer image
# Fri, 7 Feb 2020
# Rebekah / Shlømo / GIA
#
# ̸
# Rebekah, Shlømo, GIA
# New York City
# ----------------------------------------
#
# Block 35:
# 220
# RA Pick
# '999999999 / Parallx / Joey Quinones' flyer image
# Sat, 1 Feb 2020
# 999999999 / Parallx / Joey Quinones
#
# ̸
# 999999999, Parallx, Joey Quinones
# New York City
# ----------------------------------------
#
# Block 36:
# 449
# 999999999's recent Boiler Room shows off what the Italian duo know best: high BPM, nose-bleed techno with zipping acid synth lines to transport you into outer space.
# ̸January 2020
# 'Vril Live / ATEQ / LISAS' flyer image
# Fri, 31 Jan 2020
# Vril Live / ATEQ / LISAS
#
# ̸
# ATEQ, LISAS
# New York City
# ----------------------------------------
#
# Block 37:
# 147
# 'Regis / Fiedel / Ne/Re/A' flyer image
# Sat, 25 Jan 2020
# Regis / Fiedel / Ne/Re/A
#
# ̸
# Fiedel, Ne/Re/A
# New York City
# ----------------------------------------
#
# Block 38:
# 195
# RA Pick
# 'Balance with Matrixxman / Sandrien / Jason Kendig b2b Mike Servito' flyer image
# Fri, 24 Jan 2020
# Balance with Matrixxman / Sandrien / Jason Kendig b2b Mike Servito
#
# ̸
# Matrixxman, Sandrien, Jason Kendig, Mike Servito, Justin Cudmore
# New York City
# ----------------------------------------
#
# Block 39:
# 251
# Futurism is a key element in Matrixxman's music, and the result is dystopian, sci-fi techno with controlled transitions built to drive you into a state of euphoria.
# RA Pick
# 'Wrecked with Madison Moore' flyer image
# Sat, 18 Jan 2020
# Wrecked with Madison Moore
#
# ̸
# Madison Moore, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 40:
# 327
# Another installment of Wrecked brings Madison Moore. His days helming the London party Opulence helped him cultivate the boisterous, peak-time techno sets he's so revered for.
# 'Basement: Talks #1' flyer image
# Sat, 18 Jan 2020
# Basement: Talks #1
#
# ̸
# Madison Moore, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 41:
# 9
# 'Xiorro / Auspex / FadeFace' flyer image
# Fri, 17 Jan 2020
# Xiorro / Auspex / FadeFace
#
# ̸
# Xiorro, Auspex, FadeFace
# New York City
# ----------------------------------------
#
# Block 42:
# 107
# RA Pick
# 'Fist with Perc / Baby Blue / Word of Command / DJ Clone' flyer image
# Sat, 11 Jan 2020
# Fist with Perc / Baby Blue / Word of Command / DJ Clone
#
# ̸
# Perc, Word of Command, DJ Clone
# New York City
# ----------------------------------------
#
# Block 43:
# 398
# London's Perc has been holding it down as a taste-making label head, producer and DJ for nearly two decades. His pounding techno should rattle the BASEMENT's concrete walls.
# 'Veronica Vasicka / Hieroglyphic Being Live / John Barera' flyer image
# Fri, 10 Jan 2020
# Veronica Vasicka / Hieroglyphic Being Live / John Barera
#
# ̸
# Veronica Vasicka, Hieroglyphic Being, John Barera
# New York City
# ----------------------------------------
#
# Block 44:
# 55
# 'The Bunker with Haruka / Mike Servito x Derek Plaslaiko / Clay Wilson x rrao' flyer image
# Sat, 4 Jan 2020
# The Bunker with Haruka / Mike Servito x Derek Plaslaiko / Clay Wilson x rrao
#
# ̸
# Mike Servito, Derek Plaslaiko, Clay Wilson, rrao
# New York City
# ----------------------------------------
#
# Block 45:
# 189
# ̸December 2019
# RA Pick
# 'Aurora Halal / Umfang / Auspex' flyer image
# Sat, 21 Dec 2019
# Aurora Halal / Umfang / Auspex
#
# ̸
# Aurora Halal, Umfang, Auspex
# New York City
# ----------------------------------------
#
# Block 46:
# 332
# Boss and resident of the monthly techno party, Dominion, Auspex pushes harsh sounds that bridge grating industrial and hard-hitting techno for your evening dose of euphoria.
# 'Ryan Elliott / Fatherhood / Joey Quiñones' flyer image
# Fri, 20 Dec 2019
# Ryan Elliott / Fatherhood / Joey Quiñones
#
# ̸
# Ryan Elliott, Fatherhood, Joey Quinones
# New York City
# ----------------------------------------
#
# Block 47:
# 67
# RA Pick
# 'Anthony Parasole / Steve Bicknell / 0.001' flyer image
# Sat, 14 Dec 2019
# Anthony Parasole / Steve Bicknell / 0.001
#
# ̸
# Anthony Parasole, Steve Bicknell
# New York City
# ----------------------------------------
#
# Block 48:
# 99
# An American techno titan meets a British one for a night of thunderous beats.
# RA Pick
# 'The Bunker x Smoke Machine: Agonis / Diskonnected / Erika x Antenes / Abby Echiverri' flyer image
# Fri, 13 Dec 2019
# The Bunker x Smoke Machine: Agonis / Diskonnected / Erika x Antenes / Abby Echiverri
#
# ̸
# Agonis, Diskonnected, Erika, Antenes, Abby Echiverri
# New York City
# ----------------------------------------
#
# Block 49:
# 110
# Taiwan techno comes to New York with the Smoke Machine crew, whose heads-down techno sound should blend right in with The Bunker's style.
# RA Pick
# 'Wrecked with LSDXOXO / Ron Like Hell / Ryan Smith' flyer image
# Sat, 7 Dec 2019
# Wrecked with LSDXOXO / Ron Like Hell / Ryan Smith
#
# ̸
# LSDXOXO, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 50:
# 348
# LSDXOXO and New York's Basement is an ideal match, and his raunchy club sound will be pummeling the concrete of the vast subterranean venue til late.
# 'FJAAK / Rachel Noon / Word of Command' flyer image
# Fri, 6 Dec 2019
# FJAAK / Rachel Noon / Word of Command
#
# ̸
# FJAAK, Rachel Noon, Word of Command
# New York City
# ----------------------------------------
#
# Block 51:
# 237
# ̸November 2019
# RA Pick
# 'New York Trax x Voitax' flyer image
# Sat, 30 Nov 2019
# New York Trax x Voitax
#
# ̸
# Makaton, Swarm Intelligence, Brenecki, Deflector, Cressida, Paàl
# New York City
# ----------------------------------------
#
# Block 52:
# 68
# Brooklyn-based label New York Trax has a knack for curating some of the most cutting-edge and brilliantly weird acts making their mark in the city.
# 'Dasha Rush / Evigt Mörker / The Long Count Cycle' flyer image
# Sat, 23 Nov 2019
# Dasha Rush / Evigt Mörker / The Long Count Cycle
#
# ̸
# Dasha Rush, Evigt Mörker, Long Count Cycle
# New York City
# ----------------------------------------
#
# Block 53:
# 162
# RA Pick
# 'FIST with VTSS / New World Dysorder' flyer image
# Fri, 22 Nov 2019
# FIST with VTSS / New World Dysorder
#
# ̸
# VTSS, Jasmine Infiniti, Cali Rose, DJ Clone, Word of Command
# New York City
# ----------------------------------------
#
# Block 54:
# 289
# Jasmine Infiniti's New World Dysorder crew will tear BASEMENT a new one alongside industrial techno head VTSS, all the way from Poland, courtesy of FIST.
# 'Wrecked Residents Night with Ron Like Hell Ryan Smith all Night' flyer image
# Sat, 16 Nov 2019
# Wrecked Residents Night with Ron Like Hell Ryan Smith all Night
#
# ̸
# Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 55:
# 289
# RA Pick
# 'Objekt / Pearson Sound / Heidi Sabertooth' flyer image
# Fri, 15 Nov 2019
# Objekt / Pearson Sound / Heidi Sabertooth
#
# ̸
# Objekt, Pearson Sound, Heidi Sabertooth
# New York City
# ----------------------------------------
#
# Block 56:
# 474
# A UK dance music one-two punch with otherworldly beats courtesy of both Objekt and Pearson Sound.
# RA Pick
# 'Cxema Backstage' flyer image
# Sat, 9 Nov 2019
# Cxema Backstage
#
# ̸
# Voin Oruwu, Hyperaktivist, Relaxer
# New York City
# ----------------------------------------
#
# Block 57:
# 242
# Get to know Cxema, a Ukrainian cultural organization that seeks to further the cause of electronic music in Eastern Europe—and get to know them through some killer techno.
# 'Polegroup Night with Oscar Mulero / Adriana Lopez / Deepak Sharma' flyer image
# Fri, 8 Nov 2019
# Polegroup Night with Oscar Mulero / Adriana Lopez / Deepak Sharma
#
# ̸
# Oscar Mulero, Adriana Lopez, Deepak Sharma
# New York City
# ----------------------------------------
#
# Block 58:
# 178
# RA Pick
# '[CANCELLED] Xiorro / Auspex / Fadeface' flyer image
# Sat, 2 Nov 2019
# [CANCELLED] Xiorro / Auspex / Fadeface
#
# ̸
# Xiorro, Auspex, FadeFace
# New York City
# ----------------------------------------
#
# Block 59:
# 91
# Techno heads only. Pummeling bass and mobilizing rhythms reign supreme at another BASEMENT rager.
# Fri, 1 Nov 2019
# Function Album Tour
#
# ̸
# Function
# New York City
# ----------------------------------------
#
# Block 60:
# 16
# RA Pick
# 'Function / Ndrx' flyer image
# Fri, 1 Nov 2019
# Function / Ndrx
#
# ̸
# Function, Ndrx
# New York City
# ----------------------------------------
#
# Block 61:
# 157
# With over 20 years in the game, Berghain resident Function returns to home turf.
# ̸October 2019
# RA Pick
# 'Wrecked with Carlos Souffront' flyer image
# Sat, 26 Oct 2019
# Wrecked with Carlos Souffront
#
# ̸
# Carlos Souffront, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 62:
# 410
# Unafraid to throw down his expansive selection of abrasive and off kilter techno, Carlos Souffront has been moving dance floors with his eclectic sound since the '90s.
# RA Pick
# 'Bound: Blackout with Terence Fixmer / Volvox B2B Amanda Mussi / Latex Lucifer B2B Katie Rex' flyer image
# Fri, 25 Oct 2019
# Bound: Blackout with Terence Fixmer / Volvox B2B Amanda Mussi / Latex Lucifer B2B Katie Rex
#
# ̸
# Terence Fixmer, Volvox, Amanda Mussi, Katie Rex
# New York City
# ----------------------------------------
#
# Block 63:
# 367
# Name something more enticing than swarms of fetish gear, a high-intensity soundtrack from French techno powerhouse Terence Fixmer, and the endless, fog-filled tunnels of the BASEMENT.
# RA Pick
# 'DJ Skull / Verraco / Adrestia' flyer image
# Sat, 19 Oct 2019
# DJ Skull / Verraco / Adrestia
#
# ̸
# DJ Skull, Verraco, Adrestia
# New York City
# ----------------------------------------
#
# Block 64:
# 48
# Verraco is one of the most important and talented DJs and producers in Colombian techno history (and he mixed a great RA Podcast too). See him alongside Chicago vet DJ Skull and New York's own Adrestia for an essential triple-header.
# RA Pick
# 'Joey Beltram / Tin Man / Bryan Kasenic' flyer image
# Fri, 18 Oct 2019
# Joey Beltram / Tin Man / Bryan Kasenic
#
# ̸
# Joey Beltram, Tin Man, Bryan Kasenic
# New York City
# ----------------------------------------
#
# Block 65:
# 153
# This Basement night has another lineup to boast about - catch techno pioneer Joey Beltram alongside Tin Man and Bryan Kasenic for a night promising techno, trickling acid and beyond.
# 'Ancient Methods B2B Vatican Shadow / Ne/Re/A' flyer image
# Fri, 11 Oct 2019
# Ancient Methods B2B Vatican Shadow / Ne/Re/A
#
# ̸
# Ancient Methods, Vatican Shadow, Ne/Re/A
# New York City
# ----------------------------------------
#
# Block 66:
# 257
# 'Joel Mull / Young Male' flyer image
# Sat, 5 Oct 2019
# Joel Mull / Young Male
#
# ̸
# Joel Mull, Young Male
# New York City
# ----------------------------------------
#
# Block 67:
# 36
# RA Pick
# 'Anastasia Kristensen / John Barera' flyer image
# Fri, 4 Oct 2019
# Anastasia Kristensen / John Barera
#
# ̸
# Anastasia Kristensen, John Barera
# New York City
# ----------------------------------------
#
# Block 68:
# 59
# There's never a dull moment at Anastasia Kristensen's sets. Joined by John Barera, these two are equipped with the freshest techno.
# ̸September 2019
# RA Pick
# 'Shifted / SNTS / Aurora Halal' flyer image
# Sat, 28 Sep 2019
# Shifted / SNTS / Aurora Halal
#
# ̸
# Shifted, SNTS, Aurora Halal
# New York City
# ----------------------------------------
#
# Block 69:
# 292
# Big sounds from three heavy-hitting producers will form a world within the walls of Basement this weekend.
# 'Daniel Avery / Rachel Noon' flyer image
# Fri, 27 Sep 2019
# Daniel Avery / Rachel Noon
#
# ̸
# Daniel Avery, Rachel Noon
# New York City
# ----------------------------------------
#
# Block 70:
# 299
# 'Wrecked with Dr. Rubinstein' flyer image
# Sat, 21 Sep 2019
# Wrecked with Dr. Rubinstein
#
# ̸
# Dr. Rubinstein, Ryan Smith, Ron Like Hell
# New York City
# ----------------------------------------
#
# Block 71:
# 392
# 'Ellen Allien / Volvox / Juana' flyer image
# Fri, 20 Sep 2019
# Ellen Allien / Volvox / Juana
#
# ̸
# Ellen Allien, Volvox, Juana
# New York City
# ----------------------------------------
#
# Block 72:
# 525
# 'The Bunker with Wata Igarashi / Aleksi Perala / Batu / Patrick Russell / LDY OSC' flyer image
# Fri, 13 Sep 2019
# The Bunker with Wata Igarashi / Aleksi Perala / Batu / Patrick Russell / LDY OSC
#
# ̸
# Wata Igarashi, Batu, Patrick Russell, LDY OSC
# New York City
# ----------------------------------------
#
# Block 73:
# 378
# 'Balance with Vincent Neumann / Shaun J. Wright' flyer image
# Sat, 7 Sep 2019
# Balance with Vincent Neumann / Shaun J. Wright
#
# ̸
# Vincent Neumann, Shaun J. Wright, Justin Cudmore
# New York City
# ----------------------------------------
#
# Block 74:
# 94
# RA Pick
# 'Phase Fatale / Unhuman / Abby Echiverri' flyer image
# Fri, 6 Sep 2019
# Phase Fatale / Unhuman / Abby Echiverri
#
# ̸
# Phase Fatale, Unhuman, Abby Echiverri
# New York City
# ----------------------------------------
#
# Block 75:
# 166
# Get bitten by the sharp industrial techno sounds of BITE with label reps Phase Fatale and Unhuman.
# ̸August 2019
# 'Adam X / Roman / Ne/Re/A' flyer image
# Sat, 31 Aug 2019
# Adam X / Roman / Ne/Re/A
#
# ̸
# Ròman, Ne/Re/A
# New York City
# ----------------------------------------
#
# Block 76:
# 184
# 'Quo Vadis: STERAC / Clay Wilson + rrao [Live] / Soren Roi [Live] / Proteus (UK)' flyer image
# Fri, 30 Aug 2019
# Quo Vadis: STERAC / Clay Wilson + rrao [Live] / Soren Roi [Live] / Proteus (UK)
#
# ̸
# STERAC, Clay Wilson, rrao, Proteus
# New York City
# ----------------------------------------
#
# Block 77:
# 62
# RA Pick
# 'Juliana Huxtable / Heidi Sabertooth' flyer image
# Sat, 24 Aug 2019
# Juliana Huxtable / Heidi Sabertooth
#
# ̸
# Juliana Huxtable, Heidi Sabertooth
# New York City
# ----------------------------------------
#
# Block 78:
# 211
# NYC mainstay Juliana Huxtable and avant garde electronic artist Heidi Sabertooth are not to be messed with. The two will bring driving, menacing sounds to Queens' newest techno club.
# RA Pick
# 'DJ Stingray / Brenecki / Auspex' flyer image
# Sat, 17 Aug 2019
# DJ Stingray / Brenecki / Auspex
#
# ̸
# Brenecki, Auspex
# New York City
# ----------------------------------------
#
# Block 79:
# 390
# DJ Stingray delivers non-stop action-packed sets while maintaining a level of focus that's almost scary. Come see why they say he's one of the best in the game.
# Sat, 10 Aug 2019
# FIST with Special Guest / Umfang
#
# ̸
# Umfang, Word of Command
# New York City
# ----------------------------------------
#
# Block 80:
# 223
# RA Pick
# Sat, 3 Aug 2019
# Wrecked with Partok / Ron Like Hell / Ryan Smith
#
# ̸
# Partok, Ryan Smith, Ron Like Hell
# New York City
# ----------------------------------------
#
# Block 81:
# 312
# Partok, a key figure in Tel Aviv's queer scene and now a Berghain regular, joins the WRECKED residents at their new home.
# ̸July 2019
# RA Pick
# 'Vril [Live] / Julia Govor / Dasha Redkina / Relaxer' flyer image
# Sat, 27 Jul 2019
# Vril [Live] / Julia Govor / Dasha Redkina / Relaxer
#
# ̸
# Julia Govor, Dasha Redkina, Relaxer
# New York City
# ----------------------------------------
#
# Block 82:
# 152
# Julia Govor is one of New York's most inventive techno DJs—so go see her in one of the city's premiere techno venues.
# 'Matrixxman / Nthng' flyer image
# Fri, 26 Jul 2019
# Matrixxman / Nthng
#
# ̸
# Matrixxman, nthng
# New York City
# ----------------------------------------
#
# Block 83:
# 175
# RA Pick
# 'Bassiani Night with Héctor Oaks / Ndrx' flyer image
# Sat, 20 Jul 2019
# Bassiani Night with Héctor Oaks / Ndrx
#
# ̸
# Héctor Oaks, Ndrx
# New York City
# ----------------------------------------
#
# Block 84:
# 209
# Two star DJs from the Georgian techno temple touch down for a gig in the dungeon.
# 'SHDW & Obscure Shape / Damon Bradley' flyer image
# Fri, 19 Jul 2019
# SHDW & Obscure Shape / Damon Bradley
#
# ̸
# SHDW, Obscure Shape, Damon Bradley
# New York City
# ----------------------------------------
#
# Block 85:
# 163
# 'Broken English Club / Thomas Hessler / FadeFace [Live]' flyer image
# Sat, 13 Jul 2019
# Broken English Club / Thomas Hessler / FadeFace [Live]
#
# ̸
# Broken English Club, Thomas Hessler, FadeFace
# New York City
# ----------------------------------------
#
# Block 86:
# 48
# 'Ben Sims / Tapefeed / Ne/Re/A' flyer image
# Fri, 12 Jul 2019
# Ben Sims / Tapefeed / Ne/Re/A
#
# ̸
# Ben Sims, Tapefeed, Ne/Re/A
# New York City
# ----------------------------------------
#
# Block 87:
# 87
# RA Pick
# 'FOURTH WORLD' flyer image
# Sat, 6 Jul 2019
# FOURTH WORLD
#
# ̸
# Joey Beltram, Galcher Lustwerk, The Carry Nation, Gooddroid, Cali Rose, J. Albert, Long Count Cycle, Logan Takahashi, Dee Diggs, AceMo, Rachel Noon, Kiki Kudo, Olive T, motiv-a, GIA, January Hunt, LYDO, Adrestia, Shy Eyez, Octonomy, pH (12), Pure Immanence, Gaul Plus, Toribio, Alonzo, Donny Burlin, Rob Seurat, DJ Healthy
# New York City
# ----------------------------------------
#
# Block 88:
# 364
# The iconic Independence Day celebration is back for another year, with a jaw-dropping lineup that shows exactly how much local talent the Brooklyn scene boasts.
# RA Pick
# 'Answer Code Request / Mary Yuzovskaya' flyer image
# Fri, 5 Jul 2019
# Answer Code Request / Mary Yuzovskaya
#
# ̸
# Answer Code Request, Mary Yuzovskaya
# New York City
# ----------------------------------------
#
# Block 89:
# 178
# Answer Code Request, a techno DJ with a refreshingly unorthodox approach, plays alongside Mary Yuzovskaya, a secret weapon of the Brooklyn afterhours scene.
# ̸June 2019
# 'Somewhen / Juana / Xiorro' flyer image
# Sat, 29 Jun 2019
# Somewhen / Juana / Xiorro
#
# ̸
# Somewhen, Juana, Xiorro
# New York City
# ----------------------------------------
#
# Block 90:
# 123
# Fri, 28 Jun 2019
# Horse Meat Disco NYC Pride w/ Steffi, Aurora Halal
#
# ̸
# Horse Meat Disco, Steffi, Aurora Halal
# New York City
# ----------------------------------------
#
# Block 91:
# 23
# 'Etapp Kyle / Acronym / Katie Rex' flyer image
# Sat, 22 Jun 2019
# Etapp Kyle / Acronym / Katie Rex
#
# ̸
# Etapp Kyle, Acronym, Katie Rex
# New York City
# ----------------------------------------
#
# Block 92:
# 165
# 'Juan Atkins / Young Male / Auspex' flyer image
# Fri, 21 Jun 2019
# Juan Atkins / Young Male / Auspex
#
# ̸
# Juan Atkins, Young Male, Auspex
# New York City
# ----------------------------------------
#
# Block 93:
# 161
# 'Fiedel / Tin Man / Justin Cudmore' flyer image
# Fri, 14 Jun 2019
# Fiedel / Tin Man / Justin Cudmore
#
# ̸
# Fiedel, Tin Man, Justin Cudmore
# New York City
# ----------------------------------------
#
# Block 94:
# 108
# RA Pick
# 'Quo Vadis / Veronica Vasicka / L.Sangre / Orphx / O/H / Nihal Ramchandani' flyer image
# Sat, 8 Jun 2019
# Quo Vadis / Veronica Vasicka / L.Sangre / Orphx / O/H / Nihal Ramchandani
#
# ̸
# Veronica Vasicka, L.Sangre, Orphx, Nihal Ramchandani
# New York City
# ----------------------------------------
#
# Block 95:
# 171
# If you're into the darker, noisier side of dance music, this is your opportunity to check out New York's newest purpose-built techno club.
# RA Pick
# 'Function / Steve Bicknell / Sophia Saze' flyer image
# Fri, 7 Jun 2019
# Function / Steve Bicknell / Sophia Saze
#
# ̸
# Function, Steve Bicknell, Sophia Saze
# New York City
# ----------------------------------------
#
# Block 96:
# 219
# The catacomb-like passageways and pitch-black corners of this subterranean dance spot make it the ideal place to experience purist techno.
# 'FJAAK / Newa / Aurora Halal' flyer image
# Sat, 1 Jun 2019
# FJAAK / Newa / Aurora Halal
#
# ̸
# FJAAK, Newa, Aurora Halal
# New York City
# ----------------------------------------
#
# Block 97:
# 244
# ̸May 2019
# RA Pick
# 'Tommy Four Seven / Silent Servant / Katie Rex' flyer image
# Fri, 31 May 2019
# Tommy Four Seven / Silent Servant / Katie Rex
#
# ̸
# Tommy Four Seven, Silent Servant, Katie Rex
# New York City
# ----------------------------------------
#
# Block 98:
# 189
# It's a goth techno beatdown at New York's newest subterranean dance spot.
# '999999999 / Fabrizio Lapiana' flyer image
# Sat, 25 May 2019
# 999999999 / Fabrizio Lapiana
#
# ̸
# 999999999, Fabrizio Lapiana
# New York City
# ----------------------------------------
#
# Block 99:
# 214
# 'Staub with Luke Slater / Irakli / Caleb ESC / Adrestia' flyer image
# Fri, 24 May 2019
# Staub with Luke Slater / Irakli / Caleb ESC / Adrestia
#
# ̸
# Luke Slater, Irakli, Caleb ESC, Adrestia
# New York City
# ----------------------------------------
#
# Block 100:
# 191
# RA Pick
# 'Wrecked with CEM' flyer image
# Sat, 18 May 2019
# Wrecked with CEM
#
# ̸
# Wrecked, Ron Like Hell, Ryan Smith
# New York City
# ----------------------------------------
#
# Block 101:
# 290
# One of the city's sweatiest gay parties, headlined by a resident of the now famous Herrensauna in Berlin.
# 'Headless Horseman Live / Vatican Shadow / Volvox / Becka Diamond' flyer image
# Fri, 17 May 2019
# Headless Horseman Live / Vatican Shadow / Volvox / Becka Diamond
#
# ̸
# Headless Horseman, Vatican Shadow, Volvox, Becka Diamond
# New York City
# ----------------------------------------
#
# Block 102:
# 326
# RA Pick
# 'DVS1 / Bryan Kasenic' flyer image
# Sat, 11 May 2019
# DVS1 / Bryan Kasenic
#
# ̸
# DVS1, Bryan Kasenic
# New York City
# ----------------------------------------
#
# Block 103:
# 344
# Bushwick's new techno club celebrates opening weekend with a set from Midwestern rave renegade turned Berghain resident, DVS1.
# 'Rebekah / Heidi Sabertooth / Auspex / Ne/Re/A' flyer image
# Fri, 10 May 2019
# Rebekah / Heidi Sabertooth / Auspex / Ne/Re/A
#
# ̸
# Rebekah, Heidi Sabertooth, Auspex, Ne/Re/A
# New York City
# ----------------------------------------
#
# Block 104:
# 320
# ----------------------------------------

# %%
import re

def parse_block(block):
    # Split the block into individual lines
    lines = block.splitlines()
    
    # 1. Find the date: the first line that matches a day-of-week pattern.
    date_pattern = re.compile(r"^(Mon|Tue|Wed|Thu|Fri|Sat|Sun),\s+\d{1,2}\s+\w+\s+\d{4}$")
    date_line = None
    for line in lines:
        candidate = line.strip()
        if date_pattern.match(candidate):
            date_line = candidate
            break

    # 2. The second element: the line immediately above "New York City"
    ny_index = None
    for i, line in enumerate(lines):
        if line.strip() == "New York City":
            ny_index = i
            break
    ny_above = None
    if ny_index is not None:
        # Go backwards to find the first non-empty line before "New York City"
        j = ny_index - 1
        while j >= 0 and lines[j].strip() == "":
            j -= 1
        if j >= 0:
            ny_above = lines[j].strip()
    
    # 3. The third element: the last nonempty line before a delimiter "̸"
    delim_index = None
    for i, line in enumerate(lines):
        if line.strip() == "̸":
            delim_index = i
            break
    above_delim = None
    if delim_index is not None:
        # Look upward for the last non-empty line prior to the delimiter
        j = delim_index - 1
        while j >= 0 and lines[j].strip() == "":
            j -= 1
        if j >= 0:
            above_delim = lines[j].strip()
    
    return [date_line, ny_above, above_delim]

# Process each block and print the resulting list of three elements
parsed_blocks = [parse_block(block) for block in blocks][:-1]

# for i, elements in enumerate(parsed_blocks, start=1):
#     print(f"Block {i}:")
#     print(" Date:", elements[0])
#     print(" Above New York City:", elements[1])
#     print(" Above delimiter:", elements[2])
#     print("-" * 40)

parsed_blocks
# Out:
# [['Sat, 20 Nov 2021',
#   'TYGAPAW, Ron Like Hell, Ryan Smith',
#   'Wrecked: TYGAPAW / Ron Like Hell / Ryan Smith'],
#  ['Sat, 13 Nov 2021',
#   'Frankie Bones, MAEDON, Realmz',
#   'Sonic Groove Night: Adam X / Frankie Bones / MAEDON / Realmz'],
#  ['Sat, 6 Nov 2021',
#   'Miss Parker, JOSELO, Word of Command, DJ Clone, DJ Clone',
#   'Fist: Isabella / Loka / Miss Parker / Joselo b2b Fried Plátano / Word of Command b2b DJ Clone'],
#  ['Sat, 23 Oct 2021',
#   'D.Dan, Katie Rex, DAIYAH',
#   'Bound Blackout: D.Dan / Katie Rex / Daiyah'],
#  ['Fri, 22 Oct 2021', 'FJAAK, Umfang, Akua', 'FJAAK / Umfang / Akua'],
#  ['Sat, 16 Oct 2021', 'Ron Like Hell, Ryan Smith', 'Wrecked'],
#  ['Sat, 9 Oct 2021',
#   'Sara Landry, Volvox, Juana',
#   'Sara Landry / Volvox / Juana'],
#  ['Sat, 2 Oct 2021', 'Function', 'Function'],
#  ['Sat, 25 Sep 2021',
#   'Honcho, Ron Like Hell, Ryan Smith',
#   'Wrecked with Honcho'],
#  ['Fri, 24 Sep 2021',
#   'Robert Hood, Aurora Halal, FadeFace',
#   'Robert Hood / Aurora Halal / Fadeface'],
#  ['Fri, 17 Sep 2021',
#   'FadeFace, Damon Bradley, LISAS',
#   'FadeFace / Damon Bradley / LISAS'],
#  ['Sat, 11 Sep 2021',
#   'LYDO, TT (NYC), Buzzi, Word of Command, DJ Clone',
#   'Fist: Lydo / TT b2b DJ Salazar / Buzzi / Word of Command b2b DJ Clone'],
#  ['Fri, 10 Sep 2021',
#   'Headless Horseman, Becka Diamond',
#   'Regis / Headless Horseman / Becka Diamond'],
#  ['Sat, 4 Sep 2021',
#   'Phase Fatale, Silent Servant, Abby Echiverri',
#   'Bite Night: Phase Fatale / Silent Servant / Abby Echiverri'],
#  ['Sat, 28 Aug 2021', 'DVS1, Volvox', 'Dvs1 / Volvox'],
#  ['Sat, 21 Aug 2021',
#   'Veronica Vasicka, Ron Morelli, January Hunt',
#   'Veronica Vasicka / Ron Morelli / January Hunt'],
#  ['Sat, 14 Aug 2021', 'Akua, Elle Dee', 'DJ Stingray / Akua / Elle Dee'],
#  ['Sat, 7 Aug 2021', 'LSDXOXO, Newa', 'Lsdxoxo / Newa'],
#  ['Sat, 5 Dec 2020', '̸', 'Ostgut Ton Nacht'],
#  ['Wed, 24 Jun 2020',
#   'Anthony Parasole, Mike Servito, Rachel Noon, Volvox, Xiorro',
#   'United We Stream x Basement'],
#  ['Tue, 2 Jun 2020',
#   'Anthony Parasole, Mike Servito, Rachel Noon, Volvox, Xiorro',
#   'United We Stream / Live From Basement'],
#  ['Fri, 27 Mar 2020',
#   'Somewhen, Nur Jaber, Katie Rex',
#   '[POSTPONED] Bound: Blackout with Somewhen / Nur Jaber / Katie Rex'],
#  ['Sat, 21 Mar 2020', 'Boris', '[CANCELLED] 9-Years of Wrecked with Boris'],
#  ['Fri, 20 Mar 2020',
#   'Boston 168, Joey Quinones, Pure Immanence',
#   '[POSTPONED] Boston 168 / Joey Quiñones / Pure Immanence'],
#  ['Sat, 14 Mar 2020',
#   'Blue Hour, Ariel Zetina, Miss Parker, DJ Clone, Word of Command',
#   '[POSTPONED] Fist with Blue Hour / Ariel Zetina / Miss Parker'],
#  ['Fri, 13 Mar 2020',
#   'Claire Morgan, Bloody Mary, Michael Magnan, Justin Cudmore',
#   '[POSTPONED] Balance with Claire Morgan / Bloody Mary / Michael Magnan'],
#  ['Fri, 6 Mar 2020', 'Derrick May, Analog Soul', 'Derrick May / Analog Soul'],
#  ['Sat, 29 Feb 2020',
#   'VSK, Henning Baer, Volvox, Auspex',
#   'Altær: Henning Baer / VSK / Volvox / Auspex'],
#  ['Fri, 28 Feb 2020',
#   'Pangaea, Galcher Lustwerk, Lauren Flax',
#   'Pangaea / Galcher Lustwerk / Lauren Flax'],
#  ['Sat, 22 Feb 2020',
#   'Levon Vincent, Tin Man, Justin Cudmore',
#   'Levon Vincent / Tin Man / Justin Cudmore'],
#  ['Sat, 15 Feb 2020',
#   'Juana, Ron Like Hell, Ryan Smith',
#   'Wrecked with Juana / Ron Like Hell / Ryan Smith'],
#  ['Fri, 14 Feb 2020',
#   'SHDW, Obscure Shape, Damon Bradley, Adrestia',
#   'SHDW & Obscure Shape/ Damon Bradley / Adrestia'],
#  ['Sat, 8 Feb 2020', 'Randomer, LYDO', 'Randomer / LYDO'],
#  ['Fri, 7 Feb 2020', 'Rebekah, Shlømo, GIA', 'Rebekah / Shlømo / GIA'],
#  ['Sat, 1 Feb 2020',
#   '999999999, Parallx, Joey Quinones',
#   '999999999 / Parallx / Joey Quinones'],
#  ['Fri, 31 Jan 2020', 'ATEQ, LISAS', 'Vril Live / ATEQ / LISAS'],
#  ['Sat, 25 Jan 2020', 'Fiedel, Ne/Re/A', 'Regis / Fiedel / Ne/Re/A'],
#  ['Fri, 24 Jan 2020',
#   'Matrixxman, Sandrien, Jason Kendig, Mike Servito, Justin Cudmore',
#   'Balance with Matrixxman / Sandrien / Jason Kendig b2b Mike Servito'],
#  ['Sat, 18 Jan 2020',
#   'Madison Moore, Ron Like Hell, Ryan Smith',
#   'Wrecked with Madison Moore'],
#  ['Sat, 18 Jan 2020',
#   'Madison Moore, Ron Like Hell, Ryan Smith',
#   'Basement: Talks #1'],
#  ['Fri, 17 Jan 2020',
#   'Xiorro, Auspex, FadeFace',
#   'Xiorro / Auspex / FadeFace'],
#  ['Sat, 11 Jan 2020',
#   'Perc, Word of Command, DJ Clone',
#   'Fist with Perc / Baby Blue / Word of Command / DJ Clone'],
#  ['Fri, 10 Jan 2020',
#   'Veronica Vasicka, Hieroglyphic Being, John Barera',
#   'Veronica Vasicka / Hieroglyphic Being Live / John Barera'],
#  ['Sat, 4 Jan 2020',
#   'Mike Servito, Derek Plaslaiko, Clay Wilson, rrao',
#   'The Bunker with Haruka / Mike Servito x Derek Plaslaiko / Clay Wilson x rrao'],
#  ['Sat, 21 Dec 2019',
#   'Aurora Halal, Umfang, Auspex',
#   'Aurora Halal / Umfang / Auspex'],
#  ['Fri, 20 Dec 2019',
#   'Ryan Elliott, Fatherhood, Joey Quinones',
#   'Ryan Elliott / Fatherhood / Joey Quiñones'],
#  ['Sat, 14 Dec 2019',
#   'Anthony Parasole, Steve Bicknell',
#   'Anthony Parasole / Steve Bicknell / 0.001'],
#  ['Fri, 13 Dec 2019',
#   'Agonis, Diskonnected, Erika, Antenes, Abby Echiverri',
#   'The Bunker x Smoke Machine: Agonis / Diskonnected / Erika x Antenes / Abby Echiverri'],
#  ['Sat, 7 Dec 2019',
#   'LSDXOXO, Ron Like Hell, Ryan Smith',
#   'Wrecked with LSDXOXO / Ron Like Hell / Ryan Smith'],
#  ['Fri, 6 Dec 2019',
#   'FJAAK, Rachel Noon, Word of Command',
#   'FJAAK / Rachel Noon / Word of Command'],
#  ['Sat, 30 Nov 2019',
#   'Makaton, Swarm Intelligence, Brenecki, Deflector, Cressida, Paàl',
#   'New York Trax x Voitax'],
#  ['Sat, 23 Nov 2019',
#   'Dasha Rush, Evigt Mörker, Long Count Cycle',
#   'Dasha Rush / Evigt Mörker / The Long Count Cycle'],
#  ['Fri, 22 Nov 2019',
#   'VTSS, Jasmine Infiniti, Cali Rose, DJ Clone, Word of Command',
#   'FIST with VTSS / New World Dysorder'],
#  ['Sat, 16 Nov 2019',
#   'Ron Like Hell, Ryan Smith',
#   'Wrecked Residents Night with Ron Like Hell Ryan Smith all Night'],
#  ['Fri, 15 Nov 2019',
#   'Objekt, Pearson Sound, Heidi Sabertooth',
#   'Objekt / Pearson Sound / Heidi Sabertooth'],
#  ['Sat, 9 Nov 2019', 'Voin Oruwu, Hyperaktivist, Relaxer', 'Cxema Backstage'],
#  ['Fri, 8 Nov 2019',
#   'Oscar Mulero, Adriana Lopez, Deepak Sharma',
#   'Polegroup Night with Oscar Mulero / Adriana Lopez / Deepak Sharma'],
#  ['Sat, 2 Nov 2019',
#   'Xiorro, Auspex, FadeFace',
#   '[CANCELLED] Xiorro / Auspex / Fadeface'],
#  ['Fri, 1 Nov 2019', 'Function', 'Function Album Tour'],
#  ['Fri, 1 Nov 2019', 'Function, Ndrx', 'Function / Ndrx'],
#  ['Sat, 26 Oct 2019',
#   'Carlos Souffront, Ron Like Hell, Ryan Smith',
#   'Wrecked with Carlos Souffront'],
#  ['Fri, 25 Oct 2019',
#   'Terence Fixmer, Volvox, Amanda Mussi, Katie Rex',
#   'Bound: Blackout with Terence Fixmer / Volvox B2B Amanda Mussi / Latex Lucifer B2B Katie Rex'],
#  ['Sat, 19 Oct 2019',
#   'DJ Skull, Verraco, Adrestia',
#   'DJ Skull / Verraco / Adrestia'],
#  ['Fri, 18 Oct 2019',
#   'Joey Beltram, Tin Man, Bryan Kasenic',
#   'Joey Beltram / Tin Man / Bryan Kasenic'],
#  ['Fri, 11 Oct 2019',
#   'Ancient Methods, Vatican Shadow, Ne/Re/A',
#   'Ancient Methods B2B Vatican Shadow / Ne/Re/A'],
#  ['Sat, 5 Oct 2019', 'Joel Mull, Young Male', 'Joel Mull / Young Male'],
#  ['Fri, 4 Oct 2019',
#   'Anastasia Kristensen, John Barera',
#   'Anastasia Kristensen / John Barera'],
#  ['Sat, 28 Sep 2019',
#   'Shifted, SNTS, Aurora Halal',
#   'Shifted / SNTS / Aurora Halal'],
#  ['Fri, 27 Sep 2019',
#   'Daniel Avery, Rachel Noon',
#   'Daniel Avery / Rachel Noon'],
#  ['Sat, 21 Sep 2019',
#   'Dr. Rubinstein, Ryan Smith, Ron Like Hell',
#   'Wrecked with Dr. Rubinstein'],
#  ['Fri, 20 Sep 2019',
#   'Ellen Allien, Volvox, Juana',
#   'Ellen Allien / Volvox / Juana'],
#  ['Fri, 13 Sep 2019',
#   'Wata Igarashi, Batu, Patrick Russell, LDY OSC',
#   'The Bunker with Wata Igarashi / Aleksi Perala / Batu / Patrick Russell / LDY OSC'],
#  ['Sat, 7 Sep 2019',
#   'Vincent Neumann, Shaun J. Wright, Justin Cudmore',
#   'Balance with Vincent Neumann / Shaun J. Wright'],
#  ['Fri, 6 Sep 2019',
#   'Phase Fatale, Unhuman, Abby Echiverri',
#   'Phase Fatale / Unhuman / Abby Echiverri'],
#  ['Sat, 31 Aug 2019', 'Ròman, Ne/Re/A', 'Adam X / Roman / Ne/Re/A'],
#  ['Fri, 30 Aug 2019',
#   'STERAC, Clay Wilson, rrao, Proteus',
#   'Quo Vadis: STERAC / Clay Wilson + rrao [Live] / Soren Roi [Live] / Proteus (UK)'],
#  ['Sat, 24 Aug 2019',
#   'Juliana Huxtable, Heidi Sabertooth',
#   'Juliana Huxtable / Heidi Sabertooth'],
#  ['Sat, 17 Aug 2019', 'Brenecki, Auspex', 'DJ Stingray / Brenecki / Auspex'],
#  ['Sat, 10 Aug 2019',
#   'Umfang, Word of Command',
#   'FIST with Special Guest / Umfang'],
#  ['Sat, 3 Aug 2019',
#   'Partok, Ryan Smith, Ron Like Hell',
#   'Wrecked with Partok / Ron Like Hell / Ryan Smith'],
#  ['Sat, 27 Jul 2019',
#   'Julia Govor, Dasha Redkina, Relaxer',
#   'Vril [Live] / Julia Govor / Dasha Redkina / Relaxer'],
#  ['Fri, 26 Jul 2019', 'Matrixxman, nthng', 'Matrixxman / Nthng'],
#  ['Sat, 20 Jul 2019',
#   'Héctor Oaks, Ndrx',
#   'Bassiani Night with Héctor Oaks / Ndrx'],
#  ['Fri, 19 Jul 2019',
#   'SHDW, Obscure Shape, Damon Bradley',
#   'SHDW & Obscure Shape / Damon Bradley'],
#  ['Sat, 13 Jul 2019',
#   'Broken English Club, Thomas Hessler, FadeFace',
#   'Broken English Club / Thomas Hessler / FadeFace [Live]'],
#  ['Fri, 12 Jul 2019',
#   'Ben Sims, Tapefeed, Ne/Re/A',
#   'Ben Sims / Tapefeed / Ne/Re/A'],
#  ['Sat, 6 Jul 2019',
#   'Joey Beltram, Galcher Lustwerk, The Carry Nation, Gooddroid, Cali Rose, J. Albert, Long Count Cycle, Logan Takahashi, Dee Diggs, AceMo, Rachel Noon, Kiki Kudo, Olive T, motiv-a, GIA, January Hunt, LYDO, Adrestia, Shy Eyez, Octonomy, pH (12), Pure Immanence, Gaul Plus, Toribio, Alonzo, Donny Burlin, Rob Seurat, DJ Healthy',
#   'FOURTH WORLD'],
#  ['Fri, 5 Jul 2019',
#   'Answer Code Request, Mary Yuzovskaya',
#   'Answer Code Request / Mary Yuzovskaya'],
#  ['Sat, 29 Jun 2019', 'Somewhen, Juana, Xiorro', 'Somewhen / Juana / Xiorro'],
#  ['Fri, 28 Jun 2019',
#   'Horse Meat Disco, Steffi, Aurora Halal',
#   'Horse Meat Disco NYC Pride w/ Steffi, Aurora Halal'],
#  ['Sat, 22 Jun 2019',
#   'Etapp Kyle, Acronym, Katie Rex',
#   'Etapp Kyle / Acronym / Katie Rex'],
#  ['Fri, 21 Jun 2019',
#   'Juan Atkins, Young Male, Auspex',
#   'Juan Atkins / Young Male / Auspex'],
#  ['Fri, 14 Jun 2019',
#   'Fiedel, Tin Man, Justin Cudmore',
#   'Fiedel / Tin Man / Justin Cudmore'],
#  ['Sat, 8 Jun 2019',
#   'Veronica Vasicka, L.Sangre, Orphx, Nihal Ramchandani',
#   'Quo Vadis / Veronica Vasicka / L.Sangre / Orphx / O/H / Nihal Ramchandani'],
#  ['Fri, 7 Jun 2019',
#   'Function, Steve Bicknell, Sophia Saze',
#   'Function / Steve Bicknell / Sophia Saze'],
#  ['Sat, 1 Jun 2019',
#   'FJAAK, Newa, Aurora Halal',
#   'FJAAK / Newa / Aurora Halal'],
#  ['Fri, 31 May 2019',
#   'Tommy Four Seven, Silent Servant, Katie Rex',
#   'Tommy Four Seven / Silent Servant / Katie Rex'],
#  ['Sat, 25 May 2019',
#   '999999999, Fabrizio Lapiana',
#   '999999999 / Fabrizio Lapiana'],
#  ['Fri, 24 May 2019',
#   'Luke Slater, Irakli, Caleb ESC, Adrestia',
#   'Staub with Luke Slater / Irakli / Caleb ESC / Adrestia'],
#  ['Sat, 18 May 2019',
#   'Wrecked, Ron Like Hell, Ryan Smith',
#   'Wrecked with CEM'],
#  ['Fri, 17 May 2019',
#   'Headless Horseman, Vatican Shadow, Volvox, Becka Diamond',
#   'Headless Horseman Live / Vatican Shadow / Volvox / Becka Diamond'],
#  ['Sat, 11 May 2019', 'DVS1, Bryan Kasenic', 'DVS1 / Bryan Kasenic'],
#  ['Fri, 10 May 2019',
#   'Rebekah, Heidi Sabertooth, Auspex, Ne/Re/A',
#   'Rebekah / Heidi Sabertooth / Auspex / Ne/Re/A']]

# %%
processed_data = []
for block in parsed_blocks:
    processed_data.append([parse_date(block[0]), [name.strip() for name in block[1].split(',')], block[2]])
for item in processed_data:
    print(item)
# Out:
# [datetime.datetime(2021, 11, 20, 0, 0), ['TYGAPAW', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked: TYGAPAW / Ron Like Hell / Ryan Smith']
# [datetime.datetime(2021, 11, 13, 0, 0), ['Frankie Bones', 'MAEDON', 'Realmz'], 'Sonic Groove Night: Adam X / Frankie Bones / MAEDON / Realmz']
# [datetime.datetime(2021, 11, 6, 0, 0), ['Miss Parker', 'JOSELO', 'Word of Command', 'DJ Clone', 'DJ Clone'], 'Fist: Isabella / Loka / Miss Parker / Joselo b2b Fried Plátano / Word of Command b2b DJ Clone']
# [datetime.datetime(2021, 10, 23, 0, 0), ['D.Dan', 'Katie Rex', 'DAIYAH'], 'Bound Blackout: D.Dan / Katie Rex / Daiyah']
# [datetime.datetime(2021, 10, 22, 0, 0), ['FJAAK', 'Umfang', 'Akua'], 'FJAAK / Umfang / Akua']
# [datetime.datetime(2021, 10, 16, 0, 0), ['Ron Like Hell', 'Ryan Smith'], 'Wrecked']
# [datetime.datetime(2021, 10, 9, 0, 0), ['Sara Landry', 'Volvox', 'Juana'], 'Sara Landry / Volvox / Juana']
# [datetime.datetime(2021, 10, 2, 0, 0), ['Function'], 'Function']
# [datetime.datetime(2021, 9, 25, 0, 0), ['Honcho', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with Honcho']
# [datetime.datetime(2021, 9, 24, 0, 0), ['Robert Hood', 'Aurora Halal', 'FadeFace'], 'Robert Hood / Aurora Halal / Fadeface']
# [datetime.datetime(2021, 9, 17, 0, 0), ['FadeFace', 'Damon Bradley', 'LISAS'], 'FadeFace / Damon Bradley / LISAS']
# [datetime.datetime(2021, 9, 11, 0, 0), ['LYDO', 'TT (NYC)', 'Buzzi', 'Word of Command', 'DJ Clone'], 'Fist: Lydo / TT b2b DJ Salazar / Buzzi / Word of Command b2b DJ Clone']
# [datetime.datetime(2021, 9, 10, 0, 0), ['Headless Horseman', 'Becka Diamond'], 'Regis / Headless Horseman / Becka Diamond']
# [datetime.datetime(2021, 9, 4, 0, 0), ['Phase Fatale', 'Silent Servant', 'Abby Echiverri'], 'Bite Night: Phase Fatale / Silent Servant / Abby Echiverri']
# [datetime.datetime(2021, 8, 28, 0, 0), ['DVS1', 'Volvox'], 'Dvs1 / Volvox']
# [datetime.datetime(2021, 8, 21, 0, 0), ['Veronica Vasicka', 'Ron Morelli', 'January Hunt'], 'Veronica Vasicka / Ron Morelli / January Hunt']
# [datetime.datetime(2021, 8, 14, 0, 0), ['Akua', 'Elle Dee'], 'DJ Stingray / Akua / Elle Dee']
# [datetime.datetime(2021, 8, 7, 0, 0), ['LSDXOXO', 'Newa'], 'Lsdxoxo / Newa']
# [datetime.datetime(2020, 12, 5, 0, 0), ['̸'], 'Ostgut Ton Nacht']
# [datetime.datetime(2020, 6, 24, 0, 0), ['Anthony Parasole', 'Mike Servito', 'Rachel Noon', 'Volvox', 'Xiorro'], 'United We Stream x Basement']
# [datetime.datetime(2020, 6, 2, 0, 0), ['Anthony Parasole', 'Mike Servito', 'Rachel Noon', 'Volvox', 'Xiorro'], 'United We Stream / Live From Basement']
# [datetime.datetime(2020, 3, 27, 0, 0), ['Somewhen', 'Nur Jaber', 'Katie Rex'], '[POSTPONED] Bound: Blackout with Somewhen / Nur Jaber / Katie Rex']
# [datetime.datetime(2020, 3, 21, 0, 0), ['Boris'], '[CANCELLED] 9-Years of Wrecked with Boris']
# [datetime.datetime(2020, 3, 20, 0, 0), ['Boston 168', 'Joey Quinones', 'Pure Immanence'], '[POSTPONED] Boston 168 / Joey Quiñones / Pure Immanence']
# [datetime.datetime(2020, 3, 14, 0, 0), ['Blue Hour', 'Ariel Zetina', 'Miss Parker', 'DJ Clone', 'Word of Command'], '[POSTPONED] Fist with Blue Hour / Ariel Zetina / Miss Parker']
# [datetime.datetime(2020, 3, 13, 0, 0), ['Claire Morgan', 'Bloody Mary', 'Michael Magnan', 'Justin Cudmore'], '[POSTPONED] Balance with Claire Morgan / Bloody Mary / Michael Magnan']
# [datetime.datetime(2020, 3, 6, 0, 0), ['Derrick May', 'Analog Soul'], 'Derrick May / Analog Soul']
# [datetime.datetime(2020, 2, 29, 0, 0), ['VSK', 'Henning Baer', 'Volvox', 'Auspex'], 'Altær: Henning Baer / VSK / Volvox / Auspex']
# [datetime.datetime(2020, 2, 28, 0, 0), ['Pangaea', 'Galcher Lustwerk', 'Lauren Flax'], 'Pangaea / Galcher Lustwerk / Lauren Flax']
# [datetime.datetime(2020, 2, 22, 0, 0), ['Levon Vincent', 'Tin Man', 'Justin Cudmore'], 'Levon Vincent / Tin Man / Justin Cudmore']
# [datetime.datetime(2020, 2, 15, 0, 0), ['Juana', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with Juana / Ron Like Hell / Ryan Smith']
# [datetime.datetime(2020, 2, 14, 0, 0), ['SHDW', 'Obscure Shape', 'Damon Bradley', 'Adrestia'], 'SHDW & Obscure Shape/ Damon Bradley / Adrestia']
# [datetime.datetime(2020, 2, 8, 0, 0), ['Randomer', 'LYDO'], 'Randomer / LYDO']
# [datetime.datetime(2020, 2, 7, 0, 0), ['Rebekah', 'Shlømo', 'GIA'], 'Rebekah / Shlømo / GIA']
# [datetime.datetime(2020, 2, 1, 0, 0), ['999999999', 'Parallx', 'Joey Quinones'], '999999999 / Parallx / Joey Quinones']
# [datetime.datetime(2020, 1, 31, 0, 0), ['ATEQ', 'LISAS'], 'Vril Live / ATEQ / LISAS']
# [datetime.datetime(2020, 1, 25, 0, 0), ['Fiedel', 'Ne/Re/A'], 'Regis / Fiedel / Ne/Re/A']
# [datetime.datetime(2020, 1, 24, 0, 0), ['Matrixxman', 'Sandrien', 'Jason Kendig', 'Mike Servito', 'Justin Cudmore'], 'Balance with Matrixxman / Sandrien / Jason Kendig b2b Mike Servito']
# [datetime.datetime(2020, 1, 18, 0, 0), ['Madison Moore', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with Madison Moore']
# [datetime.datetime(2020, 1, 18, 0, 0), ['Madison Moore', 'Ron Like Hell', 'Ryan Smith'], 'Basement: Talks #1']
# [datetime.datetime(2020, 1, 17, 0, 0), ['Xiorro', 'Auspex', 'FadeFace'], 'Xiorro / Auspex / FadeFace']
# [datetime.datetime(2020, 1, 11, 0, 0), ['Perc', 'Word of Command', 'DJ Clone'], 'Fist with Perc / Baby Blue / Word of Command / DJ Clone']
# [datetime.datetime(2020, 1, 10, 0, 0), ['Veronica Vasicka', 'Hieroglyphic Being', 'John Barera'], 'Veronica Vasicka / Hieroglyphic Being Live / John Barera']
# [datetime.datetime(2020, 1, 4, 0, 0), ['Mike Servito', 'Derek Plaslaiko', 'Clay Wilson', 'rrao'], 'The Bunker with Haruka / Mike Servito x Derek Plaslaiko / Clay Wilson x rrao']
# [datetime.datetime(2019, 12, 21, 0, 0), ['Aurora Halal', 'Umfang', 'Auspex'], 'Aurora Halal / Umfang / Auspex']
# [datetime.datetime(2019, 12, 20, 0, 0), ['Ryan Elliott', 'Fatherhood', 'Joey Quinones'], 'Ryan Elliott / Fatherhood / Joey Quiñones']
# [datetime.datetime(2019, 12, 14, 0, 0), ['Anthony Parasole', 'Steve Bicknell'], 'Anthony Parasole / Steve Bicknell / 0.001']
# [datetime.datetime(2019, 12, 13, 0, 0), ['Agonis', 'Diskonnected', 'Erika', 'Antenes', 'Abby Echiverri'], 'The Bunker x Smoke Machine: Agonis / Diskonnected / Erika x Antenes / Abby Echiverri']
# [datetime.datetime(2019, 12, 7, 0, 0), ['LSDXOXO', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with LSDXOXO / Ron Like Hell / Ryan Smith']
# [datetime.datetime(2019, 12, 6, 0, 0), ['FJAAK', 'Rachel Noon', 'Word of Command'], 'FJAAK / Rachel Noon / Word of Command']
# [datetime.datetime(2019, 11, 30, 0, 0), ['Makaton', 'Swarm Intelligence', 'Brenecki', 'Deflector', 'Cressida', 'Paàl'], 'New York Trax x Voitax']
# [datetime.datetime(2019, 11, 23, 0, 0), ['Dasha Rush', 'Evigt Mörker', 'Long Count Cycle'], 'Dasha Rush / Evigt Mörker / The Long Count Cycle']
# [datetime.datetime(2019, 11, 22, 0, 0), ['VTSS', 'Jasmine Infiniti', 'Cali Rose', 'DJ Clone', 'Word of Command'], 'FIST with VTSS / New World Dysorder']
# [datetime.datetime(2019, 11, 16, 0, 0), ['Ron Like Hell', 'Ryan Smith'], 'Wrecked Residents Night with Ron Like Hell Ryan Smith all Night']
# [datetime.datetime(2019, 11, 15, 0, 0), ['Objekt', 'Pearson Sound', 'Heidi Sabertooth'], 'Objekt / Pearson Sound / Heidi Sabertooth']
# [datetime.datetime(2019, 11, 9, 0, 0), ['Voin Oruwu', 'Hyperaktivist', 'Relaxer'], 'Cxema Backstage']
# [datetime.datetime(2019, 11, 8, 0, 0), ['Oscar Mulero', 'Adriana Lopez', 'Deepak Sharma'], 'Polegroup Night with Oscar Mulero / Adriana Lopez / Deepak Sharma']
# [datetime.datetime(2019, 11, 2, 0, 0), ['Xiorro', 'Auspex', 'FadeFace'], '[CANCELLED] Xiorro / Auspex / Fadeface']
# [datetime.datetime(2019, 11, 1, 0, 0), ['Function'], 'Function Album Tour']
# [datetime.datetime(2019, 11, 1, 0, 0), ['Function', 'Ndrx'], 'Function / Ndrx']
# [datetime.datetime(2019, 10, 26, 0, 0), ['Carlos Souffront', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with Carlos Souffront']
# [datetime.datetime(2019, 10, 25, 0, 0), ['Terence Fixmer', 'Volvox', 'Amanda Mussi', 'Katie Rex'], 'Bound: Blackout with Terence Fixmer / Volvox B2B Amanda Mussi / Latex Lucifer B2B Katie Rex']
# [datetime.datetime(2019, 10, 19, 0, 0), ['DJ Skull', 'Verraco', 'Adrestia'], 'DJ Skull / Verraco / Adrestia']
# [datetime.datetime(2019, 10, 18, 0, 0), ['Joey Beltram', 'Tin Man', 'Bryan Kasenic'], 'Joey Beltram / Tin Man / Bryan Kasenic']
# [datetime.datetime(2019, 10, 11, 0, 0), ['Ancient Methods', 'Vatican Shadow', 'Ne/Re/A'], 'Ancient Methods B2B Vatican Shadow / Ne/Re/A']
# [datetime.datetime(2019, 10, 5, 0, 0), ['Joel Mull', 'Young Male'], 'Joel Mull / Young Male']
# [datetime.datetime(2019, 10, 4, 0, 0), ['Anastasia Kristensen', 'John Barera'], 'Anastasia Kristensen / John Barera']
# [datetime.datetime(2019, 9, 28, 0, 0), ['Shifted', 'SNTS', 'Aurora Halal'], 'Shifted / SNTS / Aurora Halal']
# [datetime.datetime(2019, 9, 27, 0, 0), ['Daniel Avery', 'Rachel Noon'], 'Daniel Avery / Rachel Noon']
# [datetime.datetime(2019, 9, 21, 0, 0), ['Dr. Rubinstein', 'Ryan Smith', 'Ron Like Hell'], 'Wrecked with Dr. Rubinstein']
# [datetime.datetime(2019, 9, 20, 0, 0), ['Ellen Allien', 'Volvox', 'Juana'], 'Ellen Allien / Volvox / Juana']
# [datetime.datetime(2019, 9, 13, 0, 0), ['Wata Igarashi', 'Batu', 'Patrick Russell', 'LDY OSC'], 'The Bunker with Wata Igarashi / Aleksi Perala / Batu / Patrick Russell / LDY OSC']
# [datetime.datetime(2019, 9, 7, 0, 0), ['Vincent Neumann', 'Shaun J. Wright', 'Justin Cudmore'], 'Balance with Vincent Neumann / Shaun J. Wright']
# [datetime.datetime(2019, 9, 6, 0, 0), ['Phase Fatale', 'Unhuman', 'Abby Echiverri'], 'Phase Fatale / Unhuman / Abby Echiverri']
# [datetime.datetime(2019, 8, 31, 0, 0), ['Ròman', 'Ne/Re/A'], 'Adam X / Roman / Ne/Re/A']
# [datetime.datetime(2019, 8, 30, 0, 0), ['STERAC', 'Clay Wilson', 'rrao', 'Proteus'], 'Quo Vadis: STERAC / Clay Wilson + rrao [Live] / Soren Roi [Live] / Proteus (UK)']
# [datetime.datetime(2019, 8, 24, 0, 0), ['Juliana Huxtable', 'Heidi Sabertooth'], 'Juliana Huxtable / Heidi Sabertooth']
# [datetime.datetime(2019, 8, 17, 0, 0), ['Brenecki', 'Auspex'], 'DJ Stingray / Brenecki / Auspex']
# [datetime.datetime(2019, 8, 10, 0, 0), ['Umfang', 'Word of Command'], 'FIST with Special Guest / Umfang']
# [datetime.datetime(2019, 8, 3, 0, 0), ['Partok', 'Ryan Smith', 'Ron Like Hell'], 'Wrecked with Partok / Ron Like Hell / Ryan Smith']
# [datetime.datetime(2019, 7, 27, 0, 0), ['Julia Govor', 'Dasha Redkina', 'Relaxer'], 'Vril [Live] / Julia Govor / Dasha Redkina / Relaxer']
# [datetime.datetime(2019, 7, 26, 0, 0), ['Matrixxman', 'nthng'], 'Matrixxman / Nthng']
# [datetime.datetime(2019, 7, 20, 0, 0), ['Héctor Oaks', 'Ndrx'], 'Bassiani Night with Héctor Oaks / Ndrx']
# [datetime.datetime(2019, 7, 19, 0, 0), ['SHDW', 'Obscure Shape', 'Damon Bradley'], 'SHDW & Obscure Shape / Damon Bradley']
# [datetime.datetime(2019, 7, 13, 0, 0), ['Broken English Club', 'Thomas Hessler', 'FadeFace'], 'Broken English Club / Thomas Hessler / FadeFace [Live]']
# [datetime.datetime(2019, 7, 12, 0, 0), ['Ben Sims', 'Tapefeed', 'Ne/Re/A'], 'Ben Sims / Tapefeed / Ne/Re/A']
# [datetime.datetime(2019, 7, 6, 0, 0), ['Joey Beltram', 'Galcher Lustwerk', 'The Carry Nation', 'Gooddroid', 'Cali Rose', 'J. Albert', 'Long Count Cycle', 'Logan Takahashi', 'Dee Diggs', 'AceMo', 'Rachel Noon', 'Kiki Kudo', 'Olive T', 'motiv-a', 'GIA', 'January Hunt', 'LYDO', 'Adrestia', 'Shy Eyez', 'Octonomy', 'pH (12)', 'Pure Immanence', 'Gaul Plus', 'Toribio', 'Alonzo', 'Donny Burlin', 'Rob Seurat', 'DJ Healthy'], 'FOURTH WORLD']
# [datetime.datetime(2019, 7, 5, 0, 0), ['Answer Code Request', 'Mary Yuzovskaya'], 'Answer Code Request / Mary Yuzovskaya']
# [datetime.datetime(2019, 6, 29, 0, 0), ['Somewhen', 'Juana', 'Xiorro'], 'Somewhen / Juana / Xiorro']
# [datetime.datetime(2019, 6, 28, 0, 0), ['Horse Meat Disco', 'Steffi', 'Aurora Halal'], 'Horse Meat Disco NYC Pride w/ Steffi, Aurora Halal']
# [datetime.datetime(2019, 6, 22, 0, 0), ['Etapp Kyle', 'Acronym', 'Katie Rex'], 'Etapp Kyle / Acronym / Katie Rex']
# [datetime.datetime(2019, 6, 21, 0, 0), ['Juan Atkins', 'Young Male', 'Auspex'], 'Juan Atkins / Young Male / Auspex']
# [datetime.datetime(2019, 6, 14, 0, 0), ['Fiedel', 'Tin Man', 'Justin Cudmore'], 'Fiedel / Tin Man / Justin Cudmore']
# [datetime.datetime(2019, 6, 8, 0, 0), ['Veronica Vasicka', 'L.Sangre', 'Orphx', 'Nihal Ramchandani'], 'Quo Vadis / Veronica Vasicka / L.Sangre / Orphx / O/H / Nihal Ramchandani']
# [datetime.datetime(2019, 6, 7, 0, 0), ['Function', 'Steve Bicknell', 'Sophia Saze'], 'Function / Steve Bicknell / Sophia Saze']
# [datetime.datetime(2019, 6, 1, 0, 0), ['FJAAK', 'Newa', 'Aurora Halal'], 'FJAAK / Newa / Aurora Halal']
# [datetime.datetime(2019, 5, 31, 0, 0), ['Tommy Four Seven', 'Silent Servant', 'Katie Rex'], 'Tommy Four Seven / Silent Servant / Katie Rex']
# [datetime.datetime(2019, 5, 25, 0, 0), ['999999999', 'Fabrizio Lapiana'], '999999999 / Fabrizio Lapiana']
# [datetime.datetime(2019, 5, 24, 0, 0), ['Luke Slater', 'Irakli', 'Caleb ESC', 'Adrestia'], 'Staub with Luke Slater / Irakli / Caleb ESC / Adrestia']
# [datetime.datetime(2019, 5, 18, 0, 0), ['Wrecked', 'Ron Like Hell', 'Ryan Smith'], 'Wrecked with CEM']
# [datetime.datetime(2019, 5, 17, 0, 0), ['Headless Horseman', 'Vatican Shadow', 'Volvox', 'Becka Diamond'], 'Headless Horseman Live / Vatican Shadow / Volvox / Becka Diamond']
# [datetime.datetime(2019, 5, 11, 0, 0), ['DVS1', 'Bryan Kasenic'], 'DVS1 / Bryan Kasenic']
# [datetime.datetime(2019, 5, 10, 0, 0), ['Rebekah', 'Heidi Sabertooth', 'Auspex', 'Ne/Re/A'], 'Rebekah / Heidi Sabertooth / Auspex / Ne/Re/A']

# %%
def clean_parsed_blocks(blocks):
    cleaned = []
    for block in blocks:
        event_title = block[2]
        lower_title = event_title.lower()
        # Drop the block if it contains "postponed" or "cancelled"
        if "postponed" in lower_title or "cancelled" in lower_title:
            continue
        # Apply recasting rules
        if "wrecked" in lower_title: block[2] = "WRECKED"
        elif "bound" in lower_title: block[2] = "BOUND BLACKOUT"
        elif "altær" in lower_title: block[2] = "ALTÆR"
        elif "sonic groove" in lower_title: block[2] = "SONIC GROOVE NIGHT"
        elif "fist" in lower_title: block[2] = "FIST"
        elif "balance" in lower_title: block[2] = "BALANCE"
        elif "bunker" in lower_title: block[2] = "THE BUNKER"
        elif "quo" in lower_title: block[2] = "QUO VADIS"
        elif "bite" in lower_title: block[2] = "BITE NITE"
        elif "united" in lower_title: block[2] = "UNITED WE STREAM"
        cleaned.append(block)
    return cleaned

cleaned_blocks = clean_parsed_blocks(processed_data)
cleaned_blocks
# Out:
# [[datetime.datetime(2021, 11, 20, 0, 0),
#   ['TYGAPAW', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2021, 11, 13, 0, 0),
#   ['Frankie Bones', 'MAEDON', 'Realmz'],
#   'SONIC GROOVE NIGHT'],
#  [datetime.datetime(2021, 11, 6, 0, 0),
#   ['Miss Parker', 'JOSELO', 'Word of Command', 'DJ Clone', 'DJ Clone'],
#   'FIST'],
#  [datetime.datetime(2021, 10, 23, 0, 0),
#   ['D.Dan', 'Katie Rex', 'DAIYAH'],
#   'BOUND BLACKOUT'],
#  [datetime.datetime(2021, 10, 22, 0, 0),
#   ['FJAAK', 'Umfang', 'Akua'],
#   'FJAAK / Umfang / Akua'],
#  [datetime.datetime(2021, 10, 16, 0, 0),
#   ['Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2021, 10, 9, 0, 0),
#   ['Sara Landry', 'Volvox', 'Juana'],
#   'Sara Landry / Volvox / Juana'],
#  [datetime.datetime(2021, 10, 2, 0, 0), ['Function'], 'Function'],
#  [datetime.datetime(2021, 9, 25, 0, 0),
#   ['Honcho', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2021, 9, 24, 0, 0),
#   ['Robert Hood', 'Aurora Halal', 'FadeFace'],
#   'Robert Hood / Aurora Halal / Fadeface'],
#  [datetime.datetime(2021, 9, 17, 0, 0),
#   ['FadeFace', 'Damon Bradley', 'LISAS'],
#   'FadeFace / Damon Bradley / LISAS'],
#  [datetime.datetime(2021, 9, 11, 0, 0),
#   ['LYDO', 'TT (NYC)', 'Buzzi', 'Word of Command', 'DJ Clone'],
#   'FIST'],
#  [datetime.datetime(2021, 9, 10, 0, 0),
#   ['Headless Horseman', 'Becka Diamond'],
#   'Regis / Headless Horseman / Becka Diamond'],
#  [datetime.datetime(2021, 9, 4, 0, 0),
#   ['Phase Fatale', 'Silent Servant', 'Abby Echiverri'],
#   'BITE NIGHT'],
#  [datetime.datetime(2021, 8, 28, 0, 0), ['DVS1', 'Volvox'], 'Dvs1 / Volvox'],
#  [datetime.datetime(2021, 8, 21, 0, 0),
#   ['Veronica Vasicka', 'Ron Morelli', 'January Hunt'],
#   'Veronica Vasicka / Ron Morelli / January Hunt'],
#  [datetime.datetime(2021, 8, 14, 0, 0),
#   ['Akua', 'Elle Dee'],
#   'DJ Stingray / Akua / Elle Dee'],
#  [datetime.datetime(2021, 8, 7, 0, 0), ['LSDXOXO', 'Newa'], 'Lsdxoxo / Newa'],
#  [datetime.datetime(2020, 12, 5, 0, 0), ['̸'], 'Ostgut Ton Nacht'],
#  [datetime.datetime(2020, 6, 24, 0, 0),
#   ['Anthony Parasole', 'Mike Servito', 'Rachel Noon', 'Volvox', 'Xiorro'],
#   'UNITED WE STREAM'],
#  [datetime.datetime(2020, 6, 2, 0, 0),
#   ['Anthony Parasole', 'Mike Servito', 'Rachel Noon', 'Volvox', 'Xiorro'],
#   'UNITED WE STREAM'],
#  [datetime.datetime(2020, 3, 6, 0, 0),
#   ['Derrick May', 'Analog Soul'],
#   'Derrick May / Analog Soul'],
#  [datetime.datetime(2020, 2, 29, 0, 0),
#   ['VSK', 'Henning Baer', 'Volvox', 'Auspex'],
#   'ALTÆR'],
#  [datetime.datetime(2020, 2, 28, 0, 0),
#   ['Pangaea', 'Galcher Lustwerk', 'Lauren Flax'],
#   'Pangaea / Galcher Lustwerk / Lauren Flax'],
#  [datetime.datetime(2020, 2, 22, 0, 0),
#   ['Levon Vincent', 'Tin Man', 'Justin Cudmore'],
#   'Levon Vincent / Tin Man / Justin Cudmore'],
#  [datetime.datetime(2020, 2, 15, 0, 0),
#   ['Juana', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2020, 2, 14, 0, 0),
#   ['SHDW', 'Obscure Shape', 'Damon Bradley', 'Adrestia'],
#   'SHDW & Obscure Shape/ Damon Bradley / Adrestia'],
#  [datetime.datetime(2020, 2, 8, 0, 0),
#   ['Randomer', 'LYDO'],
#   'Randomer / LYDO'],
#  [datetime.datetime(2020, 2, 7, 0, 0),
#   ['Rebekah', 'Shlømo', 'GIA'],
#   'Rebekah / Shlømo / GIA'],
#  [datetime.datetime(2020, 2, 1, 0, 0),
#   ['999999999', 'Parallx', 'Joey Quinones'],
#   '999999999 / Parallx / Joey Quinones'],
#  [datetime.datetime(2020, 1, 31, 0, 0),
#   ['ATEQ', 'LISAS'],
#   'Vril Live / ATEQ / LISAS'],
#  [datetime.datetime(2020, 1, 25, 0, 0),
#   ['Fiedel', 'Ne/Re/A'],
#   'Regis / Fiedel / Ne/Re/A'],
#  [datetime.datetime(2020, 1, 24, 0, 0),
#   ['Matrixxman', 'Sandrien', 'Jason Kendig', 'Mike Servito', 'Justin Cudmore'],
#   'BALANCE'],
#  [datetime.datetime(2020, 1, 18, 0, 0),
#   ['Madison Moore', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2020, 1, 18, 0, 0),
#   ['Madison Moore', 'Ron Like Hell', 'Ryan Smith'],
#   'Basement: Talks #1'],
#  [datetime.datetime(2020, 1, 17, 0, 0),
#   ['Xiorro', 'Auspex', 'FadeFace'],
#   'Xiorro / Auspex / FadeFace'],
#  [datetime.datetime(2020, 1, 11, 0, 0),
#   ['Perc', 'Word of Command', 'DJ Clone'],
#   'FIST'],
#  [datetime.datetime(2020, 1, 10, 0, 0),
#   ['Veronica Vasicka', 'Hieroglyphic Being', 'John Barera'],
#   'Veronica Vasicka / Hieroglyphic Being Live / John Barera'],
#  [datetime.datetime(2020, 1, 4, 0, 0),
#   ['Mike Servito', 'Derek Plaslaiko', 'Clay Wilson', 'rrao'],
#   'THE BUNKER'],
#  [datetime.datetime(2019, 12, 21, 0, 0),
#   ['Aurora Halal', 'Umfang', 'Auspex'],
#   'Aurora Halal / Umfang / Auspex'],
#  [datetime.datetime(2019, 12, 20, 0, 0),
#   ['Ryan Elliott', 'Fatherhood', 'Joey Quinones'],
#   'Ryan Elliott / Fatherhood / Joey Quiñones'],
#  [datetime.datetime(2019, 12, 14, 0, 0),
#   ['Anthony Parasole', 'Steve Bicknell'],
#   'Anthony Parasole / Steve Bicknell / 0.001'],
#  [datetime.datetime(2019, 12, 13, 0, 0),
#   ['Agonis', 'Diskonnected', 'Erika', 'Antenes', 'Abby Echiverri'],
#   'THE BUNKER'],
#  [datetime.datetime(2019, 12, 7, 0, 0),
#   ['LSDXOXO', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2019, 12, 6, 0, 0),
#   ['FJAAK', 'Rachel Noon', 'Word of Command'],
#   'FJAAK / Rachel Noon / Word of Command'],
#  [datetime.datetime(2019, 11, 30, 0, 0),
#   ['Makaton',
#    'Swarm Intelligence',
#    'Brenecki',
#    'Deflector',
#    'Cressida',
#    'Paàl'],
#   'New York Trax x Voitax'],
#  [datetime.datetime(2019, 11, 23, 0, 0),
#   ['Dasha Rush', 'Evigt Mörker', 'Long Count Cycle'],
#   'Dasha Rush / Evigt Mörker / The Long Count Cycle'],
#  [datetime.datetime(2019, 11, 22, 0, 0),
#   ['VTSS', 'Jasmine Infiniti', 'Cali Rose', 'DJ Clone', 'Word of Command'],
#   'FIST'],
#  [datetime.datetime(2019, 11, 16, 0, 0),
#   ['Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2019, 11, 15, 0, 0),
#   ['Objekt', 'Pearson Sound', 'Heidi Sabertooth'],
#   'Objekt / Pearson Sound / Heidi Sabertooth'],
#  [datetime.datetime(2019, 11, 9, 0, 0),
#   ['Voin Oruwu', 'Hyperaktivist', 'Relaxer'],
#   'Cxema Backstage'],
#  [datetime.datetime(2019, 11, 8, 0, 0),
#   ['Oscar Mulero', 'Adriana Lopez', 'Deepak Sharma'],
#   'Polegroup Night with Oscar Mulero / Adriana Lopez / Deepak Sharma'],
#  [datetime.datetime(2019, 11, 1, 0, 0), ['Function'], 'Function Album Tour'],
#  [datetime.datetime(2019, 11, 1, 0, 0),
#   ['Function', 'Ndrx'],
#   'Function / Ndrx'],
#  [datetime.datetime(2019, 10, 26, 0, 0),
#   ['Carlos Souffront', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2019, 10, 25, 0, 0),
#   ['Terence Fixmer', 'Volvox', 'Amanda Mussi', 'Katie Rex'],
#   'BOUND BLACKOUT'],
#  [datetime.datetime(2019, 10, 19, 0, 0),
#   ['DJ Skull', 'Verraco', 'Adrestia'],
#   'DJ Skull / Verraco / Adrestia'],
#  [datetime.datetime(2019, 10, 18, 0, 0),
#   ['Joey Beltram', 'Tin Man', 'Bryan Kasenic'],
#   'Joey Beltram / Tin Man / Bryan Kasenic'],
#  [datetime.datetime(2019, 10, 11, 0, 0),
#   ['Ancient Methods', 'Vatican Shadow', 'Ne/Re/A'],
#   'Ancient Methods B2B Vatican Shadow / Ne/Re/A'],
#  [datetime.datetime(2019, 10, 5, 0, 0),
#   ['Joel Mull', 'Young Male'],
#   'Joel Mull / Young Male'],
#  [datetime.datetime(2019, 10, 4, 0, 0),
#   ['Anastasia Kristensen', 'John Barera'],
#   'Anastasia Kristensen / John Barera'],
#  [datetime.datetime(2019, 9, 28, 0, 0),
#   ['Shifted', 'SNTS', 'Aurora Halal'],
#   'Shifted / SNTS / Aurora Halal'],
#  [datetime.datetime(2019, 9, 27, 0, 0),
#   ['Daniel Avery', 'Rachel Noon'],
#   'Daniel Avery / Rachel Noon'],
#  [datetime.datetime(2019, 9, 21, 0, 0),
#   ['Dr. Rubinstein', 'Ryan Smith', 'Ron Like Hell'],
#   'WRECKED'],
#  [datetime.datetime(2019, 9, 20, 0, 0),
#   ['Ellen Allien', 'Volvox', 'Juana'],
#   'Ellen Allien / Volvox / Juana'],
#  [datetime.datetime(2019, 9, 13, 0, 0),
#   ['Wata Igarashi', 'Batu', 'Patrick Russell', 'LDY OSC'],
#   'THE BUNKER'],
#  [datetime.datetime(2019, 9, 7, 0, 0),
#   ['Vincent Neumann', 'Shaun J. Wright', 'Justin Cudmore'],
#   'BALANCE'],
#  [datetime.datetime(2019, 9, 6, 0, 0),
#   ['Phase Fatale', 'Unhuman', 'Abby Echiverri'],
#   'Phase Fatale / Unhuman / Abby Echiverri'],
#  [datetime.datetime(2019, 8, 31, 0, 0),
#   ['Ròman', 'Ne/Re/A'],
#   'Adam X / Roman / Ne/Re/A'],
#  [datetime.datetime(2019, 8, 30, 0, 0),
#   ['STERAC', 'Clay Wilson', 'rrao', 'Proteus'],
#   'QUO VADIS'],
#  [datetime.datetime(2019, 8, 24, 0, 0),
#   ['Juliana Huxtable', 'Heidi Sabertooth'],
#   'Juliana Huxtable / Heidi Sabertooth'],
#  [datetime.datetime(2019, 8, 17, 0, 0),
#   ['Brenecki', 'Auspex'],
#   'DJ Stingray / Brenecki / Auspex'],
#  [datetime.datetime(2019, 8, 10, 0, 0), ['Umfang', 'Word of Command'], 'FIST'],
#  [datetime.datetime(2019, 8, 3, 0, 0),
#   ['Partok', 'Ryan Smith', 'Ron Like Hell'],
#   'WRECKED'],
#  [datetime.datetime(2019, 7, 27, 0, 0),
#   ['Julia Govor', 'Dasha Redkina', 'Relaxer'],
#   'Vril [Live] / Julia Govor / Dasha Redkina / Relaxer'],
#  [datetime.datetime(2019, 7, 26, 0, 0),
#   ['Matrixxman', 'nthng'],
#   'Matrixxman / Nthng'],
#  [datetime.datetime(2019, 7, 20, 0, 0),
#   ['Héctor Oaks', 'Ndrx'],
#   'Bassiani Night with Héctor Oaks / Ndrx'],
#  [datetime.datetime(2019, 7, 19, 0, 0),
#   ['SHDW', 'Obscure Shape', 'Damon Bradley'],
#   'SHDW & Obscure Shape / Damon Bradley'],
#  [datetime.datetime(2019, 7, 13, 0, 0),
#   ['Broken English Club', 'Thomas Hessler', 'FadeFace'],
#   'Broken English Club / Thomas Hessler / FadeFace [Live]'],
#  [datetime.datetime(2019, 7, 12, 0, 0),
#   ['Ben Sims', 'Tapefeed', 'Ne/Re/A'],
#   'Ben Sims / Tapefeed / Ne/Re/A'],
#  [datetime.datetime(2019, 7, 6, 0, 0),
#   ['Joey Beltram',
#    'Galcher Lustwerk',
#    'The Carry Nation',
#    'Gooddroid',
#    'Cali Rose',
#    'J. Albert',
#    'Long Count Cycle',
#    'Logan Takahashi',
#    'Dee Diggs',
#    'AceMo',
#    'Rachel Noon',
#    'Kiki Kudo',
#    'Olive T',
#    'motiv-a',
#    'GIA',
#    'January Hunt',
#    'LYDO',
#    'Adrestia',
#    'Shy Eyez',
#    'Octonomy',
#    'pH (12)',
#    'Pure Immanence',
#    'Gaul Plus',
#    'Toribio',
#    'Alonzo',
#    'Donny Burlin',
#    'Rob Seurat',
#    'DJ Healthy'],
#   'FOURTH WORLD'],
#  [datetime.datetime(2019, 7, 5, 0, 0),
#   ['Answer Code Request', 'Mary Yuzovskaya'],
#   'Answer Code Request / Mary Yuzovskaya'],
#  [datetime.datetime(2019, 6, 29, 0, 0),
#   ['Somewhen', 'Juana', 'Xiorro'],
#   'Somewhen / Juana / Xiorro'],
#  [datetime.datetime(2019, 6, 28, 0, 0),
#   ['Horse Meat Disco', 'Steffi', 'Aurora Halal'],
#   'Horse Meat Disco NYC Pride w/ Steffi, Aurora Halal'],
#  [datetime.datetime(2019, 6, 22, 0, 0),
#   ['Etapp Kyle', 'Acronym', 'Katie Rex'],
#   'Etapp Kyle / Acronym / Katie Rex'],
#  [datetime.datetime(2019, 6, 21, 0, 0),
#   ['Juan Atkins', 'Young Male', 'Auspex'],
#   'Juan Atkins / Young Male / Auspex'],
#  [datetime.datetime(2019, 6, 14, 0, 0),
#   ['Fiedel', 'Tin Man', 'Justin Cudmore'],
#   'Fiedel / Tin Man / Justin Cudmore'],
#  [datetime.datetime(2019, 6, 8, 0, 0),
#   ['Veronica Vasicka', 'L.Sangre', 'Orphx', 'Nihal Ramchandani'],
#   'QUO VADIS'],
#  [datetime.datetime(2019, 6, 7, 0, 0),
#   ['Function', 'Steve Bicknell', 'Sophia Saze'],
#   'Function / Steve Bicknell / Sophia Saze'],
#  [datetime.datetime(2019, 6, 1, 0, 0),
#   ['FJAAK', 'Newa', 'Aurora Halal'],
#   'FJAAK / Newa / Aurora Halal'],
#  [datetime.datetime(2019, 5, 31, 0, 0),
#   ['Tommy Four Seven', 'Silent Servant', 'Katie Rex'],
#   'Tommy Four Seven / Silent Servant / Katie Rex'],
#  [datetime.datetime(2019, 5, 25, 0, 0),
#   ['999999999', 'Fabrizio Lapiana'],
#   '999999999 / Fabrizio Lapiana'],
#  [datetime.datetime(2019, 5, 24, 0, 0),
#   ['Luke Slater', 'Irakli', 'Caleb ESC', 'Adrestia'],
#   'Staub with Luke Slater / Irakli / Caleb ESC / Adrestia'],
#  [datetime.datetime(2019, 5, 18, 0, 0),
#   ['Wrecked', 'Ron Like Hell', 'Ryan Smith'],
#   'WRECKED'],
#  [datetime.datetime(2019, 5, 17, 0, 0),
#   ['Headless Horseman', 'Vatican Shadow', 'Volvox', 'Becka Diamond'],
#   'Headless Horseman Live / Vatican Shadow / Volvox / Becka Diamond'],
#  [datetime.datetime(2019, 5, 11, 0, 0),
#   ['DVS1', 'Bryan Kasenic'],
#   'DVS1 / Bryan Kasenic'],
#  [datetime.datetime(2019, 5, 10, 0, 0),
#   ['Rebekah', 'Heidi Sabertooth', 'Auspex', 'Ne/Re/A'],
#   'Rebekah / Heidi Sabertooth / Auspex / Ne/Re/A']]

# %%
def create_event_dataframe(data):
    # Create an empty list to store rows
    rows = []
    
    # Loop over each record in the data
    for record in data:
        date_val = record[0]          # First element: datetime object
        dj_list = record[1]           # Second element: list of DJs
        event_title = record[2]       # Third element: event title string
        
        # For each DJ in the dj_list, create a row
        for dj in dj_list:
            row = {
                "Date": date_val,
                "event_title": event_title,
                "stage": "BASEMENT",
                "DJ": dj
            }
            rows.append(row)
    
    # Create a DataFrame from the list of rows
    df = pd.DataFrame(rows)
    return df

xdf = create_event_dataframe(cleaned_blocks)
xdf.to_excel("event_data_x.xlsx")

# %%
from googlesearch import search
import pandas as pd

# List of DJ names
names = [
    'RON LIKE HELL', 'RYAN SMITH', 'WORD OF COMMAND', 'LYDO', 'DJ CLONE', 'MIKE SERVITO', 'KATIE REX', 
    'AUSPEX', 'VOLVOX', 'JUSTIN CUDMORE', 'JASON KENDIG', 'FUNCTION', 'ELLE DEE', 'THE CARRY NATION', 
    'UMFANG', 'KYRUH', 'JEK', 'HARUKA', 'DEE DIGGS', 'ANALOG SOUL', 'ROSE KOURTS', 'RACHEL NOON', 'NE/RE/A', 
    'MATAS', 'JUANA', 'TT', 'NDRX', 'LYCHEE', 'AKUA', 'YOUNG MALE', 'X3BUTTERFLY', 'SHAUN J. WRIGHT', 
    'SEKUCCI', 'SCHACKE', 'PARTOK', 'NEWA', 'COSMO', 'CLARISA KIMSKII', 'MADISON MOORE', 
    'KILOPATRAH JONES', 'JULIANA HUXTABLE', 'IAN CRANE', 'DEVOYE', 'DAIYAH', 'ANCIENT METHODS', 'ANA B', 
    'XIORRO', 'WTCHCRFT', 'PHASE FATALE', 'D.DAN', 'ANTHONY PARASOLE', 'ANNIE LEW', 'ÆON', 
    'VERONICA VASICKA', 'PERC', 'FIEDEL', 'COTTON', 'ANTENES', 'STERLING JUAN DIAZ', 
    'MASSIMILIANO PAGLIARA', 'JADALAREIGN', 'SISTER ZO', 'MEILGAARDEN', 'MANU MIRAN', 'KIM ANH', 
    'KEVIN AVIANCE', 'ROI PEREZ', 'NATUTA', 'MUTUALISM', 'MAKADSI', 'LAUREN FLAX', 'JACOB MEEHAN', 
    'ELI ESCOBAR', 'DJ SALIVA', 'CHRIS CRUSE'
]

# Create a list to store results
results = []

# Iterate over each name and search for "name soundcloud"
for name in names:
    query = f"{name} soundcloud"
    try:
        # Retrieve the first search result
        url = next(search(query, num_results=1, lang="en"))
    except StopIteration:
        url = "No results found."
    
    results.append({
        "DJ": name,
        "Soundcloud Link": url
    })

# Create a DataFrame from the results list
df = pd.DataFrame(results, columns=["DJ", "Soundcloud Link"])

# Display the DataFrame
print(df)
# Out:
# /Users/anderszhou/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
